# %% [markdown]
# <a href="https://colab.research.google.com/github/teoalcdor/tfg_teoalcdor/blob/main/od_youtube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Detección de Objetos en un video de Youtube

# %% [markdown]
# Vamos a aplicar nuestros modelos YOLOv5m y SSD300 a un video de youtube para hacer detección en tiempo real.

# %% [markdown]
# ## Librerías

# %% [markdown]
# Instalamos e importamos las librerías necesarias:

# %%
# !pip install --force-reinstall https://github.com/yt-dlp/yt-dlp/archive/master.tar.gz
# !pip install ultralytics
# Out:
# Collecting https://github.com/yt-dlp/yt-dlp/archive/master.tar.gz
#   Downloading https://github.com/yt-dlp/yt-dlp/archive/master.tar.gz
#      - 2.8 MB 10.1 MB/s 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: yt-dlp
#   Building wheel for yt-dlp (pyproject.toml) ... done
#   Created wheel for yt-dlp: filename=yt_dlp-2025.5.22-py3-none-any.whl size=3013202 sha256=ea1a7fe911f2eaff036daeaf770122ec8d9038d0d6d243cbda30f012735c56f3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-jhq7gifr/wheels/2d/79/97/7209650ef73114e0fe0603480da012ad3afacb9cae6b8acd9a
# Successfully built yt-dlp
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2025.5.22
# Collecting ultralytics
#   Downloading ultralytics-8.3.146-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.146-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 70.6 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 128.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 101.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 114.6 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.146 ultralytics-thop-2.0.14

# %%
from base64 import b64encode
import cv2
from google.colab import drive
from IPython.display import HTML
from IPython.display import Video
import numpy as np
import matplotlib.pyplot as plt
import os
import shutil
from time import time
from sklearn.preprocessing import LabelEncoder
import torch
from torchvision import models
from torchvision import transforms
from torchvision.models.detection.ssd import SSDHead
from torchvision.ops import nms
from ultralytics import YOLO
from yt_dlp import YoutubeDL
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# Tratamos de utilizar la GPU:

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(DEVICE)
# Out:
# cuda

# %% [markdown]
# ## Funciones Auxiliares

# %%
label_encoder = LabelEncoder()
label_encoder.classes_ = np.array([
    "Tank (TANK)",
    "Infantry fighting vehicle (IFV)",
    "Armored personnel carrier (APC)",
    "Engineering vehicle (EV)",
    "Assault helicopter (AH)",
    "Transport helicopter (TH)",
    "Assault airplane (AAP)",
    "Transport airplane (TA)",
    "Anti-aircraft vehicle (AA)",
    "Towed artillery (TART)",
    "Self-propelled artillery (SPART)",
    "Human"
])


def create_class_colors(num_classes, seed):
    """
    Crea un diccionario con los colores de cada clase elegidos de forma
    aleatoria.
    """

    # Reproducibilidad
    np.random.seed(seed)

    # Inicializacion
    class_colors = {}

    # Para cada clase, creamos su color
    for i in range(num_classes):

        # Mientras no aceptemos el color creado para la clase, seguimos creando
        # colores
        not_accepted = True
        while not_accepted:

            # Elegimos el valor para cada canal
            r = np.random.randint(0, 255)
            g = np.random.randint(0, 255)
            b = np.random.randint(0, 255)

            # El color no debe ser muy gris
            not_gray = abs(r - g) > 50 or abs(r - b) > 50 and abs(g - b) > 50

            # El color no debe ser muy blanco
            not_white = r < 230 and g < 230 and b < 230

            # Si no es muy gris ni muy blanco, lo aceptamos
            if not_gray and not_white :
                not_accepted = False
                class_colors[i] = (r, g, b)

    return class_colors

CLASS_COLORS = {
    0: (255,   0,   0),   # red
    1: (  0,   0, 255),   # blue
    2: (  0, 128,   0),   # green
    3: (255, 165,   0),   # orange
    4: (128,   0, 128),   # purple
    5: (255, 255,   0),   # yellow
    6: (  0,   0, 139),   # darkblue
    7: (255,   0, 255),   # magenta
    8: (255, 192, 203),   # pink
    9: (165,  42,  42),   # brown
    10: (128, 128, 128),   # grey
    11: (  0, 100,   0)    # darkgreen
}


def get_model(num_classes):
    """
    Nos permite obtener un modelo SSD300 listo para aplicar transfer learning
    (con su cabeza descongelada) y su optimizador (Adam).
    """

    # Obtenemos el modelo pre-entrenado
    model = models.detection.ssd300_vgg16(weights=models.detection.SSD300_VGG16_Weights.DEFAULT)

    # Congelamos todos los parametros de la backbone
    for param in model.backbone.parameters():
        param.requires_grad = False

    # Calculamos el numero de canales de entrada
    in_channels = \
    [layer.in_channels for layer in model.head.classification_head.module_list]

    # Calculamos el numero de cajas por clase (son 4 y 6, como en teoria)
    boxes_per_class_1 = 364 // 91
    boxes_per_class_2 = 546 // 91

    # Calculamos el numero de cajas por defecto
    num_anchors = [boxes_per_class_1] + \
      3 * [boxes_per_class_2] + \
      2 * [boxes_per_class_1]

    # Instanciamos un objeto de tipo SSDHead adaptado a nuestras necesidades que
    # usamos para hacer las detecciones
    model.head = SSDHead(
        in_channels=in_channels,
        num_anchors=num_anchors,
        num_classes=num_classes + 1
    )

    return model.to(DEVICE)


def decode_output_ssd(output, conf_threshold=0.5):
    """
    Decodifica la salida de SSD300 para que sea posible representarla y
    calcular la mAP.
    """

    # Extraemos las partes de la salida
    bbs = output["boxes"].to("cpu").detach()
    labels = torch.tensor([i - 1 for i in output["labels"].to("cpu")])
    confs = output["scores"].to("cpu").detach()

    # Filtramos en las detecciones
    all_ixs = torch.arange(0, len(confs))
    ixs = torch.tensor([], dtype=torch.int32)

    for label in labels.unique():
        if label != 11:
            label_mask = labels == label # Seleccionamos las detecciones de una clase

            label_ixs = nms(bbs[label_mask], confs[label_mask], 0.05) # Hacemos Non-max suppression

            real_ixs = all_ixs[label_mask][label_ixs] # Seleccionamos solo las detecciones que pasan la nms

            final_ixs = real_ixs[confs[real_ixs] > 0.5] # Seleccionamos solo los indices con confianza > 0.5

            ixs = torch.cat((ixs, final_ixs)) # Nos quesamos con los indices de las detecciones de esta clase que pasan el filtro

    bbs, confs, labels = [tensor[ixs] for tensor in [bbs, confs, labels]] # Filtramos las cajas, confianzas y etiquetas

    return bbs, confs, labels


def adapt_bbs(bbs, image):
    """
    Adapta las cajas de las detecciones de una imagen de formato 300x300 a las
    dimensiones de la imagen
    """
    real_w, real_h = image.shape[1], image.shape[0]
    bbs[:, 0:3:2] = bbs[:, 0:3:2] * real_w / 300
    bbs[:, 1:4:2] = bbs[:, 1:4:2] * real_h / 300

    return bbs


@torch.no_grad()
def predict_ssd(model, image, device):
    """
    Realiza una prediccion con un modelo SSD.
    """

    model.eval() # Modo inferencia

    # Redimensionamos la imagen
    resized_image = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Resize((300, 300)),
        transforms.ToTensor()])(image)

    # Realizamos la prediccion
    output = model(resized_image.unsqueeze(0).to(device))[0]

    # Decodificamos y adaptamos la prediccion
    bbs, confs, labels = decode_output_ssd(output)
    bbs = adapt_bbs(bbs, image)

    return bbs, confs, labels


def plot_bbox(image, bbs, confs, labels, label_encoder=label_encoder,
              class_colors=CLASS_COLORS):
    """
    Dibuja unas detecciones a partir de la informacion de las cajas, confianzas
    y etiquetas.
    """

    for ix, bb in enumerate(bbs):

        # La etiqueta de la caja
        complete_label = \
            label_encoder.inverse_transform([labels[ix].item()])[0] + " - " +  \
            str(round(confs[ix].item(), 2))

        font = cv2.FONT_HERSHEY_SIMPLEX
        font_scale = 0.9
        font_thickness = 2
        text_size, _ = cv2.getTextSize(complete_label, font, font_scale, font_thickness)
        text_width, text_height = text_size

        # Tomamos medidas de la caja para centrar la etiqueta
        x0, y0, x1, y1 = bb
        x12 = (x0 + x1) / 2
        x2 = x12 - text_width / 2
        x3 = x12 + text_width / 2

        x0, y0 = int(x0), int(y0)
        x1, y1 = int(x1), int(y1)
        x2, x3 = int(x2), int(x3)

        # Pintamos caja y etiqueta
        bgr = class_colors[int(labels[ix].item())]
        image = cv2.rectangle(image, (x0, y0), (x1, y1), bgr, thickness=4)
        image = cv2.rectangle(image, (x2 - 20, y0), (x3 + 20, y0 - text_height - 20), bgr, -1)
        image = cv2.putText(image, complete_label, (x2, y0 - 10), font, 0.9, (255, 255, 255), 2)

    return image


def decode_output_yolo(output, conf_threshold=0.2):
    """
    Decodifica la salida de YOLOv5 para que sea posible representarla y
    calcular la mAP.
    """

    # Extraemos las partes de la salida
    bbs = output[0].boxes.xyxy.to("cpu")
    confs = output[0].boxes.conf.to("cpu")
    labels = output[0].boxes.cls.to("cpu").int()

    # Nos quedamos con las detecciones que superen cierto umbral
    ixs = (confs > conf_threshold) & (labels != 11)

    # Filtramos las detecctiones
    bbs = bbs[ixs]
    confs = confs[ixs]
    labels = labels[ixs]

    return bbs, confs, labels


def predict_yolo(model, image, device):
    """
    Realiza una prediccion con un modelo YOLO.
    """

    # Realizamos la prediccion
    output = model.predict(image, device=device, verbose = False)

    # Decodificamos la prediccion
    bbs, confs, labels = decode_output_yolo(output)

    return bbs, confs, labels


# Parametros de los modelos
SSD_FNS = {
    "predict": predict_ssd,
    "plot_boxes": plot_bbox
}

YOLO_FNS = {
    "predict": predict_yolo,
    "plot_boxes": plot_bbox
}

CLASS_INFO = {
    "class2label": label_encoder,
    "class_colors": CLASS_COLORS
}

# %% [markdown]
# ## Clase de los Modelos de Detección

# %% [markdown]
# Creamos una clase de modelo de detección de objetos en un video de YouTube:

# %%
class VideoParserObjectDetectionModel:
    """
    Clase de un modelo de Detección de Objetos que realiza predicciones en un
    video de YouTube frame a frame.
    """

    def __init__(self, model, model_fns, class_info):
        self.model = model
        self.device = "cuda" if torch.cuda.is_available() else "cpu"
        self.model.to(self.device)

        self.predict = model_fns["predict"]
        self.plot_boxes = model_fns["plot_boxes"]
        self.class2label = class_info["class2label"]
        if "class_colors" not in class_info:
            class_colors = {}
            for i in range(len(self.classes)):
                class_colors[i] = (220, 40, 10)
            self.class_colors = class_colors
        else:
            self.class_colors = class_info["class_colors"]

    def get_video_from_url(self, url):
        """
        Obtiene un video de una URL
        """

        with YoutubeDL({"format": "bestvideo"}) as ydl:
            info = ydl.extract_info(url, download=False)

        if info is None:
            raise Exception("No se pudo obtener el stream del video")

        return cv2.VideoCapture(info["url"])

    def score_frame(self, frame):
        """
        Realiza una prediccion en un frame.
        """

        output = self.predict(self.model, frame, self.device)
        return output

    def plot_bbs_in_frame(self, output, frame):
        """
        Dibuja las detecciones en un frame.
        """

        bbs, confs, labels = output
        frame = self.plot_boxes(frame, bbs, confs, labels, self.class2label,
                                self.class_colors)
        return frame

    def __call__(self, url, out_file):
        """
        Realiza una detección en tiempo real en un video de YouTube.
        """

        # Obtenemos el video de YouTube
        player = self.get_video_from_url(url)

        # Comprobamos que el player este abierto
        assert player.isOpened()

        # Inicializamos para poder hacer la prediccion sobre los frames
        x_shape = int(player.get(cv2.CAP_PROP_FRAME_WIDTH))
        y_shape = int(player.get(cv2.CAP_PROP_FRAME_HEIGHT))
        four_cc = cv2.VideoWriter_fourcc(*"MJPG")
        out = cv2.VideoWriter(out_file, four_cc, 20, (x_shape, y_shape))
        fc = 0
        fps = 0
        tfc = int(player.get(cv2.CAP_PROP_FRAME_COUNT))
        tfcc = 0
        i = 0
        while True:
            if i == 9500: # No hacemos la prediccion sobre mas de 9500 frames
                print("Completed!")
                break
            fc += 1
            start_time = time()
            ret, frame = player.read()
            if not ret:
                print("Completed!")
                break

            # Leemos el frame y predecimos sobr el
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            results = self.score_frame(frame)
            frame = self.plot_bbs_in_frame(results, frame)
            frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)

            # Calculamos estadisticas de los FPS a los que predecimos si procede
            end_time = time()
            fps += 1/np.round(end_time - start_time, 3)
            if fc == 10:
                fps = int(fps / 10)
                tfcc += fc
                fc = 0
                per_com = int(tfcc / tfc * 100)
                print(f"Frames Per Second : {fps} || Percentage Parsed : {per_com}")
            out.write(frame)
            i += 1
        player.release()

# %% [markdown]
# Hacemos detección en tiempo real con un video de YouTube:

# %%
# URL = "https://www.youtube.com/watch?v=ZuZtQeGHxi8" # Ucrania dificil
URL = "https://www.youtube.com/watch?v=xV24-uVq3WY" # Desfile fuerzas armadas
# URL = "https://www.youtube.com/watch?v=-l_2An11-P0" # Ucrania HD
# URL = "https://www.youtube.com/watch?v=TR-ORlwlbuA" # Palestina combate
# URL = "https://www.youtube.com/watch?v=lRFDAM3dcFQ" # Palestina Variado

# %% [markdown]
# Conectamos con nuestro Drive, de donde sacaremos los checkpoints de los modelos:

# %%
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## SSD300 Básico

# %%
model = get_model(11)

# %%
checkpoint = torch.load("/content/drive/MyDrive/tfg/models/ssd300.pth", weights_only=False)
model.load_state_dict(checkpoint["best_model"]["model_state_dict"])

# %%
ssd300_rtod = VideoParserObjectDetectionModel(model, SSD_FNS, CLASS_INFO)

# %%
ssd300_rtod(URL, "fuerzas_armadas_ssd300.mp4")

# %% [markdown]
# Salvamos el video resultante del proceso en nuestro Drive:

# %%
# Input video path
save_path = "/content/fuerzas_armadas_ssd300.mp4"

# Compressed video path
compressed_path = "/content/fuerzas_armadas_ssd300_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# %%
shutil.copy(
    "/content/fuerzas_armadas_ssd300_compressed.mp4",
    "/content/drive/MyDrive/tfg/fuerzas_armadas_compressed.mp4"
)

# %% [markdown]
# ## SSD300 con Data Augmentation

# %%
model = get_model(11)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=SSD300_VGG16_Weights.COCO_V1`. You can also use `weights=SSD300_VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
checkpoint = torch.load("/content/drive/MyDrive/tfg/models/ssd300_augmented.pth", weights_only=False)
model.load_state_dict(checkpoint["best_model"]["model_state_dict"])
# Out:
# <All keys matched successfully>

# %%
ssd300_rtod = VideoParserObjectDetectionModel(model, SSD_FNS, CLASS_INFO)

# %%
ssd300_rtod(URL, "fuerzas_armadas_ssd300_augmented.mp4")
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=xV24-uVq3WY
# [youtube] xV24-uVq3WY: Downloading webpage
# [youtube] xV24-uVq3WY: Downloading tv client config
# [youtube] xV24-uVq3WY: Downloading player 4fcd6e4a
# [youtube] xV24-uVq3WY: Downloading tv player API JSON
# [youtube] xV24-uVq3WY: Downloading ios player API JSON
# [youtube] xV24-uVq3WY: Downloading m3u8 information
# Frames Per Second : 27 || Percentage Parsed : 0
# Frames Per Second : 30 || Percentage Parsed : 0
# Frames Per Second : 31 || Percentage Parsed : 0
# Frames Per Second : 32 || Percentage Parsed : 0
# Frames Per Second : 30 || Percentage Parsed : 0
# Frames Per Second : 31 || Percentage Parsed : 0
# Frames Per Second : 31 || Percentage Parsed : 0
# Frames Per Second : 31 || Percentage Parsed : 0
# Frames Per Second : 31 || Percentage Parsed : 0
# Frames Per Second : 32 || Percentage Parsed : 0
# Frames Per Second : 32 || Percentage Parsed : 0
# Frames Per Second : 32 || Percentage Parsed : 0
# Frames Per Second : 32 || Percentage Parsed : 0
# Frames Per Second : 32 || Percentage Parsed : 0
# Frames Per Second : 31 || Percentage Parsed : 1
# Frames Per Second : 32 || Percentage Parsed : 1
# Frames Per Second : 34 || Percentage Parsed : 1
# Frames Per Second : 33 || Percentage Parsed : 1
# Frames Per Second : 33 || Percentage Parsed : 1
# Frames Per Second : 33 || Percentage Parsed : 1
# Frames Per Second : 34 || Percentage Parsed : 1
# Frames Per Second : 33 || Percentage Parsed : 1
# Frames Per Second : 33 || Percentage Parsed : 1
# Frames Per Second : 33 || Percentage Parsed : 1
# Frames Per Second : 32 || Percentage Parsed : 1
# Frames Per Second : 33 || Percentage Parsed : 1
# Frames Per Second : 35 || Percentage Parsed : 1
# Frames Per Second : 34 || Percentage Parsed : 1
# Frames Per Second : 34 || Percentage Parsed : 2
# Frames Per Second : 33 || Percentage Parsed : 2
# Frames Per Second : 33 || Percentage Parsed : 2
# Frames Per Second : 33 || Percentage Parsed : 2
# Frames Per Second : 33 || Percentage Parsed : 2
# Frames Per Second : 34 || Percentage Parsed : 2
# Frames Per Second : 34 || Percentage Parsed : 2
# Frames Per Second : 34 || Percentage Parsed : 2
# Frames Per Second : 33 || Percentage Parsed : 2
# Frames Per Second : 32 || Percentage Parsed : 2
# Frames Per Second : 32 || Percentage Parsed : 2
# Frames Per Second : 33 || Percentage Parsed : 2
# Frames Per Second : 33 || Percentage Parsed : 2
# Frames Per Second : 32 || Percentage Parsed : 2
# Frames Per Second : 31 || Percentage Parsed : 3
# Frames Per Second : 32 || Percentage Parsed : 3
# Frames Per Second : 32 || Percentage Parsed : 3
# Frames Per Second : 31 || Percentage Parsed : 3
# Frames Per Second : 32 || Percentage Parsed : 3
# Frames Per Second : 32 || Percentage Parsed : 3
# Frames Per Second : 32 || Percentage Parsed : 3
# Frames Per Second : 33 || Percentage Parsed : 3
# Frames Per Second : 32 || Percentage Parsed : 3
# Frames Per Second : 33 || Percentage Parsed : 3
# Frames Per Second : 33 || Percentage Parsed : 3
# Frames Per Second : 33 || Percentage Parsed : 3
# Frames Per Second : 33 || Percentage Parsed : 3
# Frames Per Second : 32 || Percentage Parsed : 3
# Frames Per Second : 32 || Percentage Parsed : 4
# Frames Per Second : 32 || Percentage Parsed : 4
# Frames Per Second : 32 || Percentage Parsed : 4
# Frames Per Second : 32 || Percentage Parsed : 4
# Frames Per Second : 33 || Percentage Parsed : 4
# Frames Per Second : 33 || Percentage Parsed : 4
# Frames Per Second : 33 || Percentage Parsed : 4
# Frames Per Second : 32 || Percentage Parsed : 4
# Frames Per Second : 32 || Percentage Parsed : 4
# Frames Per Second : 32 || Percentage Parsed : 4
# Frames Per Second : 32 || Percentage Parsed : 4
# Frames Per Second : 32 || Percentage Parsed : 4
# Frames Per Second : 32 || Percentage Parsed : 4
# Frames Per Second : 33 || Percentage Parsed : 4
# Frames Per Second : 33 || Percentage Parsed : 5
# Frames Per Second : 32 || Percentage Parsed : 5
# Frames Per Second : 33 || Percentage Parsed : 5
# Frames Per Second : 33 || Percentage Parsed : 5
# Frames Per Second : 33 || Percentage Parsed : 5
# Frames Per Second : 32 || Percentage Parsed : 5
# Frames Per Second : 32 || Percentage Parsed : 5
# Frames Per Second : 32 || Percentage Parsed : 5
# Frames Per Second : 32 || Percentage Parsed : 5
# Frames Per Second : 33 || Percentage Parsed : 5
# Frames Per Second : 32 || Percentage Parsed : 5
# Frames Per Second : 33 || Percentage Parsed : 5
# Frames Per Second : 33 || Percentage Parsed : 5
# Frames Per Second : 33 || Percentage Parsed : 5
# Frames Per Second : 32 || Percentage Parsed : 5
# Frames Per Second : 32 || Percentage Parsed : 6
# Frames Per Second : 32 || Percentage Parsed : 6
# Frames Per Second : 32 || Percentage Parsed : 6
# Frames Per Second : 31 || Percentage Parsed : 6
# Frames Per Second : 32 || Percentage Parsed : 6
# Frames Per Second : 32 || Percentage Parsed : 6
# Frames Per Second : 32 || Percentage Parsed : 6
# Frames Per Second : 32 || Percentage Parsed : 6
# Frames Per Second : 32 || Percentage Parsed : 6
# Frames Per Second : 33 || Percentage Parsed : 6
# Frames Per Second : 33 || Percentage Parsed : 6
# Frames Per Second : 33 || Percentage Parsed : 6
# Frames Per Second : 33 || Percentage Parsed : 6
# Frames Per Second : 33 || Percentage Parsed : 6
# Frames Per Second : 33 || Percentage Parsed : 7
# Frames Per Second : 32 || Percentage Parsed : 7
# Frames Per Second : 33 || Percentage Parsed : 7
# Frames Per Second : 33 || Percentage Parsed : 7
# Frames Per Second : 33 || Percentage Parsed : 7
# Frames Per Second : 32 || Percentage Parsed : 7
# Frames Per Second : 32 || Percentage Parsed : 7
# Frames Per Second : 33 || Percentage Parsed : 7
# Frames Per Second : 32 || Percentage Parsed : 7
# Frames Per Second : 31 || Percentage Parsed : 7
# Frames Per Second : 32 || Percentage Parsed : 7
# Frames Per Second : 32 || Percentage Parsed : 7
# Frames Per Second : 33 || Percentage Parsed : 7
# Frames Per Second : 33 || Percentage Parsed : 7
# Frames Per Second : 33 || Percentage Parsed : 8
# Frames Per Second : 32 || Percentage Parsed : 8
# Frames Per Second : 33 || Percentage Parsed : 8
# Frames Per Second : 33 || Percentage Parsed : 8
# Frames Per Second : 33 || Percentage Parsed : 8
# Frames Per Second : 32 || Percentage Parsed : 8
# Frames Per Second : 33 || Percentage Parsed : 8
# Frames Per Second : 32 || Percentage Parsed : 8
# Frames Per Second : 32 || Percentage Parsed : 8
# Frames Per Second : 32 || Percentage Parsed : 8
# Frames Per Second : 32 || Percentage Parsed : 8
# Frames Per Second : 32 || Percentage Parsed : 8
# Frames Per Second : 32 || Percentage Parsed : 8
# Frames Per Second : 32 || Percentage Parsed : 8
# Frames Per Second : 32 || Percentage Parsed : 9
# Frames Per Second : 32 || Percentage Parsed : 9
# Frames Per Second : 31 || Percentage Parsed : 9
# Frames Per Second : 32 || Percentage Parsed : 9
# Frames Per Second : 32 || Percentage Parsed : 9
# Frames Per Second : 32 || Percentage Parsed : 9
# Frames Per Second : 32 || Percentage Parsed : 9
# Frames Per Second : 32 || Percentage Parsed : 9
# Frames Per Second : 32 || Percentage Parsed : 9
# Frames Per Second : 32 || Percentage Parsed : 9
# Frames Per Second : 32 || Percentage Parsed : 9
# Frames Per Second : 32 || Percentage Parsed : 9
# Frames Per Second : 33 || Percentage Parsed : 9
# Frames Per Second : 32 || Percentage Parsed : 9
# Frames Per Second : 32 || Percentage Parsed : 10
# Frames Per Second : 32 || Percentage Parsed : 10
# Frames Per Second : 32 || Percentage Parsed : 10
# Frames Per Second : 33 || Percentage Parsed : 10
# Frames Per Second : 33 || Percentage Parsed : 10
# Frames Per Second : 32 || Percentage Parsed : 10
# Frames Per Second : 32 || Percentage Parsed : 10
# Frames Per Second : 32 || Percentage Parsed : 10
# Frames Per Second : 32 || Percentage Parsed : 10
# Frames Per Second : 32 || Percentage Parsed : 10
# Frames Per Second : 33 || Percentage Parsed : 10
# Frames Per Second : 33 || Percentage Parsed : 10
# Frames Per Second : 33 || Percentage Parsed : 10
# Frames Per Second : 33 || Percentage Parsed : 10
# Frames Per Second : 33 || Percentage Parsed : 10
# Frames Per Second : 33 || Percentage Parsed : 11
# Frames Per Second : 33 || Percentage Parsed : 11
# Frames Per Second : 33 || Percentage Parsed : 11
# Frames Per Second : 33 || Percentage Parsed : 11
# Frames Per Second : 33 || Percentage Parsed : 11
# Frames Per Second : 33 || Percentage Parsed : 11
# Frames Per Second : 32 || Percentage Parsed : 11
# Frames Per Second : 33 || Percentage Parsed : 11
# Frames Per Second : 33 || Percentage Parsed : 11
# Frames Per Second : 32 || Percentage Parsed : 11
# Frames Per Second : 33 || Percentage Parsed : 11
# Frames Per Second : 32 || Percentage Parsed : 11
# Frames Per Second : 32 || Percentage Parsed : 11
# Frames Per Second : 32 || Percentage Parsed : 11
# Frames Per Second : 32 || Percentage Parsed : 12
# Frames Per Second : 33 || Percentage Parsed : 12
# Frames Per Second : 33 || Percentage Parsed : 12
# Frames Per Second : 33 || Percentage Parsed : 12
# Frames Per Second : 33 || Percentage Parsed : 12
# Frames Per Second : 33 || Percentage Parsed : 12
# Frames Per Second : 33 || Percentage Parsed : 12
# Frames Per Second : 33 || Percentage Parsed : 12
# Frames Per Second : 32 || Percentage Parsed : 12
# Frames Per Second : 32 || Percentage Parsed : 12
# Frames Per Second : 32 || Percentage Parsed : 12
# Frames Per Second : 33 || Percentage Parsed : 12
# Frames Per Second : 32 || Percentage Parsed : 12
# Frames Per Second : 32 || Percentage Parsed : 12
# Frames Per Second : 33 || Percentage Parsed : 13
# Frames Per Second : 32 || Percentage Parsed : 13
# Frames Per Second : 32 || Percentage Parsed : 13
# Frames Per Second : 33 || Percentage Parsed : 13
# Frames Per Second : 32 || Percentage Parsed : 13
# Frames Per Second : 33 || Percentage Parsed : 13
# Frames Per Second : 32 || Percentage Parsed : 13
# Frames Per Second : 32 || Percentage Parsed : 13
# Frames Per Second : 32 || Percentage Parsed : 13
# Frames Per Second : 32 || Percentage Parsed : 13
# Frames Per Second : 32 || Percentage Parsed : 13
# Frames Per Second : 32 || Percentage Parsed : 13
# Frames Per Second : 32 || Percentage Parsed : 13
# Frames Per Second : 32 || Percentage Parsed : 13
# Frames Per Second : 32 || Percentage Parsed : 14
# Frames Per Second : 32 || Percentage Parsed : 14
# Frames Per Second : 32 || Percentage Parsed : 14
# Frames Per Second : 32 || Percentage Parsed : 14
# Frames Per Second : 32 || Percentage Parsed : 14
# Frames Per Second : 33 || Percentage Parsed : 14
# Frames Per Second : 32 || Percentage Parsed : 14
# Frames Per Second : 32 || Percentage Parsed : 14
# Frames Per Second : 33 || Percentage Parsed : 14
# Frames Per Second : 32 || Percentage Parsed : 14
# Frames Per Second : 32 || Percentage Parsed : 14
# Frames Per Second : 32 || Percentage Parsed : 14
# Frames Per Second : 32 || Percentage Parsed : 14
# Frames Per Second : 33 || Percentage Parsed : 14
# Frames Per Second : 31 || Percentage Parsed : 15
# Frames Per Second : 32 || Percentage Parsed : 15
# Frames Per Second : 32 || Percentage Parsed : 15
# Frames Per Second : 32 || Percentage Parsed : 15
# Frames Per Second : 32 || Percentage Parsed : 15
# Frames Per Second : 33 || Percentage Parsed : 15
# Frames Per Second : 32 || Percentage Parsed : 15
# Frames Per Second : 32 || Percentage Parsed : 15
# Frames Per Second : 32 || Percentage Parsed : 15
# Frames Per Second : 32 || Percentage Parsed : 15
# Frames Per Second : 32 || Percentage Parsed : 15
# Frames Per Second : 33 || Percentage Parsed : 15
# Frames Per Second : 32 || Percentage Parsed : 15
# Frames Per Second : 32 || Percentage Parsed : 15
# Frames Per Second : 33 || Percentage Parsed : 16
# Frames Per Second : 33 || Percentage Parsed : 16
# Frames Per Second : 33 || Percentage Parsed : 16
# Frames Per Second : 33 || Percentage Parsed : 16
# Frames Per Second : 33 || Percentage Parsed : 16
# Frames Per Second : 32 || Percentage Parsed : 16
# Frames Per Second : 32 || Percentage Parsed : 16
# Frames Per Second : 31 || Percentage Parsed : 16
# Frames Per Second : 32 || Percentage Parsed : 16
# Frames Per Second : 32 || Percentage Parsed : 16
# Frames Per Second : 32 || Percentage Parsed : 16
# Frames Per Second : 32 || Percentage Parsed : 16
# Frames Per Second : 32 || Percentage Parsed : 16
# Frames Per Second : 33 || Percentage Parsed : 16
# Frames Per Second : 33 || Percentage Parsed : 16
# Frames Per Second : 33 || Percentage Parsed : 17
# Frames Per Second : 33 || Percentage Parsed : 17
# Frames Per Second : 32 || Percentage Parsed : 17
# Frames Per Second : 33 || Percentage Parsed : 17
# Frames Per Second : 32 || Percentage Parsed : 17
# Frames Per Second : 33 || Percentage Parsed : 17
# Frames Per Second : 33 || Percentage Parsed : 17
# Frames Per Second : 34 || Percentage Parsed : 17
# Frames Per Second : 35 || Percentage Parsed : 17
# Frames Per Second : 34 || Percentage Parsed : 17
# Frames Per Second : 33 || Percentage Parsed : 17
# Frames Per Second : 33 || Percentage Parsed : 17
# Frames Per Second : 32 || Percentage Parsed : 17
# Frames Per Second : 33 || Percentage Parsed : 17
# Frames Per Second : 33 || Percentage Parsed : 18
# Frames Per Second : 33 || Percentage Parsed : 18
# Frames Per Second : 33 || Percentage Parsed : 18
# Frames Per Second : 35 || Percentage Parsed : 18
# Frames Per Second : 35 || Percentage Parsed : 18
# Frames Per Second : 35 || Percentage Parsed : 18
# Frames Per Second : 36 || Percentage Parsed : 18
# Frames Per Second : 36 || Percentage Parsed : 18
# Frames Per Second : 36 || Percentage Parsed : 18
# Frames Per Second : 36 || Percentage Parsed : 18
# Frames Per Second : 36 || Percentage Parsed : 18
# Frames Per Second : 36 || Percentage Parsed : 18
# Frames Per Second : 35 || Percentage Parsed : 18
# Frames Per Second : 33 || Percentage Parsed : 18
# Frames Per Second : 32 || Percentage Parsed : 19
# Frames Per Second : 32 || Percentage Parsed : 19
# Frames Per Second : 33 || Percentage Parsed : 19
# Frames Per Second : 33 || Percentage Parsed : 19
# Frames Per Second : 33 || Percentage Parsed : 19
# Frames Per Second : 33 || Percentage Parsed : 19
# Frames Per Second : 32 || Percentage Parsed : 19
# Frames Per Second : 32 || Percentage Parsed : 19
# Frames Per Second : 32 || Percentage Parsed : 19
# Frames Per Second : 33 || Percentage Parsed : 19
# Frames Per Second : 33 || Percentage Parsed : 19
# Frames Per Second : 34 || Percentage Parsed : 19
# Frames Per Second : 35 || Percentage Parsed : 19
# Frames Per Second : 34 || Percentage Parsed : 19
# Frames Per Second : 34 || Percentage Parsed : 20
# Frames Per Second : 34 || Percentage Parsed : 20
# Frames Per Second : 34 || Percentage Parsed : 20
# Frames Per Second : 34 || Percentage Parsed : 20
# Frames Per Second : 33 || Percentage Parsed : 20
# Frames Per Second : 34 || Percentage Parsed : 20
# Frames Per Second : 33 || Percentage Parsed : 20
# Frames Per Second : 32 || Percentage Parsed : 20
# Frames Per Second : 32 || Percentage Parsed : 20
# Frames Per Second : 31 || Percentage Parsed : 20
# Frames Per Second : 32 || Percentage Parsed : 20
# Frames Per Second : 32 || Percentage Parsed : 20
# Frames Per Second : 32 || Percentage Parsed : 20
# Frames Per Second : 32 || Percentage Parsed : 20
# Frames Per Second : 32 || Percentage Parsed : 21
# Frames Per Second : 31 || Percentage Parsed : 21
# Frames Per Second : 31 || Percentage Parsed : 21
# Frames Per Second : 31 || Percentage Parsed : 21
# Frames Per Second : 31 || Percentage Parsed : 21
# Frames Per Second : 32 || Percentage Parsed : 21
# Frames Per Second : 33 || Percentage Parsed : 21
# Frames Per Second : 33 || Percentage Parsed : 21
# Frames Per Second : 33 || Percentage Parsed : 21
# Frames Per Second : 31 || Percentage Parsed : 21
# Frames Per Second : 32 || Percentage Parsed : 21
# Frames Per Second : 32 || Percentage Parsed : 21
# Frames Per Second : 32 || Percentage Parsed : 21
# Frames Per Second : 32 || Percentage Parsed : 21
# Frames Per Second : 33 || Percentage Parsed : 21
# Frames Per Second : 32 || Percentage Parsed : 22
# Frames Per Second : 32 || Percentage Parsed : 22
# Frames Per Second : 32 || Percentage Parsed : 22
# Frames Per Second : 33 || Percentage Parsed : 22
# Frames Per Second : 33 || Percentage Parsed : 22
# Frames Per Second : 33 || Percentage Parsed : 22
# Frames Per Second : 32 || Percentage Parsed : 22
# Frames Per Second : 33 || Percentage Parsed : 22
# Frames Per Second : 34 || Percentage Parsed : 22
# Frames Per Second : 34 || Percentage Parsed : 22
# Frames Per Second : 34 || Percentage Parsed : 22
# Frames Per Second : 33 || Percentage Parsed : 22
# Frames Per Second : 34 || Percentage Parsed : 22
# Frames Per Second : 34 || Percentage Parsed : 22
# Frames Per Second : 34 || Percentage Parsed : 23
# Frames Per Second : 35 || Percentage Parsed : 23
# Frames Per Second : 34 || Percentage Parsed : 23
# Frames Per Second : 34 || Percentage Parsed : 23
# Frames Per Second : 34 || Percentage Parsed : 23
# Frames Per Second : 34 || Percentage Parsed : 23
# Frames Per Second : 33 || Percentage Parsed : 23
# Frames Per Second : 32 || Percentage Parsed : 23
# Frames Per Second : 33 || Percentage Parsed : 23
# Frames Per Second : 33 || Percentage Parsed : 23
# Frames Per Second : 33 || Percentage Parsed : 23
# Frames Per Second : 32 || Percentage Parsed : 23
# Frames Per Second : 32 || Percentage Parsed : 23
# Frames Per Second : 32 || Percentage Parsed : 23
# Frames Per Second : 32 || Percentage Parsed : 24
# Frames Per Second : 31 || Percentage Parsed : 24
# Frames Per Second : 33 || Percentage Parsed : 24
# Frames Per Second : 34 || Percentage Parsed : 24
# Frames Per Second : 34 || Percentage Parsed : 24
# Frames Per Second : 34 || Percentage Parsed : 24
# Frames Per Second : 33 || Percentage Parsed : 24
# Frames Per Second : 34 || Percentage Parsed : 24
# Frames Per Second : 34 || Percentage Parsed : 24
# Frames Per Second : 33 || Percentage Parsed : 24
# Frames Per Second : 33 || Percentage Parsed : 24
# Frames Per Second : 32 || Percentage Parsed : 24
# Frames Per Second : 32 || Percentage Parsed : 24
# Frames Per Second : 32 || Percentage Parsed : 24
# Frames Per Second : 32 || Percentage Parsed : 25
# Frames Per Second : 32 || Percentage Parsed : 25
# Frames Per Second : 32 || Percentage Parsed : 25
# Frames Per Second : 32 || Percentage Parsed : 25
# Frames Per Second : 32 || Percentage Parsed : 25
# Frames Per Second : 33 || Percentage Parsed : 25
# Frames Per Second : 32 || Percentage Parsed : 25
# Frames Per Second : 33 || Percentage Parsed : 25
# Frames Per Second : 32 || Percentage Parsed : 25
# Frames Per Second : 32 || Percentage Parsed : 25
# Frames Per Second : 33 || Percentage Parsed : 25
# Frames Per Second : 32 || Percentage Parsed : 25
# Frames Per Second : 32 || Percentage Parsed : 25
# Frames Per Second : 32 || Percentage Parsed : 25
# Frames Per Second : 33 || Percentage Parsed : 26
# Frames Per Second : 33 || Percentage Parsed : 26
# Frames Per Second : 32 || Percentage Parsed : 26
# Frames Per Second : 32 || Percentage Parsed : 26
# Frames Per Second : 33 || Percentage Parsed : 26
# Frames Per Second : 33 || Percentage Parsed : 26
# Frames Per Second : 34 || Percentage Parsed : 26
# Frames Per Second : 33 || Percentage Parsed : 26
# Frames Per Second : 34 || Percentage Parsed : 26
# Frames Per Second : 34 || Percentage Parsed : 26
# Frames Per Second : 34 || Percentage Parsed : 26
# Frames Per Second : 34 || Percentage Parsed : 26
# Frames Per Second : 34 || Percentage Parsed : 26
# Frames Per Second : 33 || Percentage Parsed : 26
# Frames Per Second : 34 || Percentage Parsed : 27
# Frames Per Second : 34 || Percentage Parsed : 27
# Frames Per Second : 33 || Percentage Parsed : 27
# Frames Per Second : 33 || Percentage Parsed : 27
# Frames Per Second : 34 || Percentage Parsed : 27
# Frames Per Second : 34 || Percentage Parsed : 27
# Frames Per Second : 34 || Percentage Parsed : 27
# Frames Per Second : 34 || Percentage Parsed : 27
# Frames Per Second : 33 || Percentage Parsed : 27
# Frames Per Second : 33 || Percentage Parsed : 27
# Frames Per Second : 33 || Percentage Parsed : 27
# Frames Per Second : 33 || Percentage Parsed : 27
# Frames Per Second : 33 || Percentage Parsed : 27
# Frames Per Second : 33 || Percentage Parsed : 27
# Frames Per Second : 33 || Percentage Parsed : 27
# Frames Per Second : 33 || Percentage Parsed : 28
# Frames Per Second : 33 || Percentage Parsed : 28
# Frames Per Second : 34 || Percentage Parsed : 28
# Frames Per Second : 34 || Percentage Parsed : 28
# Frames Per Second : 34 || Percentage Parsed : 28
# Frames Per Second : 34 || Percentage Parsed : 28
# Frames Per Second : 33 || Percentage Parsed : 28
# Frames Per Second : 33 || Percentage Parsed : 28
# Frames Per Second : 32 || Percentage Parsed : 28
# Frames Per Second : 32 || Percentage Parsed : 28
# Frames Per Second : 33 || Percentage Parsed : 28
# Frames Per Second : 34 || Percentage Parsed : 28
# Frames Per Second : 33 || Percentage Parsed : 28
# Frames Per Second : 33 || Percentage Parsed : 28
# Frames Per Second : 34 || Percentage Parsed : 29
# Frames Per Second : 33 || Percentage Parsed : 29
# Frames Per Second : 33 || Percentage Parsed : 29
# Frames Per Second : 32 || Percentage Parsed : 29
# Frames Per Second : 32 || Percentage Parsed : 29
# Frames Per Second : 32 || Percentage Parsed : 29
# Frames Per Second : 32 || Percentage Parsed : 29
# Frames Per Second : 33 || Percentage Parsed : 29
# Frames Per Second : 32 || Percentage Parsed : 29
# Frames Per Second : 32 || Percentage Parsed : 29
# Frames Per Second : 33 || Percentage Parsed : 29
# Frames Per Second : 33 || Percentage Parsed : 29
# Frames Per Second : 33 || Percentage Parsed : 29
# Frames Per Second : 33 || Percentage Parsed : 29
# Frames Per Second : 32 || Percentage Parsed : 30
# Frames Per Second : 32 || Percentage Parsed : 30
# Frames Per Second : 33 || Percentage Parsed : 30
# Frames Per Second : 32 || Percentage Parsed : 30
# Frames Per Second : 33 || Percentage Parsed : 30
# Frames Per Second : 33 || Percentage Parsed : 30
# Frames Per Second : 32 || Percentage Parsed : 30
# Frames Per Second : 33 || Percentage Parsed : 30
# Frames Per Second : 33 || Percentage Parsed : 30
# Frames Per Second : 33 || Percentage Parsed : 30
# Frames Per Second : 33 || Percentage Parsed : 30
# Frames Per Second : 33 || Percentage Parsed : 30
# Frames Per Second : 33 || Percentage Parsed : 30
# Frames Per Second : 32 || Percentage Parsed : 30
# Frames Per Second : 32 || Percentage Parsed : 31
# Frames Per Second : 32 || Percentage Parsed : 31
# Frames Per Second : 33 || Percentage Parsed : 31
# Frames Per Second : 33 || Percentage Parsed : 31
# Frames Per Second : 33 || Percentage Parsed : 31
# Frames Per Second : 33 || Percentage Parsed : 31
# Frames Per Second : 34 || Percentage Parsed : 31
# Frames Per Second : 33 || Percentage Parsed : 31
# Frames Per Second : 33 || Percentage Parsed : 31
# Frames Per Second : 33 || Percentage Parsed : 31
# Frames Per Second : 32 || Percentage Parsed : 31
# Frames Per Second : 33 || Percentage Parsed : 31
# Frames Per Second : 33 || Percentage Parsed : 31
# Frames Per Second : 33 || Percentage Parsed : 31
# Frames Per Second : 34 || Percentage Parsed : 32
# Frames Per Second : 33 || Percentage Parsed : 32
# Frames Per Second : 34 || Percentage Parsed : 32
# Frames Per Second : 33 || Percentage Parsed : 32
# Frames Per Second : 33 || Percentage Parsed : 32
# Frames Per Second : 33 || Percentage Parsed : 32
# Frames Per Second : 33 || Percentage Parsed : 32
# Frames Per Second : 32 || Percentage Parsed : 32
# Frames Per Second : 32 || Percentage Parsed : 32
# Frames Per Second : 32 || Percentage Parsed : 32
# Frames Per Second : 33 || Percentage Parsed : 32
# Frames Per Second : 32 || Percentage Parsed : 32
# Frames Per Second : 32 || Percentage Parsed : 32
# Frames Per Second : 33 || Percentage Parsed : 32
# Frames Per Second : 33 || Percentage Parsed : 32
# Frames Per Second : 33 || Percentage Parsed : 33
# Frames Per Second : 32 || Percentage Parsed : 33
# Frames Per Second : 32 || Percentage Parsed : 33
# Frames Per Second : 33 || Percentage Parsed : 33
# Frames Per Second : 32 || Percentage Parsed : 33
# Frames Per Second : 32 || Percentage Parsed : 33
# Frames Per Second : 32 || Percentage Parsed : 33
# Frames Per Second : 32 || Percentage Parsed : 33
# Frames Per Second : 33 || Percentage Parsed : 33
# Frames Per Second : 33 || Percentage Parsed : 33
# Frames Per Second : 33 || Percentage Parsed : 33
# Frames Per Second : 34 || Percentage Parsed : 33
# Frames Per Second : 33 || Percentage Parsed : 33
# Frames Per Second : 33 || Percentage Parsed : 33
# Frames Per Second : 33 || Percentage Parsed : 34
# Frames Per Second : 33 || Percentage Parsed : 34
# Frames Per Second : 33 || Percentage Parsed : 34
# Frames Per Second : 33 || Percentage Parsed : 34
# Frames Per Second : 33 || Percentage Parsed : 34
# Frames Per Second : 33 || Percentage Parsed : 34
# Frames Per Second : 33 || Percentage Parsed : 34
# Frames Per Second : 32 || Percentage Parsed : 34
# Frames Per Second : 32 || Percentage Parsed : 34
# Frames Per Second : 32 || Percentage Parsed : 34
# Frames Per Second : 32 || Percentage Parsed : 34
# Frames Per Second : 33 || Percentage Parsed : 34
# Frames Per Second : 32 || Percentage Parsed : 34
# Frames Per Second : 32 || Percentage Parsed : 34
# Frames Per Second : 33 || Percentage Parsed : 35
# Frames Per Second : 33 || Percentage Parsed : 35
# Frames Per Second : 33 || Percentage Parsed : 35
# Frames Per Second : 32 || Percentage Parsed : 35
# Frames Per Second : 32 || Percentage Parsed : 35
# Frames Per Second : 33 || Percentage Parsed : 35
# Frames Per Second : 33 || Percentage Parsed : 35
# Frames Per Second : 32 || Percentage Parsed : 35
# Frames Per Second : 33 || Percentage Parsed : 35
# Frames Per Second : 33 || Percentage Parsed : 35
# Frames Per Second : 34 || Percentage Parsed : 35
# Frames Per Second : 34 || Percentage Parsed : 35
# Frames Per Second : 34 || Percentage Parsed : 35
# Frames Per Second : 33 || Percentage Parsed : 35
# Frames Per Second : 33 || Percentage Parsed : 36
# Frames Per Second : 33 || Percentage Parsed : 36
# Frames Per Second : 33 || Percentage Parsed : 36
# Frames Per Second : 33 || Percentage Parsed : 36
# Frames Per Second : 33 || Percentage Parsed : 36
# Frames Per Second : 33 || Percentage Parsed : 36
# Frames Per Second : 34 || Percentage Parsed : 36
# Frames Per Second : 33 || Percentage Parsed : 36
# Frames Per Second : 33 || Percentage Parsed : 36
# Frames Per Second : 34 || Percentage Parsed : 36
# Frames Per Second : 33 || Percentage Parsed : 36
# Frames Per Second : 33 || Percentage Parsed : 36
# Frames Per Second : 33 || Percentage Parsed : 36
# Frames Per Second : 32 || Percentage Parsed : 36
# Frames Per Second : 31 || Percentage Parsed : 37
# Frames Per Second : 33 || Percentage Parsed : 37
# Frames Per Second : 33 || Percentage Parsed : 37
# Frames Per Second : 33 || Percentage Parsed : 37
# Frames Per Second : 34 || Percentage Parsed : 37
# Frames Per Second : 34 || Percentage Parsed : 37
# Frames Per Second : 33 || Percentage Parsed : 37
# Frames Per Second : 32 || Percentage Parsed : 37
# Frames Per Second : 33 || Percentage Parsed : 37
# Frames Per Second : 32 || Percentage Parsed : 37
# Frames Per Second : 32 || Percentage Parsed : 37
# Frames Per Second : 32 || Percentage Parsed : 37
# Frames Per Second : 33 || Percentage Parsed : 37
# Frames Per Second : 33 || Percentage Parsed : 37
# Frames Per Second : 33 || Percentage Parsed : 38
# Frames Per Second : 32 || Percentage Parsed : 38
# Frames Per Second : 33 || Percentage Parsed : 38
# Frames Per Second : 33 || Percentage Parsed : 38
# Frames Per Second : 34 || Percentage Parsed : 38
# Frames Per Second : 34 || Percentage Parsed : 38
# Frames Per Second : 33 || Percentage Parsed : 38
# Frames Per Second : 34 || Percentage Parsed : 38
# Frames Per Second : 33 || Percentage Parsed : 38
# Frames Per Second : 33 || Percentage Parsed : 38
# Frames Per Second : 34 || Percentage Parsed : 38
# Frames Per Second : 34 || Percentage Parsed : 38
# Frames Per Second : 34 || Percentage Parsed : 38
# Frames Per Second : 33 || Percentage Parsed : 38
# Frames Per Second : 33 || Percentage Parsed : 38
# Frames Per Second : 33 || Percentage Parsed : 39
# Frames Per Second : 32 || Percentage Parsed : 39
# Frames Per Second : 32 || Percentage Parsed : 39
# Frames Per Second : 32 || Percentage Parsed : 39
# Frames Per Second : 33 || Percentage Parsed : 39
# Frames Per Second : 33 || Percentage Parsed : 39
# Frames Per Second : 32 || Percentage Parsed : 39
# Frames Per Second : 32 || Percentage Parsed : 39
# Frames Per Second : 32 || Percentage Parsed : 39
# Frames Per Second : 33 || Percentage Parsed : 39
# Frames Per Second : 33 || Percentage Parsed : 39
# Frames Per Second : 33 || Percentage Parsed : 39
# Frames Per Second : 33 || Percentage Parsed : 39
# Frames Per Second : 33 || Percentage Parsed : 39
# Frames Per Second : 33 || Percentage Parsed : 40
# Frames Per Second : 33 || Percentage Parsed : 40
# Frames Per Second : 33 || Percentage Parsed : 40
# Frames Per Second : 32 || Percentage Parsed : 40
# Frames Per Second : 32 || Percentage Parsed : 40
# Frames Per Second : 33 || Percentage Parsed : 40
# Frames Per Second : 32 || Percentage Parsed : 40
# Frames Per Second : 32 || Percentage Parsed : 40
# Frames Per Second : 32 || Percentage Parsed : 40
# Frames Per Second : 32 || Percentage Parsed : 40
# Frames Per Second : 33 || Percentage Parsed : 40
# Frames Per Second : 33 || Percentage Parsed : 40
# Frames Per Second : 32 || Percentage Parsed : 40
# Frames Per Second : 32 || Percentage Parsed : 40
# Frames Per Second : 31 || Percentage Parsed : 41
# Frames Per Second : 32 || Percentage Parsed : 41
# Frames Per Second : 33 || Percentage Parsed : 41
# Frames Per Second : 32 || Percentage Parsed : 41
# Frames Per Second : 32 || Percentage Parsed : 41
# Frames Per Second : 32 || Percentage Parsed : 41
# Frames Per Second : 32 || Percentage Parsed : 41
# Frames Per Second : 32 || Percentage Parsed : 41
# Frames Per Second : 32 || Percentage Parsed : 41
# Frames Per Second : 32 || Percentage Parsed : 41
# Frames Per Second : 33 || Percentage Parsed : 41
# Frames Per Second : 34 || Percentage Parsed : 41
# Frames Per Second : 34 || Percentage Parsed : 41
# Frames Per Second : 35 || Percentage Parsed : 41
# Frames Per Second : 34 || Percentage Parsed : 42
# Frames Per Second : 34 || Percentage Parsed : 42
# Frames Per Second : 33 || Percentage Parsed : 42
# Frames Per Second : 32 || Percentage Parsed : 42
# Frames Per Second : 34 || Percentage Parsed : 42
# Frames Per Second : 33 || Percentage Parsed : 42
# Frames Per Second : 33 || Percentage Parsed : 42
# Frames Per Second : 32 || Percentage Parsed : 42
# Frames Per Second : 32 || Percentage Parsed : 42
# Frames Per Second : 32 || Percentage Parsed : 42
# Frames Per Second : 33 || Percentage Parsed : 42
# Frames Per Second : 33 || Percentage Parsed : 42
# Frames Per Second : 33 || Percentage Parsed : 42
# Frames Per Second : 32 || Percentage Parsed : 42
# Frames Per Second : 32 || Percentage Parsed : 43
# Frames Per Second : 33 || Percentage Parsed : 43
# Frames Per Second : 33 || Percentage Parsed : 43
# Frames Per Second : 33 || Percentage Parsed : 43
# Frames Per Second : 33 || Percentage Parsed : 43
# Frames Per Second : 33 || Percentage Parsed : 43
# Frames Per Second : 33 || Percentage Parsed : 43
# Frames Per Second : 33 || Percentage Parsed : 43
# Frames Per Second : 32 || Percentage Parsed : 43
# Frames Per Second : 30 || Percentage Parsed : 43
# Frames Per Second : 31 || Percentage Parsed : 43
# Frames Per Second : 31 || Percentage Parsed : 43
# Frames Per Second : 31 || Percentage Parsed : 43
# Frames Per Second : 33 || Percentage Parsed : 43
# Frames Per Second : 33 || Percentage Parsed : 43
# Frames Per Second : 35 || Percentage Parsed : 44
# Frames Per Second : 36 || Percentage Parsed : 44
# Frames Per Second : 35 || Percentage Parsed : 44
# Frames Per Second : 34 || Percentage Parsed : 44
# Frames Per Second : 34 || Percentage Parsed : 44
# Frames Per Second : 34 || Percentage Parsed : 44
# Frames Per Second : 35 || Percentage Parsed : 44
# Frames Per Second : 32 || Percentage Parsed : 44
# Frames Per Second : 32 || Percentage Parsed : 44
# Frames Per Second : 33 || Percentage Parsed : 44
# Frames Per Second : 33 || Percentage Parsed : 44
# Frames Per Second : 34 || Percentage Parsed : 44
# Frames Per Second : 34 || Percentage Parsed : 44
# Frames Per Second : 34 || Percentage Parsed : 44
# Frames Per Second : 35 || Percentage Parsed : 45
# Frames Per Second : 35 || Percentage Parsed : 45
# Frames Per Second : 35 || Percentage Parsed : 45
# Frames Per Second : 33 || Percentage Parsed : 45
# Frames Per Second : 33 || Percentage Parsed : 45
# Frames Per Second : 32 || Percentage Parsed : 45
# Frames Per Second : 32 || Percentage Parsed : 45
# Frames Per Second : 31 || Percentage Parsed : 45
# Frames Per Second : 33 || Percentage Parsed : 45
# Frames Per Second : 34 || Percentage Parsed : 45
# Frames Per Second : 34 || Percentage Parsed : 45
# Frames Per Second : 32 || Percentage Parsed : 45
# Frames Per Second : 33 || Percentage Parsed : 45
# Frames Per Second : 33 || Percentage Parsed : 45
# Frames Per Second : 35 || Percentage Parsed : 46
# Frames Per Second : 35 || Percentage Parsed : 46
# Frames Per Second : 34 || Percentage Parsed : 46
# Frames Per Second : 34 || Percentage Parsed : 46
# Frames Per Second : 34 || Percentage Parsed : 46
# Frames Per Second : 33 || Percentage Parsed : 46
# Frames Per Second : 34 || Percentage Parsed : 46
# Frames Per Second : 33 || Percentage Parsed : 46
# Frames Per Second : 34 || Percentage Parsed : 46
# Frames Per Second : 34 || Percentage Parsed : 46
# Frames Per Second : 34 || Percentage Parsed : 46
# Frames Per Second : 34 || Percentage Parsed : 46
# Frames Per Second : 33 || Percentage Parsed : 46
# Frames Per Second : 34 || Percentage Parsed : 46
# Frames Per Second : 33 || Percentage Parsed : 47
# Frames Per Second : 33 || Percentage Parsed : 47
# Frames Per Second : 34 || Percentage Parsed : 47
# Frames Per Second : 35 || Percentage Parsed : 47
# Frames Per Second : 35 || Percentage Parsed : 47
# Frames Per Second : 35 || Percentage Parsed : 47
# Frames Per Second : 35 || Percentage Parsed : 47
# Frames Per Second : 35 || Percentage Parsed : 47
# Frames Per Second : 34 || Percentage Parsed : 47
# Frames Per Second : 33 || Percentage Parsed : 47
# Frames Per Second : 34 || Percentage Parsed : 47
# Frames Per Second : 34 || Percentage Parsed : 47
# Frames Per Second : 33 || Percentage Parsed : 47
# Frames Per Second : 33 || Percentage Parsed : 47
# Frames Per Second : 33 || Percentage Parsed : 48
# Frames Per Second : 33 || Percentage Parsed : 48
# Frames Per Second : 34 || Percentage Parsed : 48
# Frames Per Second : 35 || Percentage Parsed : 48
# Frames Per Second : 35 || Percentage Parsed : 48
# Frames Per Second : 35 || Percentage Parsed : 48
# Frames Per Second : 35 || Percentage Parsed : 48
# Frames Per Second : 34 || Percentage Parsed : 48
# Frames Per Second : 35 || Percentage Parsed : 48
# Frames Per Second : 35 || Percentage Parsed : 48
# Frames Per Second : 32 || Percentage Parsed : 48
# Frames Per Second : 32 || Percentage Parsed : 48
# Frames Per Second : 33 || Percentage Parsed : 48
# Frames Per Second : 33 || Percentage Parsed : 48
# Frames Per Second : 33 || Percentage Parsed : 49
# Frames Per Second : 33 || Percentage Parsed : 49
# Frames Per Second : 33 || Percentage Parsed : 49
# Frames Per Second : 34 || Percentage Parsed : 49
# Frames Per Second : 34 || Percentage Parsed : 49
# Frames Per Second : 35 || Percentage Parsed : 49
# Frames Per Second : 34 || Percentage Parsed : 49
# Frames Per Second : 33 || Percentage Parsed : 49
# Frames Per Second : 34 || Percentage Parsed : 49
# Frames Per Second : 33 || Percentage Parsed : 49
# Frames Per Second : 34 || Percentage Parsed : 49
# Frames Per Second : 34 || Percentage Parsed : 49
# Frames Per Second : 34 || Percentage Parsed : 49
# Frames Per Second : 34 || Percentage Parsed : 49
# Frames Per Second : 34 || Percentage Parsed : 49
# Frames Per Second : 35 || Percentage Parsed : 50
# Frames Per Second : 35 || Percentage Parsed : 50
# Frames Per Second : 34 || Percentage Parsed : 50
# Frames Per Second : 35 || Percentage Parsed : 50
# Frames Per Second : 34 || Percentage Parsed : 50
# Frames Per Second : 35 || Percentage Parsed : 50
# Frames Per Second : 36 || Percentage Parsed : 50
# Frames Per Second : 35 || Percentage Parsed : 50
# Frames Per Second : 35 || Percentage Parsed : 50
# Frames Per Second : 35 || Percentage Parsed : 50
# Frames Per Second : 36 || Percentage Parsed : 50
# Frames Per Second : 35 || Percentage Parsed : 50
# Frames Per Second : 35 || Percentage Parsed : 50
# Frames Per Second : 34 || Percentage Parsed : 50
# Frames Per Second : 34 || Percentage Parsed : 51
# Frames Per Second : 34 || Percentage Parsed : 51
# Frames Per Second : 34 || Percentage Parsed : 51
# Frames Per Second : 34 || Percentage Parsed : 51
# Frames Per Second : 34 || Percentage Parsed : 51
# Frames Per Second : 34 || Percentage Parsed : 51
# Frames Per Second : 34 || Percentage Parsed : 51
# Frames Per Second : 34 || Percentage Parsed : 51
# Frames Per Second : 33 || Percentage Parsed : 51
# Frames Per Second : 33 || Percentage Parsed : 51
# Frames Per Second : 33 || Percentage Parsed : 51
# Frames Per Second : 34 || Percentage Parsed : 51
# Frames Per Second : 34 || Percentage Parsed : 51
# Frames Per Second : 33 || Percentage Parsed : 51
# Frames Per Second : 34 || Percentage Parsed : 52
# Frames Per Second : 33 || Percentage Parsed : 52
# Frames Per Second : 33 || Percentage Parsed : 52
# Frames Per Second : 34 || Percentage Parsed : 52
# Frames Per Second : 34 || Percentage Parsed : 52
# Frames Per Second : 34 || Percentage Parsed : 52
# Frames Per Second : 34 || Percentage Parsed : 52
# Frames Per Second : 34 || Percentage Parsed : 52
# Frames Per Second : 34 || Percentage Parsed : 52
# Frames Per Second : 33 || Percentage Parsed : 52
# Frames Per Second : 33 || Percentage Parsed : 52
# Frames Per Second : 33 || Percentage Parsed : 52
# Frames Per Second : 33 || Percentage Parsed : 52
# Frames Per Second : 33 || Percentage Parsed : 52
# Frames Per Second : 33 || Percentage Parsed : 53
# Frames Per Second : 34 || Percentage Parsed : 53
# Frames Per Second : 33 || Percentage Parsed : 53
# Frames Per Second : 33 || Percentage Parsed : 53
# Frames Per Second : 33 || Percentage Parsed : 53
# Frames Per Second : 33 || Percentage Parsed : 53
# Frames Per Second : 34 || Percentage Parsed : 53
# Frames Per Second : 34 || Percentage Parsed : 53
# Frames Per Second : 33 || Percentage Parsed : 53
# Frames Per Second : 33 || Percentage Parsed : 53
# Frames Per Second : 33 || Percentage Parsed : 53
# Frames Per Second : 34 || Percentage Parsed : 53
# Frames Per Second : 33 || Percentage Parsed : 53
# Frames Per Second : 33 || Percentage Parsed : 53
# Frames Per Second : 33 || Percentage Parsed : 54
# Frames Per Second : 33 || Percentage Parsed : 54
# Frames Per Second : 33 || Percentage Parsed : 54
# Frames Per Second : 33 || Percentage Parsed : 54
# Frames Per Second : 32 || Percentage Parsed : 54
# Frames Per Second : 33 || Percentage Parsed : 54
# Frames Per Second : 32 || Percentage Parsed : 54
# Frames Per Second : 33 || Percentage Parsed : 54
# Frames Per Second : 33 || Percentage Parsed : 54
# Frames Per Second : 34 || Percentage Parsed : 54
# Frames Per Second : 34 || Percentage Parsed : 54
# Frames Per Second : 34 || Percentage Parsed : 54
# Frames Per Second : 34 || Percentage Parsed : 54
# Frames Per Second : 35 || Percentage Parsed : 54
# Frames Per Second : 33 || Percentage Parsed : 54
# Frames Per Second : 34 || Percentage Parsed : 55
# Frames Per Second : 34 || Percentage Parsed : 55
# Frames Per Second : 33 || Percentage Parsed : 55
# Frames Per Second : 34 || Percentage Parsed : 55
# Frames Per Second : 34 || Percentage Parsed : 55
# Frames Per Second : 34 || Percentage Parsed : 55
# Frames Per Second : 34 || Percentage Parsed : 55
# Frames Per Second : 34 || Percentage Parsed : 55
# Frames Per Second : 34 || Percentage Parsed : 55
# Frames Per Second : 34 || Percentage Parsed : 55
# Frames Per Second : 34 || Percentage Parsed : 55
# Frames Per Second : 33 || Percentage Parsed : 55
# Frames Per Second : 33 || Percentage Parsed : 55
# Frames Per Second : 33 || Percentage Parsed : 55
# Frames Per Second : 33 || Percentage Parsed : 56
# Frames Per Second : 33 || Percentage Parsed : 56
# Frames Per Second : 33 || Percentage Parsed : 56
# Frames Per Second : 33 || Percentage Parsed : 56
# Frames Per Second : 33 || Percentage Parsed : 56
# Frames Per Second : 33 || Percentage Parsed : 56
# Frames Per Second : 33 || Percentage Parsed : 56
# Frames Per Second : 33 || Percentage Parsed : 56
# Frames Per Second : 33 || Percentage Parsed : 56
# Frames Per Second : 33 || Percentage Parsed : 56
# Frames Per Second : 34 || Percentage Parsed : 56
# Frames Per Second : 33 || Percentage Parsed : 56
# Frames Per Second : 33 || Percentage Parsed : 56
# Frames Per Second : 34 || Percentage Parsed : 56
# Frames Per Second : 35 || Percentage Parsed : 57
# Frames Per Second : 34 || Percentage Parsed : 57
# Frames Per Second : 33 || Percentage Parsed : 57
# Frames Per Second : 33 || Percentage Parsed : 57
# Frames Per Second : 33 || Percentage Parsed : 57
# Frames Per Second : 33 || Percentage Parsed : 57
# Frames Per Second : 32 || Percentage Parsed : 57
# Frames Per Second : 33 || Percentage Parsed : 57
# Frames Per Second : 33 || Percentage Parsed : 57
# Frames Per Second : 33 || Percentage Parsed : 57
# Frames Per Second : 33 || Percentage Parsed : 57
# Frames Per Second : 33 || Percentage Parsed : 57
# Frames Per Second : 33 || Percentage Parsed : 57
# Frames Per Second : 33 || Percentage Parsed : 57
# Frames Per Second : 34 || Percentage Parsed : 58
# Frames Per Second : 33 || Percentage Parsed : 58
# Frames Per Second : 32 || Percentage Parsed : 58
# Frames Per Second : 32 || Percentage Parsed : 58
# Frames Per Second : 32 || Percentage Parsed : 58
# Frames Per Second : 33 || Percentage Parsed : 58
# Frames Per Second : 33 || Percentage Parsed : 58
# Frames Per Second : 33 || Percentage Parsed : 58
# Frames Per Second : 33 || Percentage Parsed : 58
# Frames Per Second : 33 || Percentage Parsed : 58
# Frames Per Second : 33 || Percentage Parsed : 58
# Frames Per Second : 33 || Percentage Parsed : 58
# Frames Per Second : 33 || Percentage Parsed : 58
# Frames Per Second : 33 || Percentage Parsed : 58
# Frames Per Second : 33 || Percentage Parsed : 59
# Frames Per Second : 33 || Percentage Parsed : 59
# Frames Per Second : 32 || Percentage Parsed : 59
# Frames Per Second : 32 || Percentage Parsed : 59
# Frames Per Second : 32 || Percentage Parsed : 59
# Frames Per Second : 32 || Percentage Parsed : 59
# Frames Per Second : 33 || Percentage Parsed : 59
# Frames Per Second : 34 || Percentage Parsed : 59
# Frames Per Second : 33 || Percentage Parsed : 59
# Frames Per Second : 33 || Percentage Parsed : 59
# Frames Per Second : 32 || Percentage Parsed : 59
# Frames Per Second : 32 || Percentage Parsed : 59
# Frames Per Second : 33 || Percentage Parsed : 59
# Frames Per Second : 33 || Percentage Parsed : 59
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 33 || Percentage Parsed : 60
# Frames Per Second : 33 || Percentage Parsed : 60
# Frames Per Second : 33 || Percentage Parsed : 60
# Frames Per Second : 33 || Percentage Parsed : 60
# Frames Per Second : 33 || Percentage Parsed : 60
# Frames Per Second : 33 || Percentage Parsed : 61
# Frames Per Second : 33 || Percentage Parsed : 61
# Frames Per Second : 33 || Percentage Parsed : 61
# Frames Per Second : 33 || Percentage Parsed : 61
# Frames Per Second : 33 || Percentage Parsed : 61
# Frames Per Second : 32 || Percentage Parsed : 61
# Frames Per Second : 32 || Percentage Parsed : 61
# Frames Per Second : 32 || Percentage Parsed : 61
# Frames Per Second : 32 || Percentage Parsed : 61
# Frames Per Second : 33 || Percentage Parsed : 61
# Frames Per Second : 33 || Percentage Parsed : 61
# Frames Per Second : 33 || Percentage Parsed : 61
# Frames Per Second : 33 || Percentage Parsed : 61
# Frames Per Second : 32 || Percentage Parsed : 61
# Frames Per Second : 32 || Percentage Parsed : 62
# Frames Per Second : 33 || Percentage Parsed : 62
# Frames Per Second : 33 || Percentage Parsed : 62
# Frames Per Second : 33 || Percentage Parsed : 62
# Frames Per Second : 32 || Percentage Parsed : 62
# Frames Per Second : 33 || Percentage Parsed : 62
# Frames Per Second : 33 || Percentage Parsed : 62
# Frames Per Second : 33 || Percentage Parsed : 62
# Frames Per Second : 33 || Percentage Parsed : 62
# Frames Per Second : 32 || Percentage Parsed : 62
# Frames Per Second : 32 || Percentage Parsed : 62
# Frames Per Second : 33 || Percentage Parsed : 62
# Frames Per Second : 33 || Percentage Parsed : 62
# Frames Per Second : 33 || Percentage Parsed : 62
# Frames Per Second : 33 || Percentage Parsed : 63
# Frames Per Second : 32 || Percentage Parsed : 63
# Frames Per Second : 33 || Percentage Parsed : 63
# Frames Per Second : 33 || Percentage Parsed : 63
# Frames Per Second : 32 || Percentage Parsed : 63
# Frames Per Second : 32 || Percentage Parsed : 63
# Frames Per Second : 33 || Percentage Parsed : 63
# Frames Per Second : 33 || Percentage Parsed : 63
# Frames Per Second : 32 || Percentage Parsed : 63
# Frames Per Second : 32 || Percentage Parsed : 63
# Frames Per Second : 32 || Percentage Parsed : 63
# Frames Per Second : 32 || Percentage Parsed : 63
# Frames Per Second : 33 || Percentage Parsed : 63
# Frames Per Second : 33 || Percentage Parsed : 63
# Frames Per Second : 33 || Percentage Parsed : 64
# Frames Per Second : 33 || Percentage Parsed : 64
# Frames Per Second : 31 || Percentage Parsed : 64
# Frames Per Second : 32 || Percentage Parsed : 64
# Frames Per Second : 32 || Percentage Parsed : 64
# Frames Per Second : 33 || Percentage Parsed : 64
# Frames Per Second : 33 || Percentage Parsed : 64
# Frames Per Second : 33 || Percentage Parsed : 64
# Frames Per Second : 33 || Percentage Parsed : 64
# Frames Per Second : 32 || Percentage Parsed : 64
# Frames Per Second : 32 || Percentage Parsed : 64
# Frames Per Second : 32 || Percentage Parsed : 64
# Frames Per Second : 32 || Percentage Parsed : 64
# Frames Per Second : 33 || Percentage Parsed : 64
# Frames Per Second : 32 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 34 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 34 || Percentage Parsed : 65
# Frames Per Second : 34 || Percentage Parsed : 65
# Frames Per Second : 32 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 66
# Frames Per Second : 32 || Percentage Parsed : 66
# Frames Per Second : 33 || Percentage Parsed : 66
# Frames Per Second : 32 || Percentage Parsed : 66
# Frames Per Second : 32 || Percentage Parsed : 66
# Frames Per Second : 33 || Percentage Parsed : 66
# Frames Per Second : 33 || Percentage Parsed : 66
# Frames Per Second : 33 || Percentage Parsed : 66
# Frames Per Second : 33 || Percentage Parsed : 66
# Frames Per Second : 33 || Percentage Parsed : 66
# Frames Per Second : 33 || Percentage Parsed : 66
# Frames Per Second : 33 || Percentage Parsed : 66
# Frames Per Second : 32 || Percentage Parsed : 66
# Frames Per Second : 32 || Percentage Parsed : 66

# %% [markdown]
# Salvamos el video resultante del proceso en nuestro Drive:

# %%
# Input video path
save_path = "/content/fuerzas_armadas_ssd300_augmented.mp4"

# Compressed video path
compressed_path = "/content/fuerzas_armadas_ssd300_augmented_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")
# Out:
# 0

# %%
shutil.copy(
    "/content/fuerzas_armadas_ssd300_augmented_compressed.mp4",
    "/content/drive/MyDrive/tfg/fuerzas_armadas_ssd300_augmented_compressed.mp4"
)
# Out:
# '/content/drive/MyDrive/tfg/fuerzas_armadas_ssd300_augmented_compressed.mp4'

# %% [markdown]
# ## SSD300 con Data Augmentation y Datos de Humanos

# %%
model = get_model(12)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=SSD300_VGG16_Weights.COCO_V1`. You can also use `weights=SSD300_VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
checkpoint = torch.load("/content/drive/MyDrive/tfg/models/ssd300_augmented_humans.pth", weights_only=False)
model.load_state_dict(checkpoint["best_model"]["model_state_dict"])
# Out:
# <All keys matched successfully>

# %%
ssd300_rtod = VideoParserObjectDetectionModel(model, SSD_FNS, CLASS_INFO)

# %%
ssd300_rtod(URL, "fuerzas_armadas_ssd300_augmented_humans.mp4")
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=xV24-uVq3WY
# [youtube] xV24-uVq3WY: Downloading webpage
# [youtube] xV24-uVq3WY: Downloading tv client config
# [youtube] xV24-uVq3WY: Downloading player 4fcd6e4a
# [youtube] xV24-uVq3WY: Downloading tv player API JSON
# [youtube] xV24-uVq3WY: Downloading ios player API JSON
# [youtube] xV24-uVq3WY: Downloading m3u8 information
# Frames Per Second : 29 || Percentage Parsed : 0
# Frames Per Second : 32 || Percentage Parsed : 0
# Frames Per Second : 33 || Percentage Parsed : 0
# Frames Per Second : 32 || Percentage Parsed : 0
# Frames Per Second : 32 || Percentage Parsed : 0
# Frames Per Second : 32 || Percentage Parsed : 0
# Frames Per Second : 32 || Percentage Parsed : 0
# Frames Per Second : 31 || Percentage Parsed : 0
# Frames Per Second : 32 || Percentage Parsed : 0
# Frames Per Second : 31 || Percentage Parsed : 0
# Frames Per Second : 31 || Percentage Parsed : 0
# Frames Per Second : 31 || Percentage Parsed : 0
# Frames Per Second : 31 || Percentage Parsed : 0
# Frames Per Second : 31 || Percentage Parsed : 0
# Frames Per Second : 32 || Percentage Parsed : 1
# Frames Per Second : 31 || Percentage Parsed : 1
# Frames Per Second : 32 || Percentage Parsed : 1
# Frames Per Second : 32 || Percentage Parsed : 1
# Frames Per Second : 29 || Percentage Parsed : 1
# Frames Per Second : 32 || Percentage Parsed : 1
# Frames Per Second : 32 || Percentage Parsed : 1
# Frames Per Second : 32 || Percentage Parsed : 1
# Frames Per Second : 32 || Percentage Parsed : 1
# Frames Per Second : 32 || Percentage Parsed : 1
# Frames Per Second : 33 || Percentage Parsed : 1
# Frames Per Second : 32 || Percentage Parsed : 1
# Frames Per Second : 32 || Percentage Parsed : 1
# Frames Per Second : 31 || Percentage Parsed : 1
# Frames Per Second : 32 || Percentage Parsed : 2
# Frames Per Second : 32 || Percentage Parsed : 2
# Frames Per Second : 31 || Percentage Parsed : 2
# Frames Per Second : 33 || Percentage Parsed : 2
# Frames Per Second : 33 || Percentage Parsed : 2
# Frames Per Second : 32 || Percentage Parsed : 2
# Frames Per Second : 31 || Percentage Parsed : 2
# Frames Per Second : 32 || Percentage Parsed : 2
# Frames Per Second : 33 || Percentage Parsed : 2
# Frames Per Second : 33 || Percentage Parsed : 2
# Frames Per Second : 33 || Percentage Parsed : 2
# Frames Per Second : 33 || Percentage Parsed : 2
# Frames Per Second : 33 || Percentage Parsed : 2
# Frames Per Second : 33 || Percentage Parsed : 2
# Frames Per Second : 32 || Percentage Parsed : 3
# Frames Per Second : 32 || Percentage Parsed : 3
# Frames Per Second : 32 || Percentage Parsed : 3
# Frames Per Second : 32 || Percentage Parsed : 3
# Frames Per Second : 32 || Percentage Parsed : 3
# Frames Per Second : 33 || Percentage Parsed : 3
# Frames Per Second : 33 || Percentage Parsed : 3
# Frames Per Second : 32 || Percentage Parsed : 3
# Frames Per Second : 32 || Percentage Parsed : 3
# Frames Per Second : 32 || Percentage Parsed : 3
# Frames Per Second : 33 || Percentage Parsed : 3
# Frames Per Second : 32 || Percentage Parsed : 3
# Frames Per Second : 31 || Percentage Parsed : 3
# Frames Per Second : 32 || Percentage Parsed : 3
# Frames Per Second : 33 || Percentage Parsed : 4
# Frames Per Second : 33 || Percentage Parsed : 4
# Frames Per Second : 33 || Percentage Parsed : 4
# Frames Per Second : 33 || Percentage Parsed : 4
# Frames Per Second : 33 || Percentage Parsed : 4
# Frames Per Second : 33 || Percentage Parsed : 4
# Frames Per Second : 32 || Percentage Parsed : 4
# Frames Per Second : 32 || Percentage Parsed : 4
# Frames Per Second : 32 || Percentage Parsed : 4
# Frames Per Second : 32 || Percentage Parsed : 4
# Frames Per Second : 32 || Percentage Parsed : 4
# Frames Per Second : 33 || Percentage Parsed : 4
# Frames Per Second : 32 || Percentage Parsed : 4
# Frames Per Second : 31 || Percentage Parsed : 4
# Frames Per Second : 31 || Percentage Parsed : 5
# Frames Per Second : 31 || Percentage Parsed : 5
# Frames Per Second : 32 || Percentage Parsed : 5
# Frames Per Second : 33 || Percentage Parsed : 5
# Frames Per Second : 32 || Percentage Parsed : 5
# Frames Per Second : 32 || Percentage Parsed : 5
# Frames Per Second : 33 || Percentage Parsed : 5
# Frames Per Second : 33 || Percentage Parsed : 5
# Frames Per Second : 32 || Percentage Parsed : 5
# Frames Per Second : 32 || Percentage Parsed : 5
# Frames Per Second : 32 || Percentage Parsed : 5
# Frames Per Second : 32 || Percentage Parsed : 5
# Frames Per Second : 32 || Percentage Parsed : 5
# Frames Per Second : 32 || Percentage Parsed : 5
# Frames Per Second : 32 || Percentage Parsed : 5
# Frames Per Second : 32 || Percentage Parsed : 6
# Frames Per Second : 32 || Percentage Parsed : 6
# Frames Per Second : 32 || Percentage Parsed : 6
# Frames Per Second : 32 || Percentage Parsed : 6
# Frames Per Second : 32 || Percentage Parsed : 6
# Frames Per Second : 31 || Percentage Parsed : 6
# Frames Per Second : 32 || Percentage Parsed : 6
# Frames Per Second : 32 || Percentage Parsed : 6
# Frames Per Second : 32 || Percentage Parsed : 6
# Frames Per Second : 31 || Percentage Parsed : 6
# Frames Per Second : 31 || Percentage Parsed : 6
# Frames Per Second : 32 || Percentage Parsed : 6
# Frames Per Second : 32 || Percentage Parsed : 6
# Frames Per Second : 33 || Percentage Parsed : 6
# Frames Per Second : 32 || Percentage Parsed : 7
# Frames Per Second : 32 || Percentage Parsed : 7
# Frames Per Second : 32 || Percentage Parsed : 7
# Frames Per Second : 33 || Percentage Parsed : 7
# Frames Per Second : 33 || Percentage Parsed : 7
# Frames Per Second : 32 || Percentage Parsed : 7
# Frames Per Second : 32 || Percentage Parsed : 7
# Frames Per Second : 32 || Percentage Parsed : 7
# Frames Per Second : 32 || Percentage Parsed : 7
# Frames Per Second : 32 || Percentage Parsed : 7
# Frames Per Second : 32 || Percentage Parsed : 7
# Frames Per Second : 31 || Percentage Parsed : 7
# Frames Per Second : 31 || Percentage Parsed : 7
# Frames Per Second : 31 || Percentage Parsed : 7
# Frames Per Second : 32 || Percentage Parsed : 8
# Frames Per Second : 33 || Percentage Parsed : 8
# Frames Per Second : 33 || Percentage Parsed : 8
# Frames Per Second : 33 || Percentage Parsed : 8
# Frames Per Second : 33 || Percentage Parsed : 8
# Frames Per Second : 32 || Percentage Parsed : 8
# Frames Per Second : 32 || Percentage Parsed : 8
# Frames Per Second : 33 || Percentage Parsed : 8
# Frames Per Second : 32 || Percentage Parsed : 8
# Frames Per Second : 33 || Percentage Parsed : 8
# Frames Per Second : 33 || Percentage Parsed : 8
# Frames Per Second : 33 || Percentage Parsed : 8
# Frames Per Second : 33 || Percentage Parsed : 8
# Frames Per Second : 32 || Percentage Parsed : 8
# Frames Per Second : 32 || Percentage Parsed : 9
# Frames Per Second : 33 || Percentage Parsed : 9
# Frames Per Second : 32 || Percentage Parsed : 9
# Frames Per Second : 33 || Percentage Parsed : 9
# Frames Per Second : 33 || Percentage Parsed : 9
# Frames Per Second : 33 || Percentage Parsed : 9
# Frames Per Second : 33 || Percentage Parsed : 9
# Frames Per Second : 33 || Percentage Parsed : 9
# Frames Per Second : 32 || Percentage Parsed : 9
# Frames Per Second : 33 || Percentage Parsed : 9
# Frames Per Second : 34 || Percentage Parsed : 9
# Frames Per Second : 34 || Percentage Parsed : 9
# Frames Per Second : 32 || Percentage Parsed : 9
# Frames Per Second : 33 || Percentage Parsed : 9
# Frames Per Second : 32 || Percentage Parsed : 10
# Frames Per Second : 31 || Percentage Parsed : 10
# Frames Per Second : 32 || Percentage Parsed : 10
# Frames Per Second : 31 || Percentage Parsed : 10
# Frames Per Second : 32 || Percentage Parsed : 10
# Frames Per Second : 33 || Percentage Parsed : 10
# Frames Per Second : 33 || Percentage Parsed : 10
# Frames Per Second : 33 || Percentage Parsed : 10
# Frames Per Second : 33 || Percentage Parsed : 10
# Frames Per Second : 33 || Percentage Parsed : 10
# Frames Per Second : 32 || Percentage Parsed : 10
# Frames Per Second : 32 || Percentage Parsed : 10
# Frames Per Second : 32 || Percentage Parsed : 10
# Frames Per Second : 31 || Percentage Parsed : 10
# Frames Per Second : 32 || Percentage Parsed : 10
# Frames Per Second : 32 || Percentage Parsed : 11
# Frames Per Second : 32 || Percentage Parsed : 11
# Frames Per Second : 31 || Percentage Parsed : 11
# Frames Per Second : 31 || Percentage Parsed : 11
# Frames Per Second : 32 || Percentage Parsed : 11
# Frames Per Second : 32 || Percentage Parsed : 11
# Frames Per Second : 32 || Percentage Parsed : 11
# Frames Per Second : 32 || Percentage Parsed : 11
# Frames Per Second : 33 || Percentage Parsed : 11
# Frames Per Second : 33 || Percentage Parsed : 11
# Frames Per Second : 32 || Percentage Parsed : 11
# Frames Per Second : 33 || Percentage Parsed : 11
# Frames Per Second : 33 || Percentage Parsed : 11
# Frames Per Second : 33 || Percentage Parsed : 11
# Frames Per Second : 32 || Percentage Parsed : 12
# Frames Per Second : 33 || Percentage Parsed : 12
# Frames Per Second : 32 || Percentage Parsed : 12
# Frames Per Second : 33 || Percentage Parsed : 12
# Frames Per Second : 32 || Percentage Parsed : 12
# Frames Per Second : 32 || Percentage Parsed : 12
# Frames Per Second : 33 || Percentage Parsed : 12
# Frames Per Second : 32 || Percentage Parsed : 12
# Frames Per Second : 32 || Percentage Parsed : 12
# Frames Per Second : 32 || Percentage Parsed : 12
# Frames Per Second : 32 || Percentage Parsed : 12
# Frames Per Second : 33 || Percentage Parsed : 12
# Frames Per Second : 33 || Percentage Parsed : 12
# Frames Per Second : 33 || Percentage Parsed : 12
# Frames Per Second : 33 || Percentage Parsed : 13
# Frames Per Second : 33 || Percentage Parsed : 13
# Frames Per Second : 33 || Percentage Parsed : 13
# Frames Per Second : 33 || Percentage Parsed : 13
# Frames Per Second : 33 || Percentage Parsed : 13
# Frames Per Second : 33 || Percentage Parsed : 13
# Frames Per Second : 33 || Percentage Parsed : 13
# Frames Per Second : 33 || Percentage Parsed : 13
# Frames Per Second : 33 || Percentage Parsed : 13
# Frames Per Second : 33 || Percentage Parsed : 13
# Frames Per Second : 33 || Percentage Parsed : 13
# Frames Per Second : 32 || Percentage Parsed : 13
# Frames Per Second : 32 || Percentage Parsed : 13
# Frames Per Second : 33 || Percentage Parsed : 13
# Frames Per Second : 33 || Percentage Parsed : 14
# Frames Per Second : 32 || Percentage Parsed : 14
# Frames Per Second : 33 || Percentage Parsed : 14
# Frames Per Second : 33 || Percentage Parsed : 14
# Frames Per Second : 33 || Percentage Parsed : 14
# Frames Per Second : 33 || Percentage Parsed : 14
# Frames Per Second : 32 || Percentage Parsed : 14
# Frames Per Second : 32 || Percentage Parsed : 14
# Frames Per Second : 34 || Percentage Parsed : 14
# Frames Per Second : 34 || Percentage Parsed : 14
# Frames Per Second : 34 || Percentage Parsed : 14
# Frames Per Second : 33 || Percentage Parsed : 14
# Frames Per Second : 33 || Percentage Parsed : 14
# Frames Per Second : 33 || Percentage Parsed : 14
# Frames Per Second : 33 || Percentage Parsed : 15
# Frames Per Second : 33 || Percentage Parsed : 15
# Frames Per Second : 33 || Percentage Parsed : 15
# Frames Per Second : 33 || Percentage Parsed : 15
# Frames Per Second : 33 || Percentage Parsed : 15
# Frames Per Second : 32 || Percentage Parsed : 15
# Frames Per Second : 32 || Percentage Parsed : 15
# Frames Per Second : 33 || Percentage Parsed : 15
# Frames Per Second : 32 || Percentage Parsed : 15
# Frames Per Second : 33 || Percentage Parsed : 15
# Frames Per Second : 33 || Percentage Parsed : 15
# Frames Per Second : 33 || Percentage Parsed : 15
# Frames Per Second : 32 || Percentage Parsed : 15
# Frames Per Second : 33 || Percentage Parsed : 15
# Frames Per Second : 33 || Percentage Parsed : 16
# Frames Per Second : 33 || Percentage Parsed : 16
# Frames Per Second : 33 || Percentage Parsed : 16
# Frames Per Second : 33 || Percentage Parsed : 16
# Frames Per Second : 34 || Percentage Parsed : 16
# Frames Per Second : 34 || Percentage Parsed : 16
# Frames Per Second : 33 || Percentage Parsed : 16
# Frames Per Second : 33 || Percentage Parsed : 16
# Frames Per Second : 33 || Percentage Parsed : 16
# Frames Per Second : 34 || Percentage Parsed : 16
# Frames Per Second : 33 || Percentage Parsed : 16
# Frames Per Second : 33 || Percentage Parsed : 16
# Frames Per Second : 33 || Percentage Parsed : 16
# Frames Per Second : 33 || Percentage Parsed : 16
# Frames Per Second : 33 || Percentage Parsed : 16
# Frames Per Second : 34 || Percentage Parsed : 17
# Frames Per Second : 33 || Percentage Parsed : 17
# Frames Per Second : 34 || Percentage Parsed : 17
# Frames Per Second : 34 || Percentage Parsed : 17
# Frames Per Second : 34 || Percentage Parsed : 17
# Frames Per Second : 34 || Percentage Parsed : 17
# Frames Per Second : 34 || Percentage Parsed : 17
# Frames Per Second : 34 || Percentage Parsed : 17
# Frames Per Second : 35 || Percentage Parsed : 17
# Frames Per Second : 33 || Percentage Parsed : 17
# Frames Per Second : 34 || Percentage Parsed : 17
# Frames Per Second : 34 || Percentage Parsed : 17
# Frames Per Second : 35 || Percentage Parsed : 17
# Frames Per Second : 35 || Percentage Parsed : 17
# Frames Per Second : 34 || Percentage Parsed : 18
# Frames Per Second : 34 || Percentage Parsed : 18
# Frames Per Second : 35 || Percentage Parsed : 18
# Frames Per Second : 34 || Percentage Parsed : 18
# Frames Per Second : 34 || Percentage Parsed : 18
# Frames Per Second : 34 || Percentage Parsed : 18
# Frames Per Second : 34 || Percentage Parsed : 18
# Frames Per Second : 34 || Percentage Parsed : 18
# Frames Per Second : 35 || Percentage Parsed : 18
# Frames Per Second : 35 || Percentage Parsed : 18
# Frames Per Second : 34 || Percentage Parsed : 18
# Frames Per Second : 35 || Percentage Parsed : 18
# Frames Per Second : 35 || Percentage Parsed : 18
# Frames Per Second : 33 || Percentage Parsed : 18
# Frames Per Second : 33 || Percentage Parsed : 19
# Frames Per Second : 33 || Percentage Parsed : 19
# Frames Per Second : 33 || Percentage Parsed : 19
# Frames Per Second : 33 || Percentage Parsed : 19
# Frames Per Second : 33 || Percentage Parsed : 19
# Frames Per Second : 33 || Percentage Parsed : 19
# Frames Per Second : 33 || Percentage Parsed : 19
# Frames Per Second : 32 || Percentage Parsed : 19
# Frames Per Second : 33 || Percentage Parsed : 19
# Frames Per Second : 35 || Percentage Parsed : 19
# Frames Per Second : 34 || Percentage Parsed : 19
# Frames Per Second : 35 || Percentage Parsed : 19
# Frames Per Second : 34 || Percentage Parsed : 19
# Frames Per Second : 34 || Percentage Parsed : 19
# Frames Per Second : 34 || Percentage Parsed : 20
# Frames Per Second : 33 || Percentage Parsed : 20
# Frames Per Second : 34 || Percentage Parsed : 20
# Frames Per Second : 34 || Percentage Parsed : 20
# Frames Per Second : 33 || Percentage Parsed : 20
# Frames Per Second : 34 || Percentage Parsed : 20
# Frames Per Second : 33 || Percentage Parsed : 20
# Frames Per Second : 33 || Percentage Parsed : 20
# Frames Per Second : 32 || Percentage Parsed : 20
# Frames Per Second : 33 || Percentage Parsed : 20
# Frames Per Second : 33 || Percentage Parsed : 20
# Frames Per Second : 32 || Percentage Parsed : 20
# Frames Per Second : 32 || Percentage Parsed : 20
# Frames Per Second : 33 || Percentage Parsed : 20
# Frames Per Second : 33 || Percentage Parsed : 21
# Frames Per Second : 33 || Percentage Parsed : 21
# Frames Per Second : 33 || Percentage Parsed : 21
# Frames Per Second : 33 || Percentage Parsed : 21
# Frames Per Second : 32 || Percentage Parsed : 21
# Frames Per Second : 32 || Percentage Parsed : 21
# Frames Per Second : 32 || Percentage Parsed : 21
# Frames Per Second : 32 || Percentage Parsed : 21
# Frames Per Second : 31 || Percentage Parsed : 21
# Frames Per Second : 32 || Percentage Parsed : 21
# Frames Per Second : 32 || Percentage Parsed : 21
# Frames Per Second : 32 || Percentage Parsed : 21
# Frames Per Second : 33 || Percentage Parsed : 21
# Frames Per Second : 33 || Percentage Parsed : 21
# Frames Per Second : 33 || Percentage Parsed : 21
# Frames Per Second : 33 || Percentage Parsed : 22
# Frames Per Second : 33 || Percentage Parsed : 22
# Frames Per Second : 33 || Percentage Parsed : 22
# Frames Per Second : 33 || Percentage Parsed : 22
# Frames Per Second : 32 || Percentage Parsed : 22
# Frames Per Second : 33 || Percentage Parsed : 22
# Frames Per Second : 33 || Percentage Parsed : 22
# Frames Per Second : 33 || Percentage Parsed : 22
# Frames Per Second : 33 || Percentage Parsed : 22
# Frames Per Second : 33 || Percentage Parsed : 22
# Frames Per Second : 33 || Percentage Parsed : 22
# Frames Per Second : 32 || Percentage Parsed : 22
# Frames Per Second : 32 || Percentage Parsed : 22
# Frames Per Second : 32 || Percentage Parsed : 22
# Frames Per Second : 32 || Percentage Parsed : 23
# Frames Per Second : 32 || Percentage Parsed : 23
# Frames Per Second : 32 || Percentage Parsed : 23
# Frames Per Second : 33 || Percentage Parsed : 23
# Frames Per Second : 33 || Percentage Parsed : 23
# Frames Per Second : 33 || Percentage Parsed : 23
# Frames Per Second : 32 || Percentage Parsed : 23
# Frames Per Second : 33 || Percentage Parsed : 23
# Frames Per Second : 33 || Percentage Parsed : 23
# Frames Per Second : 33 || Percentage Parsed : 23
# Frames Per Second : 33 || Percentage Parsed : 23
# Frames Per Second : 33 || Percentage Parsed : 23
# Frames Per Second : 33 || Percentage Parsed : 23
# Frames Per Second : 33 || Percentage Parsed : 23
# Frames Per Second : 32 || Percentage Parsed : 24
# Frames Per Second : 33 || Percentage Parsed : 24
# Frames Per Second : 32 || Percentage Parsed : 24
# Frames Per Second : 33 || Percentage Parsed : 24
# Frames Per Second : 32 || Percentage Parsed : 24
# Frames Per Second : 32 || Percentage Parsed : 24
# Frames Per Second : 32 || Percentage Parsed : 24
# Frames Per Second : 32 || Percentage Parsed : 24
# Frames Per Second : 33 || Percentage Parsed : 24
# Frames Per Second : 33 || Percentage Parsed : 24
# Frames Per Second : 33 || Percentage Parsed : 24
# Frames Per Second : 33 || Percentage Parsed : 24
# Frames Per Second : 33 || Percentage Parsed : 24
# Frames Per Second : 31 || Percentage Parsed : 24
# Frames Per Second : 32 || Percentage Parsed : 25
# Frames Per Second : 33 || Percentage Parsed : 25
# Frames Per Second : 33 || Percentage Parsed : 25
# Frames Per Second : 34 || Percentage Parsed : 25
# Frames Per Second : 33 || Percentage Parsed : 25
# Frames Per Second : 33 || Percentage Parsed : 25
# Frames Per Second : 31 || Percentage Parsed : 25
# Frames Per Second : 31 || Percentage Parsed : 25
# Frames Per Second : 31 || Percentage Parsed : 25
# Frames Per Second : 31 || Percentage Parsed : 25
# Frames Per Second : 32 || Percentage Parsed : 25
# Frames Per Second : 32 || Percentage Parsed : 25
# Frames Per Second : 32 || Percentage Parsed : 25
# Frames Per Second : 32 || Percentage Parsed : 25
# Frames Per Second : 32 || Percentage Parsed : 26
# Frames Per Second : 32 || Percentage Parsed : 26
# Frames Per Second : 32 || Percentage Parsed : 26
# Frames Per Second : 32 || Percentage Parsed : 26
# Frames Per Second : 32 || Percentage Parsed : 26
# Frames Per Second : 32 || Percentage Parsed : 26
# Frames Per Second : 32 || Percentage Parsed : 26
# Frames Per Second : 31 || Percentage Parsed : 26
# Frames Per Second : 32 || Percentage Parsed : 26
# Frames Per Second : 33 || Percentage Parsed : 26
# Frames Per Second : 33 || Percentage Parsed : 26
# Frames Per Second : 33 || Percentage Parsed : 26
# Frames Per Second : 33 || Percentage Parsed : 26
# Frames Per Second : 33 || Percentage Parsed : 26
# Frames Per Second : 32 || Percentage Parsed : 27
# Frames Per Second : 32 || Percentage Parsed : 27
# Frames Per Second : 32 || Percentage Parsed : 27
# Frames Per Second : 32 || Percentage Parsed : 27
# Frames Per Second : 32 || Percentage Parsed : 27
# Frames Per Second : 32 || Percentage Parsed : 27
# Frames Per Second : 32 || Percentage Parsed : 27
# Frames Per Second : 32 || Percentage Parsed : 27
# Frames Per Second : 33 || Percentage Parsed : 27
# Frames Per Second : 33 || Percentage Parsed : 27
# Frames Per Second : 32 || Percentage Parsed : 27
# Frames Per Second : 31 || Percentage Parsed : 27
# Frames Per Second : 31 || Percentage Parsed : 27
# Frames Per Second : 32 || Percentage Parsed : 27
# Frames Per Second : 32 || Percentage Parsed : 27
# Frames Per Second : 31 || Percentage Parsed : 28
# Frames Per Second : 31 || Percentage Parsed : 28
# Frames Per Second : 32 || Percentage Parsed : 28
# Frames Per Second : 32 || Percentage Parsed : 28
# Frames Per Second : 32 || Percentage Parsed : 28
# Frames Per Second : 31 || Percentage Parsed : 28
# Frames Per Second : 32 || Percentage Parsed : 28
# Frames Per Second : 32 || Percentage Parsed : 28
# Frames Per Second : 32 || Percentage Parsed : 28
# Frames Per Second : 32 || Percentage Parsed : 28
# Frames Per Second : 32 || Percentage Parsed : 28
# Frames Per Second : 32 || Percentage Parsed : 28
# Frames Per Second : 33 || Percentage Parsed : 28
# Frames Per Second : 32 || Percentage Parsed : 28
# Frames Per Second : 33 || Percentage Parsed : 29
# Frames Per Second : 33 || Percentage Parsed : 29
# Frames Per Second : 32 || Percentage Parsed : 29
# Frames Per Second : 32 || Percentage Parsed : 29
# Frames Per Second : 32 || Percentage Parsed : 29
# Frames Per Second : 33 || Percentage Parsed : 29
# Frames Per Second : 32 || Percentage Parsed : 29
# Frames Per Second : 33 || Percentage Parsed : 29
# Frames Per Second : 33 || Percentage Parsed : 29
# Frames Per Second : 33 || Percentage Parsed : 29
# Frames Per Second : 32 || Percentage Parsed : 29
# Frames Per Second : 32 || Percentage Parsed : 29
# Frames Per Second : 32 || Percentage Parsed : 29
# Frames Per Second : 33 || Percentage Parsed : 29
# Frames Per Second : 33 || Percentage Parsed : 30
# Frames Per Second : 32 || Percentage Parsed : 30
# Frames Per Second : 33 || Percentage Parsed : 30
# Frames Per Second : 33 || Percentage Parsed : 30
# Frames Per Second : 32 || Percentage Parsed : 30
# Frames Per Second : 32 || Percentage Parsed : 30
# Frames Per Second : 33 || Percentage Parsed : 30
# Frames Per Second : 33 || Percentage Parsed : 30
# Frames Per Second : 33 || Percentage Parsed : 30
# Frames Per Second : 32 || Percentage Parsed : 30
# Frames Per Second : 32 || Percentage Parsed : 30
# Frames Per Second : 33 || Percentage Parsed : 30
# Frames Per Second : 33 || Percentage Parsed : 30
# Frames Per Second : 33 || Percentage Parsed : 30
# Frames Per Second : 33 || Percentage Parsed : 31
# Frames Per Second : 33 || Percentage Parsed : 31
# Frames Per Second : 33 || Percentage Parsed : 31
# Frames Per Second : 33 || Percentage Parsed : 31
# Frames Per Second : 32 || Percentage Parsed : 31
# Frames Per Second : 33 || Percentage Parsed : 31
# Frames Per Second : 33 || Percentage Parsed : 31
# Frames Per Second : 33 || Percentage Parsed : 31
# Frames Per Second : 32 || Percentage Parsed : 31
# Frames Per Second : 33 || Percentage Parsed : 31
# Frames Per Second : 33 || Percentage Parsed : 31
# Frames Per Second : 32 || Percentage Parsed : 31
# Frames Per Second : 32 || Percentage Parsed : 31
# Frames Per Second : 32 || Percentage Parsed : 31
# Frames Per Second : 32 || Percentage Parsed : 32
# Frames Per Second : 33 || Percentage Parsed : 32
# Frames Per Second : 34 || Percentage Parsed : 32
# Frames Per Second : 33 || Percentage Parsed : 32
# Frames Per Second : 33 || Percentage Parsed : 32
# Frames Per Second : 33 || Percentage Parsed : 32
# Frames Per Second : 32 || Percentage Parsed : 32
# Frames Per Second : 32 || Percentage Parsed : 32
# Frames Per Second : 32 || Percentage Parsed : 32
# Frames Per Second : 33 || Percentage Parsed : 32
# Frames Per Second : 34 || Percentage Parsed : 32
# Frames Per Second : 34 || Percentage Parsed : 32
# Frames Per Second : 33 || Percentage Parsed : 32
# Frames Per Second : 33 || Percentage Parsed : 32
# Frames Per Second : 33 || Percentage Parsed : 32
# Frames Per Second : 33 || Percentage Parsed : 33
# Frames Per Second : 33 || Percentage Parsed : 33
# Frames Per Second : 33 || Percentage Parsed : 33
# Frames Per Second : 33 || Percentage Parsed : 33
# Frames Per Second : 33 || Percentage Parsed : 33
# Frames Per Second : 32 || Percentage Parsed : 33
# Frames Per Second : 33 || Percentage Parsed : 33
# Frames Per Second : 32 || Percentage Parsed : 33
# Frames Per Second : 34 || Percentage Parsed : 33
# Frames Per Second : 33 || Percentage Parsed : 33
# Frames Per Second : 34 || Percentage Parsed : 33
# Frames Per Second : 33 || Percentage Parsed : 33
# Frames Per Second : 34 || Percentage Parsed : 33
# Frames Per Second : 33 || Percentage Parsed : 33
# Frames Per Second : 33 || Percentage Parsed : 34
# Frames Per Second : 32 || Percentage Parsed : 34
# Frames Per Second : 32 || Percentage Parsed : 34
# Frames Per Second : 32 || Percentage Parsed : 34
# Frames Per Second : 33 || Percentage Parsed : 34
# Frames Per Second : 33 || Percentage Parsed : 34
# Frames Per Second : 32 || Percentage Parsed : 34
# Frames Per Second : 32 || Percentage Parsed : 34
# Frames Per Second : 33 || Percentage Parsed : 34
# Frames Per Second : 33 || Percentage Parsed : 34
# Frames Per Second : 33 || Percentage Parsed : 34
# Frames Per Second : 34 || Percentage Parsed : 34
# Frames Per Second : 34 || Percentage Parsed : 34
# Frames Per Second : 33 || Percentage Parsed : 34
# Frames Per Second : 34 || Percentage Parsed : 35
# Frames Per Second : 34 || Percentage Parsed : 35
# Frames Per Second : 34 || Percentage Parsed : 35
# Frames Per Second : 33 || Percentage Parsed : 35
# Frames Per Second : 33 || Percentage Parsed : 35
# Frames Per Second : 34 || Percentage Parsed : 35
# Frames Per Second : 33 || Percentage Parsed : 35
# Frames Per Second : 33 || Percentage Parsed : 35
# Frames Per Second : 33 || Percentage Parsed : 35
# Frames Per Second : 33 || Percentage Parsed : 35
# Frames Per Second : 33 || Percentage Parsed : 35
# Frames Per Second : 33 || Percentage Parsed : 35
# Frames Per Second : 33 || Percentage Parsed : 35
# Frames Per Second : 33 || Percentage Parsed : 35
# Frames Per Second : 33 || Percentage Parsed : 36
# Frames Per Second : 33 || Percentage Parsed : 36
# Frames Per Second : 32 || Percentage Parsed : 36
# Frames Per Second : 32 || Percentage Parsed : 36
# Frames Per Second : 33 || Percentage Parsed : 36
# Frames Per Second : 32 || Percentage Parsed : 36
# Frames Per Second : 32 || Percentage Parsed : 36
# Frames Per Second : 32 || Percentage Parsed : 36
# Frames Per Second : 33 || Percentage Parsed : 36
# Frames Per Second : 33 || Percentage Parsed : 36
# Frames Per Second : 33 || Percentage Parsed : 36
# Frames Per Second : 33 || Percentage Parsed : 36
# Frames Per Second : 32 || Percentage Parsed : 36
# Frames Per Second : 32 || Percentage Parsed : 36
# Frames Per Second : 33 || Percentage Parsed : 37
# Frames Per Second : 33 || Percentage Parsed : 37
# Frames Per Second : 34 || Percentage Parsed : 37
# Frames Per Second : 33 || Percentage Parsed : 37
# Frames Per Second : 34 || Percentage Parsed : 37
# Frames Per Second : 33 || Percentage Parsed : 37
# Frames Per Second : 32 || Percentage Parsed : 37
# Frames Per Second : 32 || Percentage Parsed : 37
# Frames Per Second : 32 || Percentage Parsed : 37
# Frames Per Second : 33 || Percentage Parsed : 37
# Frames Per Second : 32 || Percentage Parsed : 37
# Frames Per Second : 32 || Percentage Parsed : 37
# Frames Per Second : 32 || Percentage Parsed : 37
# Frames Per Second : 31 || Percentage Parsed : 37
# Frames Per Second : 33 || Percentage Parsed : 38
# Frames Per Second : 33 || Percentage Parsed : 38
# Frames Per Second : 33 || Percentage Parsed : 38
# Frames Per Second : 33 || Percentage Parsed : 38
# Frames Per Second : 33 || Percentage Parsed : 38
# Frames Per Second : 33 || Percentage Parsed : 38
# Frames Per Second : 33 || Percentage Parsed : 38
# Frames Per Second : 33 || Percentage Parsed : 38
# Frames Per Second : 33 || Percentage Parsed : 38
# Frames Per Second : 33 || Percentage Parsed : 38
# Frames Per Second : 33 || Percentage Parsed : 38
# Frames Per Second : 34 || Percentage Parsed : 38
# Frames Per Second : 34 || Percentage Parsed : 38
# Frames Per Second : 34 || Percentage Parsed : 38
# Frames Per Second : 34 || Percentage Parsed : 38
# Frames Per Second : 32 || Percentage Parsed : 39
# Frames Per Second : 33 || Percentage Parsed : 39
# Frames Per Second : 32 || Percentage Parsed : 39
# Frames Per Second : 32 || Percentage Parsed : 39
# Frames Per Second : 32 || Percentage Parsed : 39
# Frames Per Second : 30 || Percentage Parsed : 39
# Frames Per Second : 31 || Percentage Parsed : 39
# Frames Per Second : 31 || Percentage Parsed : 39
# Frames Per Second : 32 || Percentage Parsed : 39
# Frames Per Second : 32 || Percentage Parsed : 39
# Frames Per Second : 33 || Percentage Parsed : 39
# Frames Per Second : 33 || Percentage Parsed : 39
# Frames Per Second : 33 || Percentage Parsed : 39
# Frames Per Second : 33 || Percentage Parsed : 39
# Frames Per Second : 33 || Percentage Parsed : 40
# Frames Per Second : 33 || Percentage Parsed : 40
# Frames Per Second : 33 || Percentage Parsed : 40
# Frames Per Second : 33 || Percentage Parsed : 40
# Frames Per Second : 33 || Percentage Parsed : 40
# Frames Per Second : 33 || Percentage Parsed : 40
# Frames Per Second : 33 || Percentage Parsed : 40
# Frames Per Second : 32 || Percentage Parsed : 40
# Frames Per Second : 32 || Percentage Parsed : 40
# Frames Per Second : 32 || Percentage Parsed : 40
# Frames Per Second : 32 || Percentage Parsed : 40
# Frames Per Second : 31 || Percentage Parsed : 40
# Frames Per Second : 31 || Percentage Parsed : 40
# Frames Per Second : 31 || Percentage Parsed : 40
# Frames Per Second : 32 || Percentage Parsed : 41
# Frames Per Second : 32 || Percentage Parsed : 41
# Frames Per Second : 32 || Percentage Parsed : 41
# Frames Per Second : 32 || Percentage Parsed : 41
# Frames Per Second : 33 || Percentage Parsed : 41
# Frames Per Second : 33 || Percentage Parsed : 41
# Frames Per Second : 33 || Percentage Parsed : 41
# Frames Per Second : 32 || Percentage Parsed : 41
# Frames Per Second : 32 || Percentage Parsed : 41
# Frames Per Second : 32 || Percentage Parsed : 41
# Frames Per Second : 34 || Percentage Parsed : 41
# Frames Per Second : 33 || Percentage Parsed : 41
# Frames Per Second : 33 || Percentage Parsed : 41
# Frames Per Second : 33 || Percentage Parsed : 41
# Frames Per Second : 33 || Percentage Parsed : 42
# Frames Per Second : 33 || Percentage Parsed : 42
# Frames Per Second : 33 || Percentage Parsed : 42
# Frames Per Second : 33 || Percentage Parsed : 42
# Frames Per Second : 32 || Percentage Parsed : 42
# Frames Per Second : 33 || Percentage Parsed : 42
# Frames Per Second : 32 || Percentage Parsed : 42
# Frames Per Second : 32 || Percentage Parsed : 42
# Frames Per Second : 32 || Percentage Parsed : 42
# Frames Per Second : 31 || Percentage Parsed : 42
# Frames Per Second : 33 || Percentage Parsed : 42
# Frames Per Second : 33 || Percentage Parsed : 42
# Frames Per Second : 32 || Percentage Parsed : 42
# Frames Per Second : 31 || Percentage Parsed : 42
# Frames Per Second : 32 || Percentage Parsed : 43
# Frames Per Second : 31 || Percentage Parsed : 43
# Frames Per Second : 31 || Percentage Parsed : 43
# Frames Per Second : 32 || Percentage Parsed : 43
# Frames Per Second : 32 || Percentage Parsed : 43
# Frames Per Second : 31 || Percentage Parsed : 43
# Frames Per Second : 31 || Percentage Parsed : 43
# Frames Per Second : 31 || Percentage Parsed : 43
# Frames Per Second : 32 || Percentage Parsed : 43
# Frames Per Second : 32 || Percentage Parsed : 43
# Frames Per Second : 32 || Percentage Parsed : 43
# Frames Per Second : 32 || Percentage Parsed : 43
# Frames Per Second : 32 || Percentage Parsed : 43
# Frames Per Second : 32 || Percentage Parsed : 43
# Frames Per Second : 32 || Percentage Parsed : 43
# Frames Per Second : 32 || Percentage Parsed : 44
# Frames Per Second : 32 || Percentage Parsed : 44
# Frames Per Second : 33 || Percentage Parsed : 44
# Frames Per Second : 33 || Percentage Parsed : 44
# Frames Per Second : 33 || Percentage Parsed : 44
# Frames Per Second : 33 || Percentage Parsed : 44
# Frames Per Second : 33 || Percentage Parsed : 44
# Frames Per Second : 31 || Percentage Parsed : 44
# Frames Per Second : 31 || Percentage Parsed : 44
# Frames Per Second : 32 || Percentage Parsed : 44
# Frames Per Second : 32 || Percentage Parsed : 44
# Frames Per Second : 33 || Percentage Parsed : 44
# Frames Per Second : 31 || Percentage Parsed : 44
# Frames Per Second : 33 || Percentage Parsed : 44
# Frames Per Second : 33 || Percentage Parsed : 45
# Frames Per Second : 33 || Percentage Parsed : 45
# Frames Per Second : 32 || Percentage Parsed : 45
# Frames Per Second : 32 || Percentage Parsed : 45
# Frames Per Second : 32 || Percentage Parsed : 45
# Frames Per Second : 32 || Percentage Parsed : 45
# Frames Per Second : 32 || Percentage Parsed : 45
# Frames Per Second : 32 || Percentage Parsed : 45
# Frames Per Second : 31 || Percentage Parsed : 45
# Frames Per Second : 32 || Percentage Parsed : 45
# Frames Per Second : 32 || Percentage Parsed : 45
# Frames Per Second : 32 || Percentage Parsed : 45
# Frames Per Second : 33 || Percentage Parsed : 45
# Frames Per Second : 33 || Percentage Parsed : 45
# Frames Per Second : 34 || Percentage Parsed : 46
# Frames Per Second : 34 || Percentage Parsed : 46
# Frames Per Second : 34 || Percentage Parsed : 46
# Frames Per Second : 34 || Percentage Parsed : 46
# Frames Per Second : 33 || Percentage Parsed : 46
# Frames Per Second : 33 || Percentage Parsed : 46
# Frames Per Second : 32 || Percentage Parsed : 46
# Frames Per Second : 32 || Percentage Parsed : 46
# Frames Per Second : 32 || Percentage Parsed : 46
# Frames Per Second : 33 || Percentage Parsed : 46
# Frames Per Second : 33 || Percentage Parsed : 46
# Frames Per Second : 34 || Percentage Parsed : 46
# Frames Per Second : 33 || Percentage Parsed : 46
# Frames Per Second : 33 || Percentage Parsed : 46
# Frames Per Second : 33 || Percentage Parsed : 47
# Frames Per Second : 33 || Percentage Parsed : 47
# Frames Per Second : 32 || Percentage Parsed : 47
# Frames Per Second : 33 || Percentage Parsed : 47
# Frames Per Second : 34 || Percentage Parsed : 47
# Frames Per Second : 34 || Percentage Parsed : 47
# Frames Per Second : 33 || Percentage Parsed : 47
# Frames Per Second : 32 || Percentage Parsed : 47
# Frames Per Second : 32 || Percentage Parsed : 47
# Frames Per Second : 32 || Percentage Parsed : 47
# Frames Per Second : 33 || Percentage Parsed : 47
# Frames Per Second : 33 || Percentage Parsed : 47
# Frames Per Second : 33 || Percentage Parsed : 47
# Frames Per Second : 33 || Percentage Parsed : 47
# Frames Per Second : 32 || Percentage Parsed : 48
# Frames Per Second : 33 || Percentage Parsed : 48
# Frames Per Second : 34 || Percentage Parsed : 48
# Frames Per Second : 34 || Percentage Parsed : 48
# Frames Per Second : 33 || Percentage Parsed : 48
# Frames Per Second : 33 || Percentage Parsed : 48
# Frames Per Second : 33 || Percentage Parsed : 48
# Frames Per Second : 34 || Percentage Parsed : 48
# Frames Per Second : 33 || Percentage Parsed : 48
# Frames Per Second : 33 || Percentage Parsed : 48
# Frames Per Second : 32 || Percentage Parsed : 48
# Frames Per Second : 31 || Percentage Parsed : 48
# Frames Per Second : 32 || Percentage Parsed : 48
# Frames Per Second : 32 || Percentage Parsed : 48
# Frames Per Second : 33 || Percentage Parsed : 49
# Frames Per Second : 33 || Percentage Parsed : 49
# Frames Per Second : 32 || Percentage Parsed : 49
# Frames Per Second : 33 || Percentage Parsed : 49
# Frames Per Second : 33 || Percentage Parsed : 49
# Frames Per Second : 33 || Percentage Parsed : 49
# Frames Per Second : 33 || Percentage Parsed : 49
# Frames Per Second : 33 || Percentage Parsed : 49
# Frames Per Second : 33 || Percentage Parsed : 49
# Frames Per Second : 33 || Percentage Parsed : 49
# Frames Per Second : 33 || Percentage Parsed : 49
# Frames Per Second : 33 || Percentage Parsed : 49
# Frames Per Second : 33 || Percentage Parsed : 49
# Frames Per Second : 33 || Percentage Parsed : 49
# Frames Per Second : 33 || Percentage Parsed : 49
# Frames Per Second : 34 || Percentage Parsed : 50
# Frames Per Second : 33 || Percentage Parsed : 50
# Frames Per Second : 33 || Percentage Parsed : 50
# Frames Per Second : 33 || Percentage Parsed : 50
# Frames Per Second : 34 || Percentage Parsed : 50
# Frames Per Second : 33 || Percentage Parsed : 50
# Frames Per Second : 34 || Percentage Parsed : 50
# Frames Per Second : 34 || Percentage Parsed : 50
# Frames Per Second : 35 || Percentage Parsed : 50
# Frames Per Second : 35 || Percentage Parsed : 50
# Frames Per Second : 35 || Percentage Parsed : 50
# Frames Per Second : 34 || Percentage Parsed : 50
# Frames Per Second : 34 || Percentage Parsed : 50
# Frames Per Second : 33 || Percentage Parsed : 50
# Frames Per Second : 33 || Percentage Parsed : 51
# Frames Per Second : 33 || Percentage Parsed : 51
# Frames Per Second : 33 || Percentage Parsed : 51
# Frames Per Second : 32 || Percentage Parsed : 51
# Frames Per Second : 32 || Percentage Parsed : 51
# Frames Per Second : 32 || Percentage Parsed : 51
# Frames Per Second : 33 || Percentage Parsed : 51
# Frames Per Second : 32 || Percentage Parsed : 51
# Frames Per Second : 32 || Percentage Parsed : 51
# Frames Per Second : 32 || Percentage Parsed : 51
# Frames Per Second : 33 || Percentage Parsed : 51
# Frames Per Second : 33 || Percentage Parsed : 51
# Frames Per Second : 33 || Percentage Parsed : 51
# Frames Per Second : 33 || Percentage Parsed : 51
# Frames Per Second : 32 || Percentage Parsed : 52
# Frames Per Second : 33 || Percentage Parsed : 52
# Frames Per Second : 33 || Percentage Parsed : 52
# Frames Per Second : 32 || Percentage Parsed : 52
# Frames Per Second : 33 || Percentage Parsed : 52
# Frames Per Second : 33 || Percentage Parsed : 52
# Frames Per Second : 33 || Percentage Parsed : 52
# Frames Per Second : 33 || Percentage Parsed : 52
# Frames Per Second : 33 || Percentage Parsed : 52
# Frames Per Second : 32 || Percentage Parsed : 52
# Frames Per Second : 32 || Percentage Parsed : 52
# Frames Per Second : 33 || Percentage Parsed : 52
# Frames Per Second : 33 || Percentage Parsed : 52
# Frames Per Second : 32 || Percentage Parsed : 52
# Frames Per Second : 32 || Percentage Parsed : 53
# Frames Per Second : 33 || Percentage Parsed : 53
# Frames Per Second : 33 || Percentage Parsed : 53
# Frames Per Second : 33 || Percentage Parsed : 53
# Frames Per Second : 32 || Percentage Parsed : 53
# Frames Per Second : 32 || Percentage Parsed : 53
# Frames Per Second : 32 || Percentage Parsed : 53
# Frames Per Second : 31 || Percentage Parsed : 53
# Frames Per Second : 30 || Percentage Parsed : 53
# Frames Per Second : 32 || Percentage Parsed : 53
# Frames Per Second : 32 || Percentage Parsed : 53
# Frames Per Second : 32 || Percentage Parsed : 53
# Frames Per Second : 32 || Percentage Parsed : 53
# Frames Per Second : 32 || Percentage Parsed : 53
# Frames Per Second : 31 || Percentage Parsed : 54
# Frames Per Second : 32 || Percentage Parsed : 54
# Frames Per Second : 32 || Percentage Parsed : 54
# Frames Per Second : 32 || Percentage Parsed : 54
# Frames Per Second : 31 || Percentage Parsed : 54
# Frames Per Second : 32 || Percentage Parsed : 54
# Frames Per Second : 33 || Percentage Parsed : 54
# Frames Per Second : 33 || Percentage Parsed : 54
# Frames Per Second : 33 || Percentage Parsed : 54
# Frames Per Second : 34 || Percentage Parsed : 54
# Frames Per Second : 34 || Percentage Parsed : 54
# Frames Per Second : 33 || Percentage Parsed : 54
# Frames Per Second : 34 || Percentage Parsed : 54
# Frames Per Second : 33 || Percentage Parsed : 54
# Frames Per Second : 33 || Percentage Parsed : 54
# Frames Per Second : 32 || Percentage Parsed : 55
# Frames Per Second : 31 || Percentage Parsed : 55
# Frames Per Second : 33 || Percentage Parsed : 55
# Frames Per Second : 33 || Percentage Parsed : 55
# Frames Per Second : 31 || Percentage Parsed : 55
# Frames Per Second : 31 || Percentage Parsed : 55
# Frames Per Second : 32 || Percentage Parsed : 55
# Frames Per Second : 31 || Percentage Parsed : 55
# Frames Per Second : 32 || Percentage Parsed : 55
# Frames Per Second : 33 || Percentage Parsed : 55
# Frames Per Second : 32 || Percentage Parsed : 55
# Frames Per Second : 33 || Percentage Parsed : 55
# Frames Per Second : 33 || Percentage Parsed : 55
# Frames Per Second : 33 || Percentage Parsed : 55
# Frames Per Second : 33 || Percentage Parsed : 56
# Frames Per Second : 32 || Percentage Parsed : 56
# Frames Per Second : 33 || Percentage Parsed : 56
# Frames Per Second : 33 || Percentage Parsed : 56
# Frames Per Second : 32 || Percentage Parsed : 56
# Frames Per Second : 32 || Percentage Parsed : 56
# Frames Per Second : 32 || Percentage Parsed : 56
# Frames Per Second : 32 || Percentage Parsed : 56
# Frames Per Second : 32 || Percentage Parsed : 56
# Frames Per Second : 31 || Percentage Parsed : 56
# Frames Per Second : 31 || Percentage Parsed : 56
# Frames Per Second : 32 || Percentage Parsed : 56
# Frames Per Second : 32 || Percentage Parsed : 56
# Frames Per Second : 32 || Percentage Parsed : 56
# Frames Per Second : 33 || Percentage Parsed : 57
# Frames Per Second : 33 || Percentage Parsed : 57
# Frames Per Second : 32 || Percentage Parsed : 57
# Frames Per Second : 32 || Percentage Parsed : 57
# Frames Per Second : 32 || Percentage Parsed : 57
# Frames Per Second : 32 || Percentage Parsed : 57
# Frames Per Second : 32 || Percentage Parsed : 57
# Frames Per Second : 32 || Percentage Parsed : 57
# Frames Per Second : 32 || Percentage Parsed : 57
# Frames Per Second : 32 || Percentage Parsed : 57
# Frames Per Second : 33 || Percentage Parsed : 57
# Frames Per Second : 33 || Percentage Parsed : 57
# Frames Per Second : 33 || Percentage Parsed : 57
# Frames Per Second : 32 || Percentage Parsed : 57
# Frames Per Second : 33 || Percentage Parsed : 58
# Frames Per Second : 33 || Percentage Parsed : 58
# Frames Per Second : 33 || Percentage Parsed : 58
# Frames Per Second : 31 || Percentage Parsed : 58
# Frames Per Second : 32 || Percentage Parsed : 58
# Frames Per Second : 32 || Percentage Parsed : 58
# Frames Per Second : 32 || Percentage Parsed : 58
# Frames Per Second : 32 || Percentage Parsed : 58
# Frames Per Second : 32 || Percentage Parsed : 58
# Frames Per Second : 31 || Percentage Parsed : 58
# Frames Per Second : 31 || Percentage Parsed : 58
# Frames Per Second : 32 || Percentage Parsed : 58
# Frames Per Second : 31 || Percentage Parsed : 58
# Frames Per Second : 33 || Percentage Parsed : 58
# Frames Per Second : 33 || Percentage Parsed : 59
# Frames Per Second : 33 || Percentage Parsed : 59
# Frames Per Second : 32 || Percentage Parsed : 59
# Frames Per Second : 31 || Percentage Parsed : 59
# Frames Per Second : 31 || Percentage Parsed : 59
# Frames Per Second : 32 || Percentage Parsed : 59
# Frames Per Second : 32 || Percentage Parsed : 59
# Frames Per Second : 32 || Percentage Parsed : 59
# Frames Per Second : 32 || Percentage Parsed : 59
# Frames Per Second : 31 || Percentage Parsed : 59
# Frames Per Second : 32 || Percentage Parsed : 59
# Frames Per Second : 32 || Percentage Parsed : 59
# Frames Per Second : 32 || Percentage Parsed : 59
# Frames Per Second : 31 || Percentage Parsed : 59
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 33 || Percentage Parsed : 60
# Frames Per Second : 33 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 31 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 60
# Frames Per Second : 32 || Percentage Parsed : 61
# Frames Per Second : 32 || Percentage Parsed : 61
# Frames Per Second : 33 || Percentage Parsed : 61
# Frames Per Second : 33 || Percentage Parsed : 61
# Frames Per Second : 32 || Percentage Parsed : 61
# Frames Per Second : 32 || Percentage Parsed : 61
# Frames Per Second : 32 || Percentage Parsed : 61
# Frames Per Second : 32 || Percentage Parsed : 61
# Frames Per Second : 31 || Percentage Parsed : 61
# Frames Per Second : 32 || Percentage Parsed : 61
# Frames Per Second : 33 || Percentage Parsed : 61
# Frames Per Second : 33 || Percentage Parsed : 61
# Frames Per Second : 32 || Percentage Parsed : 61
# Frames Per Second : 32 || Percentage Parsed : 61
# Frames Per Second : 31 || Percentage Parsed : 62
# Frames Per Second : 31 || Percentage Parsed : 62
# Frames Per Second : 32 || Percentage Parsed : 62
# Frames Per Second : 34 || Percentage Parsed : 62
# Frames Per Second : 32 || Percentage Parsed : 62
# Frames Per Second : 33 || Percentage Parsed : 62
# Frames Per Second : 33 || Percentage Parsed : 62
# Frames Per Second : 33 || Percentage Parsed : 62
# Frames Per Second : 32 || Percentage Parsed : 62
# Frames Per Second : 32 || Percentage Parsed : 62
# Frames Per Second : 33 || Percentage Parsed : 62
# Frames Per Second : 32 || Percentage Parsed : 62
# Frames Per Second : 32 || Percentage Parsed : 62
# Frames Per Second : 32 || Percentage Parsed : 62
# Frames Per Second : 33 || Percentage Parsed : 63
# Frames Per Second : 32 || Percentage Parsed : 63
# Frames Per Second : 32 || Percentage Parsed : 63
# Frames Per Second : 33 || Percentage Parsed : 63
# Frames Per Second : 33 || Percentage Parsed : 63
# Frames Per Second : 33 || Percentage Parsed : 63
# Frames Per Second : 33 || Percentage Parsed : 63
# Frames Per Second : 33 || Percentage Parsed : 63
# Frames Per Second : 32 || Percentage Parsed : 63
# Frames Per Second : 32 || Percentage Parsed : 63
# Frames Per Second : 32 || Percentage Parsed : 63
# Frames Per Second : 32 || Percentage Parsed : 63
# Frames Per Second : 32 || Percentage Parsed : 63
# Frames Per Second : 31 || Percentage Parsed : 63
# Frames Per Second : 32 || Percentage Parsed : 64
# Frames Per Second : 32 || Percentage Parsed : 64
# Frames Per Second : 32 || Percentage Parsed : 64
# Frames Per Second : 32 || Percentage Parsed : 64
# Frames Per Second : 31 || Percentage Parsed : 64
# Frames Per Second : 32 || Percentage Parsed : 64
# Frames Per Second : 32 || Percentage Parsed : 64
# Frames Per Second : 32 || Percentage Parsed : 64
# Frames Per Second : 33 || Percentage Parsed : 64
# Frames Per Second : 32 || Percentage Parsed : 64
# Frames Per Second : 32 || Percentage Parsed : 64
# Frames Per Second : 32 || Percentage Parsed : 64
# Frames Per Second : 32 || Percentage Parsed : 64
# Frames Per Second : 32 || Percentage Parsed : 64
# Frames Per Second : 32 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 32 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 33 || Percentage Parsed : 65
# Frames Per Second : 32 || Percentage Parsed : 65
# Frames Per Second : 32 || Percentage Parsed : 66
# Frames Per Second : 32 || Percentage Parsed : 66
# Frames Per Second : 32 || Percentage Parsed : 66
# Frames Per Second : 32 || Percentage Parsed : 66
# Frames Per Second : 32 || Percentage Parsed : 66
# Frames Per Second : 32 || Percentage Parsed : 66
# Frames Per Second : 33 || Percentage Parsed : 66
# Frames Per Second : 33 || Percentage Parsed : 66
# Frames Per Second : 32 || Percentage Parsed : 66
# Frames Per Second : 33 || Percentage Parsed : 66
# Frames Per Second : 32 || Percentage Parsed : 66
# Frames Per Second : 33 || Percentage Parsed : 66
# Frames Per Second : 32 || Percentage Parsed : 66
# Frames Per Second : 32 || Percentage Parsed : 66

# %% [markdown]
# Salvamos el video resultante del proceso en nuestro Drive:

# %%
# Input video path
save_path = "/content/fuerzas_armadas_ssd300_augmented_humans.mp4"

# Compressed video path
compressed_path = "/content/fuerzas_armadas_ssd300_augmented_humans_compressed_02.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")
# Out:
# 0

# %%
shutil.copy(
    "/content/fuerzas_armadas_ssd300_augmented_humans_compressed_02.mp4",
    "/content/drive/MyDrive/tfg/fuerzas_armadas_ssd300_augmented_humans_compressed_02.mp4"
)
# Out:
# '/content/drive/MyDrive/tfg/fuerzas_armadas_ssd300_augmented_humans_compressed_02.mp4'

# %% [markdown]
# ## YOLOv5 Básico

# %%
zip_path = "/content/drive/MyDrive/tfg/models/runs_yolov5.zip"
extract_path = "/content/"
# !unzip -q "$zip_path" -d "$extract_path"

# %%
model = YOLO("runs/detect/train/weights/best.pt")

# %%
yolov5_rtod = VideoParserObjectDetectionModel(model, YOLO_FNS, CLASS_INFO)

# %%
yolov5_rtod(URL, "fuerzas_armadas_yolov5.mp4")
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=xV24-uVq3WY
# [youtube] xV24-uVq3WY: Downloading webpage
# [youtube] xV24-uVq3WY: Downloading tv client config
# [youtube] xV24-uVq3WY: Downloading player 91e7c654-main
# [youtube] xV24-uVq3WY: Downloading tv player API JSON
# [youtube] xV24-uVq3WY: Downloading ios player API JSON
# [youtube] xV24-uVq3WY: Downloading m3u8 information
# Frames Per Second : 38 || Percentage Parsed : 0
# Frames Per Second : 51 || Percentage Parsed : 0
# Frames Per Second : 50 || Percentage Parsed : 0
# Frames Per Second : 53 || Percentage Parsed : 0
# Frames Per Second : 53 || Percentage Parsed : 0
# Frames Per Second : 53 || Percentage Parsed : 0
# Frames Per Second : 52 || Percentage Parsed : 0
# Frames Per Second : 54 || Percentage Parsed : 0
# Frames Per Second : 54 || Percentage Parsed : 0
# Frames Per Second : 53 || Percentage Parsed : 0
# Frames Per Second : 51 || Percentage Parsed : 0
# Frames Per Second : 50 || Percentage Parsed : 0
# Frames Per Second : 50 || Percentage Parsed : 0
# Frames Per Second : 50 || Percentage Parsed : 0
# Frames Per Second : 50 || Percentage Parsed : 1
# Frames Per Second : 49 || Percentage Parsed : 1
# Frames Per Second : 52 || Percentage Parsed : 1
# Frames Per Second : 54 || Percentage Parsed : 1
# Frames Per Second : 54 || Percentage Parsed : 1
# Frames Per Second : 54 || Percentage Parsed : 1
# Frames Per Second : 54 || Percentage Parsed : 1
# Frames Per Second : 54 || Percentage Parsed : 1
# Frames Per Second : 55 || Percentage Parsed : 1
# Frames Per Second : 54 || Percentage Parsed : 1
# Frames Per Second : 52 || Percentage Parsed : 1
# Frames Per Second : 54 || Percentage Parsed : 1
# Frames Per Second : 54 || Percentage Parsed : 1
# Frames Per Second : 54 || Percentage Parsed : 1
# Frames Per Second : 54 || Percentage Parsed : 2
# Frames Per Second : 54 || Percentage Parsed : 2
# Frames Per Second : 54 || Percentage Parsed : 2
# Frames Per Second : 53 || Percentage Parsed : 2
# Frames Per Second : 53 || Percentage Parsed : 2
# Frames Per Second : 53 || Percentage Parsed : 2
# Frames Per Second : 55 || Percentage Parsed : 2
# Frames Per Second : 55 || Percentage Parsed : 2
# Frames Per Second : 55 || Percentage Parsed : 2
# Frames Per Second : 55 || Percentage Parsed : 2
# Frames Per Second : 51 || Percentage Parsed : 2
# Frames Per Second : 52 || Percentage Parsed : 2
# Frames Per Second : 52 || Percentage Parsed : 2
# Frames Per Second : 53 || Percentage Parsed : 2
# Frames Per Second : 51 || Percentage Parsed : 3
# Frames Per Second : 54 || Percentage Parsed : 3
# Frames Per Second : 53 || Percentage Parsed : 3
# Frames Per Second : 51 || Percentage Parsed : 3
# Frames Per Second : 52 || Percentage Parsed : 3
# Frames Per Second : 52 || Percentage Parsed : 3
# Frames Per Second : 53 || Percentage Parsed : 3
# Frames Per Second : 54 || Percentage Parsed : 3
# Frames Per Second : 55 || Percentage Parsed : 3
# Frames Per Second : 54 || Percentage Parsed : 3
# Frames Per Second : 53 || Percentage Parsed : 3
# Frames Per Second : 54 || Percentage Parsed : 3
# Frames Per Second : 55 || Percentage Parsed : 3
# Frames Per Second : 55 || Percentage Parsed : 3
# Frames Per Second : 51 || Percentage Parsed : 4
# Frames Per Second : 50 || Percentage Parsed : 4
# Frames Per Second : 50 || Percentage Parsed : 4
# Frames Per Second : 50 || Percentage Parsed : 4
# Frames Per Second : 51 || Percentage Parsed : 4
# Frames Per Second : 51 || Percentage Parsed : 4
# Frames Per Second : 50 || Percentage Parsed : 4
# Frames Per Second : 50 || Percentage Parsed : 4
# Frames Per Second : 50 || Percentage Parsed : 4
# Frames Per Second : 51 || Percentage Parsed : 4
# Frames Per Second : 52 || Percentage Parsed : 4
# Frames Per Second : 54 || Percentage Parsed : 4
# Frames Per Second : 52 || Percentage Parsed : 4
# Frames Per Second : 53 || Percentage Parsed : 4
# Frames Per Second : 55 || Percentage Parsed : 5
# Frames Per Second : 54 || Percentage Parsed : 5
# Frames Per Second : 51 || Percentage Parsed : 5
# Frames Per Second : 51 || Percentage Parsed : 5
# Frames Per Second : 51 || Percentage Parsed : 5
# Frames Per Second : 49 || Percentage Parsed : 5
# Frames Per Second : 49 || Percentage Parsed : 5
# Frames Per Second : 49 || Percentage Parsed : 5
# Frames Per Second : 50 || Percentage Parsed : 5
# Frames Per Second : 50 || Percentage Parsed : 5
# Frames Per Second : 50 || Percentage Parsed : 5
# Frames Per Second : 50 || Percentage Parsed : 5
# Frames Per Second : 49 || Percentage Parsed : 5
# Frames Per Second : 49 || Percentage Parsed : 5
# Frames Per Second : 50 || Percentage Parsed : 5
# Frames Per Second : 51 || Percentage Parsed : 6
# Frames Per Second : 50 || Percentage Parsed : 6
# Frames Per Second : 49 || Percentage Parsed : 6
# Frames Per Second : 50 || Percentage Parsed : 6
# Frames Per Second : 49 || Percentage Parsed : 6
# Frames Per Second : 50 || Percentage Parsed : 6
# Frames Per Second : 51 || Percentage Parsed : 6
# Frames Per Second : 49 || Percentage Parsed : 6
# Frames Per Second : 50 || Percentage Parsed : 6
# Frames Per Second : 50 || Percentage Parsed : 6
# Frames Per Second : 51 || Percentage Parsed : 6
# Frames Per Second : 50 || Percentage Parsed : 6
# Frames Per Second : 51 || Percentage Parsed : 6
# Frames Per Second : 50 || Percentage Parsed : 6
# Frames Per Second : 51 || Percentage Parsed : 7
# Frames Per Second : 51 || Percentage Parsed : 7
# Frames Per Second : 53 || Percentage Parsed : 7
# Frames Per Second : 51 || Percentage Parsed : 7
# Frames Per Second : 51 || Percentage Parsed : 7
# Frames Per Second : 50 || Percentage Parsed : 7
# Frames Per Second : 50 || Percentage Parsed : 7
# Frames Per Second : 50 || Percentage Parsed : 7
# Frames Per Second : 49 || Percentage Parsed : 7
# Frames Per Second : 51 || Percentage Parsed : 7
# Frames Per Second : 50 || Percentage Parsed : 7
# Frames Per Second : 48 || Percentage Parsed : 7
# Frames Per Second : 48 || Percentage Parsed : 7
# Frames Per Second : 49 || Percentage Parsed : 7
# Frames Per Second : 50 || Percentage Parsed : 8
# Frames Per Second : 48 || Percentage Parsed : 8
# Frames Per Second : 52 || Percentage Parsed : 8
# Frames Per Second : 50 || Percentage Parsed : 8
# Frames Per Second : 50 || Percentage Parsed : 8
# Frames Per Second : 49 || Percentage Parsed : 8
# Frames Per Second : 48 || Percentage Parsed : 8
# Frames Per Second : 50 || Percentage Parsed : 8
# Frames Per Second : 51 || Percentage Parsed : 8
# Frames Per Second : 51 || Percentage Parsed : 8
# Frames Per Second : 50 || Percentage Parsed : 8
# Frames Per Second : 52 || Percentage Parsed : 8
# Frames Per Second : 51 || Percentage Parsed : 8
# Frames Per Second : 51 || Percentage Parsed : 8
# Frames Per Second : 51 || Percentage Parsed : 9
# Frames Per Second : 50 || Percentage Parsed : 9
# Frames Per Second : 50 || Percentage Parsed : 9
# Frames Per Second : 49 || Percentage Parsed : 9
# Frames Per Second : 53 || Percentage Parsed : 9
# Frames Per Second : 54 || Percentage Parsed : 9
# Frames Per Second : 55 || Percentage Parsed : 9
# Frames Per Second : 54 || Percentage Parsed : 9
# Frames Per Second : 52 || Percentage Parsed : 9
# Frames Per Second : 53 || Percentage Parsed : 9
# Frames Per Second : 53 || Percentage Parsed : 9
# Frames Per Second : 54 || Percentage Parsed : 9
# Frames Per Second : 54 || Percentage Parsed : 9
# Frames Per Second : 54 || Percentage Parsed : 9
# Frames Per Second : 51 || Percentage Parsed : 10
# Frames Per Second : 49 || Percentage Parsed : 10
# Frames Per Second : 49 || Percentage Parsed : 10
# Frames Per Second : 47 || Percentage Parsed : 10
# Frames Per Second : 48 || Percentage Parsed : 10
# Frames Per Second : 48 || Percentage Parsed : 10
# Frames Per Second : 46 || Percentage Parsed : 10
# Frames Per Second : 47 || Percentage Parsed : 10
# Frames Per Second : 49 || Percentage Parsed : 10
# Frames Per Second : 49 || Percentage Parsed : 10
# Frames Per Second : 51 || Percentage Parsed : 10
# Frames Per Second : 53 || Percentage Parsed : 10
# Frames Per Second : 54 || Percentage Parsed : 10
# Frames Per Second : 52 || Percentage Parsed : 10
# Frames Per Second : 52 || Percentage Parsed : 10
# Frames Per Second : 52 || Percentage Parsed : 11
# Frames Per Second : 52 || Percentage Parsed : 11
# Frames Per Second : 50 || Percentage Parsed : 11
# Frames Per Second : 50 || Percentage Parsed : 11
# Frames Per Second : 52 || Percentage Parsed : 11
# Frames Per Second : 53 || Percentage Parsed : 11
# Frames Per Second : 52 || Percentage Parsed : 11
# Frames Per Second : 53 || Percentage Parsed : 11
# Frames Per Second : 53 || Percentage Parsed : 11
# Frames Per Second : 53 || Percentage Parsed : 11
# Frames Per Second : 53 || Percentage Parsed : 11
# Frames Per Second : 56 || Percentage Parsed : 11
# Frames Per Second : 55 || Percentage Parsed : 11
# Frames Per Second : 55 || Percentage Parsed : 11
# Frames Per Second : 53 || Percentage Parsed : 12
# Frames Per Second : 53 || Percentage Parsed : 12
# Frames Per Second : 54 || Percentage Parsed : 12
# Frames Per Second : 53 || Percentage Parsed : 12
# Frames Per Second : 53 || Percentage Parsed : 12
# Frames Per Second : 55 || Percentage Parsed : 12
# Frames Per Second : 53 || Percentage Parsed : 12
# Frames Per Second : 54 || Percentage Parsed : 12
# Frames Per Second : 55 || Percentage Parsed : 12
# Frames Per Second : 52 || Percentage Parsed : 12
# Frames Per Second : 52 || Percentage Parsed : 12
# Frames Per Second : 54 || Percentage Parsed : 12
# Frames Per Second : 53 || Percentage Parsed : 12
# Frames Per Second : 53 || Percentage Parsed : 12
# Frames Per Second : 53 || Percentage Parsed : 13
# Frames Per Second : 54 || Percentage Parsed : 13
# Frames Per Second : 52 || Percentage Parsed : 13
# Frames Per Second : 52 || Percentage Parsed : 13
# Frames Per Second : 51 || Percentage Parsed : 13
# Frames Per Second : 51 || Percentage Parsed : 13
# Frames Per Second : 53 || Percentage Parsed : 13
# Frames Per Second : 52 || Percentage Parsed : 13
# Frames Per Second : 53 || Percentage Parsed : 13
# Frames Per Second : 53 || Percentage Parsed : 13
# Frames Per Second : 50 || Percentage Parsed : 13
# Frames Per Second : 50 || Percentage Parsed : 13
# Frames Per Second : 52 || Percentage Parsed : 13
# Frames Per Second : 51 || Percentage Parsed : 13
# Frames Per Second : 51 || Percentage Parsed : 14
# Frames Per Second : 52 || Percentage Parsed : 14
# Frames Per Second : 50 || Percentage Parsed : 14
# Frames Per Second : 51 || Percentage Parsed : 14
# Frames Per Second : 51 || Percentage Parsed : 14
# Frames Per Second : 52 || Percentage Parsed : 14
# Frames Per Second : 51 || Percentage Parsed : 14
# Frames Per Second : 51 || Percentage Parsed : 14
# Frames Per Second : 56 || Percentage Parsed : 14
# Frames Per Second : 56 || Percentage Parsed : 14
# Frames Per Second : 55 || Percentage Parsed : 14
# Frames Per Second : 55 || Percentage Parsed : 14
# Frames Per Second : 56 || Percentage Parsed : 14
# Frames Per Second : 55 || Percentage Parsed : 14
# Frames Per Second : 57 || Percentage Parsed : 15
# Frames Per Second : 57 || Percentage Parsed : 15
# Frames Per Second : 56 || Percentage Parsed : 15
# Frames Per Second : 57 || Percentage Parsed : 15
# Frames Per Second : 56 || Percentage Parsed : 15
# Frames Per Second : 55 || Percentage Parsed : 15
# Frames Per Second : 55 || Percentage Parsed : 15
# Frames Per Second : 56 || Percentage Parsed : 15
# Frames Per Second : 57 || Percentage Parsed : 15
# Frames Per Second : 56 || Percentage Parsed : 15
# Frames Per Second : 56 || Percentage Parsed : 15
# Frames Per Second : 58 || Percentage Parsed : 15
# Frames Per Second : 57 || Percentage Parsed : 15
# Frames Per Second : 57 || Percentage Parsed : 15
# Frames Per Second : 57 || Percentage Parsed : 16
# Frames Per Second : 56 || Percentage Parsed : 16
# Frames Per Second : 56 || Percentage Parsed : 16
# Frames Per Second : 54 || Percentage Parsed : 16
# Frames Per Second : 54 || Percentage Parsed : 16
# Frames Per Second : 55 || Percentage Parsed : 16
# Frames Per Second : 56 || Percentage Parsed : 16
# Frames Per Second : 57 || Percentage Parsed : 16
# Frames Per Second : 55 || Percentage Parsed : 16
# Frames Per Second : 56 || Percentage Parsed : 16
# Frames Per Second : 54 || Percentage Parsed : 16
# Frames Per Second : 55 || Percentage Parsed : 16
# Frames Per Second : 56 || Percentage Parsed : 16
# Frames Per Second : 55 || Percentage Parsed : 16
# Frames Per Second : 54 || Percentage Parsed : 16
# Frames Per Second : 54 || Percentage Parsed : 17
# Frames Per Second : 55 || Percentage Parsed : 17
# Frames Per Second : 55 || Percentage Parsed : 17
# Frames Per Second : 55 || Percentage Parsed : 17
# Frames Per Second : 56 || Percentage Parsed : 17
# Frames Per Second : 56 || Percentage Parsed : 17
# Frames Per Second : 55 || Percentage Parsed : 17
# Frames Per Second : 55 || Percentage Parsed : 17
# Frames Per Second : 56 || Percentage Parsed : 17
# Frames Per Second : 56 || Percentage Parsed : 17
# Frames Per Second : 55 || Percentage Parsed : 17
# Frames Per Second : 53 || Percentage Parsed : 17
# Frames Per Second : 54 || Percentage Parsed : 17
# Frames Per Second : 53 || Percentage Parsed : 17
# Frames Per Second : 50 || Percentage Parsed : 18
# Frames Per Second : 51 || Percentage Parsed : 18
# Frames Per Second : 52 || Percentage Parsed : 18
# Frames Per Second : 51 || Percentage Parsed : 18
# Frames Per Second : 51 || Percentage Parsed : 18
# Frames Per Second : 51 || Percentage Parsed : 18
# Frames Per Second : 55 || Percentage Parsed : 18
# Frames Per Second : 55 || Percentage Parsed : 18
# Frames Per Second : 55 || Percentage Parsed : 18
# Frames Per Second : 56 || Percentage Parsed : 18
# Frames Per Second : 55 || Percentage Parsed : 18
# Frames Per Second : 55 || Percentage Parsed : 18
# Frames Per Second : 55 || Percentage Parsed : 18
# Frames Per Second : 52 || Percentage Parsed : 18
# Frames Per Second : 52 || Percentage Parsed : 19
# Frames Per Second : 54 || Percentage Parsed : 19
# Frames Per Second : 54 || Percentage Parsed : 19
# Frames Per Second : 55 || Percentage Parsed : 19
# Frames Per Second : 55 || Percentage Parsed : 19
# Frames Per Second : 56 || Percentage Parsed : 19
# Frames Per Second : 57 || Percentage Parsed : 19
# Frames Per Second : 57 || Percentage Parsed : 19
# Frames Per Second : 55 || Percentage Parsed : 19
# Frames Per Second : 55 || Percentage Parsed : 19
# Frames Per Second : 56 || Percentage Parsed : 19
# Frames Per Second : 56 || Percentage Parsed : 19
# Frames Per Second : 55 || Percentage Parsed : 19
# Frames Per Second : 55 || Percentage Parsed : 19
# Frames Per Second : 56 || Percentage Parsed : 20
# Frames Per Second : 53 || Percentage Parsed : 20
# Frames Per Second : 55 || Percentage Parsed : 20
# Frames Per Second : 54 || Percentage Parsed : 20
# Frames Per Second : 54 || Percentage Parsed : 20
# Frames Per Second : 53 || Percentage Parsed : 20
# Frames Per Second : 51 || Percentage Parsed : 20
# Frames Per Second : 53 || Percentage Parsed : 20
# Frames Per Second : 52 || Percentage Parsed : 20
# Frames Per Second : 51 || Percentage Parsed : 20
# Frames Per Second : 51 || Percentage Parsed : 20
# Frames Per Second : 51 || Percentage Parsed : 20
# Frames Per Second : 52 || Percentage Parsed : 20
# Frames Per Second : 51 || Percentage Parsed : 20
# Frames Per Second : 52 || Percentage Parsed : 21
# Frames Per Second : 54 || Percentage Parsed : 21
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 56 || Percentage Parsed : 21
# Frames Per Second : 57 || Percentage Parsed : 21
# Frames Per Second : 57 || Percentage Parsed : 21
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 57 || Percentage Parsed : 21
# Frames Per Second : 57 || Percentage Parsed : 21
# Frames Per Second : 56 || Percentage Parsed : 21
# Frames Per Second : 54 || Percentage Parsed : 21
# Frames Per Second : 54 || Percentage Parsed : 22
# Frames Per Second : 54 || Percentage Parsed : 22
# Frames Per Second : 54 || Percentage Parsed : 22
# Frames Per Second : 54 || Percentage Parsed : 22
# Frames Per Second : 53 || Percentage Parsed : 22
# Frames Per Second : 51 || Percentage Parsed : 22
# Frames Per Second : 53 || Percentage Parsed : 22
# Frames Per Second : 53 || Percentage Parsed : 22
# Frames Per Second : 55 || Percentage Parsed : 22
# Frames Per Second : 56 || Percentage Parsed : 22
# Frames Per Second : 56 || Percentage Parsed : 22
# Frames Per Second : 55 || Percentage Parsed : 22
# Frames Per Second : 56 || Percentage Parsed : 22
# Frames Per Second : 53 || Percentage Parsed : 22
# Frames Per Second : 52 || Percentage Parsed : 23
# Frames Per Second : 50 || Percentage Parsed : 23
# Frames Per Second : 53 || Percentage Parsed : 23
# Frames Per Second : 52 || Percentage Parsed : 23
# Frames Per Second : 54 || Percentage Parsed : 23
# Frames Per Second : 54 || Percentage Parsed : 23
# Frames Per Second : 55 || Percentage Parsed : 23
# Frames Per Second : 56 || Percentage Parsed : 23
# Frames Per Second : 55 || Percentage Parsed : 23
# Frames Per Second : 53 || Percentage Parsed : 23
# Frames Per Second : 54 || Percentage Parsed : 23
# Frames Per Second : 54 || Percentage Parsed : 23
# Frames Per Second : 53 || Percentage Parsed : 23
# Frames Per Second : 54 || Percentage Parsed : 23
# Frames Per Second : 55 || Percentage Parsed : 24
# Frames Per Second : 50 || Percentage Parsed : 24
# Frames Per Second : 50 || Percentage Parsed : 24
# Frames Per Second : 51 || Percentage Parsed : 24
# Frames Per Second : 53 || Percentage Parsed : 24
# Frames Per Second : 51 || Percentage Parsed : 24
# Frames Per Second : 52 || Percentage Parsed : 24
# Frames Per Second : 51 || Percentage Parsed : 24
# Frames Per Second : 52 || Percentage Parsed : 24
# Frames Per Second : 52 || Percentage Parsed : 24
# Frames Per Second : 53 || Percentage Parsed : 24
# Frames Per Second : 56 || Percentage Parsed : 24
# Frames Per Second : 56 || Percentage Parsed : 24
# Frames Per Second : 54 || Percentage Parsed : 24
# Frames Per Second : 55 || Percentage Parsed : 25
# Frames Per Second : 55 || Percentage Parsed : 25
# Frames Per Second : 55 || Percentage Parsed : 25
# Frames Per Second : 56 || Percentage Parsed : 25
# Frames Per Second : 56 || Percentage Parsed : 25
# Frames Per Second : 55 || Percentage Parsed : 25
# Frames Per Second : 54 || Percentage Parsed : 25
# Frames Per Second : 56 || Percentage Parsed : 25
# Frames Per Second : 56 || Percentage Parsed : 25
# Frames Per Second : 52 || Percentage Parsed : 25
# Frames Per Second : 53 || Percentage Parsed : 25
# Frames Per Second : 53 || Percentage Parsed : 25
# Frames Per Second : 54 || Percentage Parsed : 25
# Frames Per Second : 55 || Percentage Parsed : 25
# Frames Per Second : 56 || Percentage Parsed : 26
# Frames Per Second : 55 || Percentage Parsed : 26
# Frames Per Second : 57 || Percentage Parsed : 26
# Frames Per Second : 56 || Percentage Parsed : 26
# Frames Per Second : 56 || Percentage Parsed : 26
# Frames Per Second : 55 || Percentage Parsed : 26
# Frames Per Second : 54 || Percentage Parsed : 26
# Frames Per Second : 56 || Percentage Parsed : 26
# Frames Per Second : 55 || Percentage Parsed : 26
# Frames Per Second : 56 || Percentage Parsed : 26
# Frames Per Second : 56 || Percentage Parsed : 26
# Frames Per Second : 52 || Percentage Parsed : 26
# Frames Per Second : 54 || Percentage Parsed : 26
# Frames Per Second : 55 || Percentage Parsed : 26
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 56 || Percentage Parsed : 27
# Frames Per Second : 56 || Percentage Parsed : 27
# Frames Per Second : 56 || Percentage Parsed : 27
# Frames Per Second : 56 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 54 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 56 || Percentage Parsed : 27
# Frames Per Second : 56 || Percentage Parsed : 27
# Frames Per Second : 54 || Percentage Parsed : 27
# Frames Per Second : 54 || Percentage Parsed : 27
# Frames Per Second : 54 || Percentage Parsed : 27
# Frames Per Second : 54 || Percentage Parsed : 28
# Frames Per Second : 54 || Percentage Parsed : 28
# Frames Per Second : 57 || Percentage Parsed : 28
# Frames Per Second : 56 || Percentage Parsed : 28
# Frames Per Second : 55 || Percentage Parsed : 28
# Frames Per Second : 52 || Percentage Parsed : 28
# Frames Per Second : 50 || Percentage Parsed : 28
# Frames Per Second : 52 || Percentage Parsed : 28
# Frames Per Second : 53 || Percentage Parsed : 28
# Frames Per Second : 52 || Percentage Parsed : 28
# Frames Per Second : 57 || Percentage Parsed : 28
# Frames Per Second : 56 || Percentage Parsed : 28
# Frames Per Second : 57 || Percentage Parsed : 28
# Frames Per Second : 57 || Percentage Parsed : 28
# Frames Per Second : 55 || Percentage Parsed : 29
# Frames Per Second : 54 || Percentage Parsed : 29
# Frames Per Second : 55 || Percentage Parsed : 29
# Frames Per Second : 55 || Percentage Parsed : 29
# Frames Per Second : 53 || Percentage Parsed : 29
# Frames Per Second : 52 || Percentage Parsed : 29
# Frames Per Second : 52 || Percentage Parsed : 29
# Frames Per Second : 53 || Percentage Parsed : 29
# Frames Per Second : 50 || Percentage Parsed : 29
# Frames Per Second : 51 || Percentage Parsed : 29
# Frames Per Second : 51 || Percentage Parsed : 29
# Frames Per Second : 50 || Percentage Parsed : 29
# Frames Per Second : 51 || Percentage Parsed : 29
# Frames Per Second : 51 || Percentage Parsed : 29
# Frames Per Second : 52 || Percentage Parsed : 30
# Frames Per Second : 51 || Percentage Parsed : 30
# Frames Per Second : 55 || Percentage Parsed : 30
# Frames Per Second : 56 || Percentage Parsed : 30
# Frames Per Second : 56 || Percentage Parsed : 30
# Frames Per Second : 57 || Percentage Parsed : 30
# Frames Per Second : 56 || Percentage Parsed : 30
# Frames Per Second : 57 || Percentage Parsed : 30
# Frames Per Second : 56 || Percentage Parsed : 30
# Frames Per Second : 56 || Percentage Parsed : 30
# Frames Per Second : 55 || Percentage Parsed : 30
# Frames Per Second : 56 || Percentage Parsed : 30
# Frames Per Second : 56 || Percentage Parsed : 30
# Frames Per Second : 55 || Percentage Parsed : 30
# Frames Per Second : 54 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 56 || Percentage Parsed : 31
# Frames Per Second : 56 || Percentage Parsed : 31
# Frames Per Second : 54 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 56 || Percentage Parsed : 31
# Frames Per Second : 51 || Percentage Parsed : 31
# Frames Per Second : 52 || Percentage Parsed : 31
# Frames Per Second : 52 || Percentage Parsed : 31
# Frames Per Second : 53 || Percentage Parsed : 32
# Frames Per Second : 52 || Percentage Parsed : 32
# Frames Per Second : 53 || Percentage Parsed : 32
# Frames Per Second : 53 || Percentage Parsed : 32
# Frames Per Second : 53 || Percentage Parsed : 32
# Frames Per Second : 53 || Percentage Parsed : 32
# Frames Per Second : 54 || Percentage Parsed : 32
# Frames Per Second : 54 || Percentage Parsed : 32
# Frames Per Second : 52 || Percentage Parsed : 32
# Frames Per Second : 52 || Percentage Parsed : 32
# Frames Per Second : 55 || Percentage Parsed : 32
# Frames Per Second : 56 || Percentage Parsed : 32
# Frames Per Second : 56 || Percentage Parsed : 32
# Frames Per Second : 56 || Percentage Parsed : 32
# Frames Per Second : 53 || Percentage Parsed : 32
# Frames Per Second : 52 || Percentage Parsed : 33
# Frames Per Second : 52 || Percentage Parsed : 33
# Frames Per Second : 52 || Percentage Parsed : 33
# Frames Per Second : 53 || Percentage Parsed : 33
# Frames Per Second : 52 || Percentage Parsed : 33
# Frames Per Second : 51 || Percentage Parsed : 33
# Frames Per Second : 52 || Percentage Parsed : 33
# Frames Per Second : 56 || Percentage Parsed : 33
# Frames Per Second : 52 || Percentage Parsed : 33
# Frames Per Second : 51 || Percentage Parsed : 33
# Frames Per Second : 50 || Percentage Parsed : 33
# Frames Per Second : 52 || Percentage Parsed : 33
# Frames Per Second : 51 || Percentage Parsed : 33
# Frames Per Second : 50 || Percentage Parsed : 33
# Frames Per Second : 50 || Percentage Parsed : 34
# Frames Per Second : 51 || Percentage Parsed : 34
# Frames Per Second : 51 || Percentage Parsed : 34
# Frames Per Second : 51 || Percentage Parsed : 34
# Frames Per Second : 52 || Percentage Parsed : 34
# Frames Per Second : 51 || Percentage Parsed : 34
# Frames Per Second : 51 || Percentage Parsed : 34
# Frames Per Second : 52 || Percentage Parsed : 34
# Frames Per Second : 56 || Percentage Parsed : 34
# Frames Per Second : 57 || Percentage Parsed : 34
# Frames Per Second : 57 || Percentage Parsed : 34
# Frames Per Second : 56 || Percentage Parsed : 34
# Frames Per Second : 56 || Percentage Parsed : 34
# Frames Per Second : 59 || Percentage Parsed : 34
# Frames Per Second : 57 || Percentage Parsed : 35
# Frames Per Second : 55 || Percentage Parsed : 35
# Frames Per Second : 55 || Percentage Parsed : 35
# Frames Per Second : 57 || Percentage Parsed : 35
# Frames Per Second : 55 || Percentage Parsed : 35
# Frames Per Second : 54 || Percentage Parsed : 35
# Frames Per Second : 55 || Percentage Parsed : 35
# Frames Per Second : 53 || Percentage Parsed : 35
# Frames Per Second : 54 || Percentage Parsed : 35
# Frames Per Second : 56 || Percentage Parsed : 35
# Frames Per Second : 56 || Percentage Parsed : 35
# Frames Per Second : 55 || Percentage Parsed : 35
# Frames Per Second : 55 || Percentage Parsed : 35
# Frames Per Second : 54 || Percentage Parsed : 35
# Frames Per Second : 55 || Percentage Parsed : 36
# Frames Per Second : 55 || Percentage Parsed : 36
# Frames Per Second : 53 || Percentage Parsed : 36
# Frames Per Second : 56 || Percentage Parsed : 36
# Frames Per Second : 55 || Percentage Parsed : 36
# Frames Per Second : 56 || Percentage Parsed : 36
# Frames Per Second : 56 || Percentage Parsed : 36
# Frames Per Second : 56 || Percentage Parsed : 36
# Frames Per Second : 56 || Percentage Parsed : 36
# Frames Per Second : 57 || Percentage Parsed : 36
# Frames Per Second : 56 || Percentage Parsed : 36
# Frames Per Second : 55 || Percentage Parsed : 36
# Frames Per Second : 56 || Percentage Parsed : 36
# Frames Per Second : 53 || Percentage Parsed : 36
# Frames Per Second : 54 || Percentage Parsed : 37
# Frames Per Second : 48 || Percentage Parsed : 37
# Frames Per Second : 51 || Percentage Parsed : 37
# Frames Per Second : 51 || Percentage Parsed : 37
# Frames Per Second : 51 || Percentage Parsed : 37
# Frames Per Second : 51 || Percentage Parsed : 37
# Frames Per Second : 52 || Percentage Parsed : 37
# Frames Per Second : 53 || Percentage Parsed : 37
# Frames Per Second : 49 || Percentage Parsed : 37
# Frames Per Second : 52 || Percentage Parsed : 37
# Frames Per Second : 54 || Percentage Parsed : 37
# Frames Per Second : 55 || Percentage Parsed : 37
# Frames Per Second : 55 || Percentage Parsed : 37
# Frames Per Second : 56 || Percentage Parsed : 37
# Frames Per Second : 57 || Percentage Parsed : 38
# Frames Per Second : 56 || Percentage Parsed : 38
# Frames Per Second : 56 || Percentage Parsed : 38
# Frames Per Second : 56 || Percentage Parsed : 38
# Frames Per Second : 55 || Percentage Parsed : 38
# Frames Per Second : 54 || Percentage Parsed : 38
# Frames Per Second : 55 || Percentage Parsed : 38
# Frames Per Second : 54 || Percentage Parsed : 38
# Frames Per Second : 55 || Percentage Parsed : 38
# Frames Per Second : 55 || Percentage Parsed : 38
# Frames Per Second : 54 || Percentage Parsed : 38
# Frames Per Second : 55 || Percentage Parsed : 38
# Frames Per Second : 56 || Percentage Parsed : 38
# Frames Per Second : 57 || Percentage Parsed : 38
# Frames Per Second : 55 || Percentage Parsed : 38
# Frames Per Second : 54 || Percentage Parsed : 39
# Frames Per Second : 52 || Percentage Parsed : 39
# Frames Per Second : 52 || Percentage Parsed : 39
# Frames Per Second : 50 || Percentage Parsed : 39
# Frames Per Second : 49 || Percentage Parsed : 39
# Frames Per Second : 51 || Percentage Parsed : 39
# Frames Per Second : 51 || Percentage Parsed : 39
# Frames Per Second : 47 || Percentage Parsed : 39
# Frames Per Second : 51 || Percentage Parsed : 39
# Frames Per Second : 55 || Percentage Parsed : 39
# Frames Per Second : 55 || Percentage Parsed : 39
# Frames Per Second : 54 || Percentage Parsed : 39
# Frames Per Second : 55 || Percentage Parsed : 39
# Frames Per Second : 53 || Percentage Parsed : 39
# Frames Per Second : 53 || Percentage Parsed : 40
# Frames Per Second : 54 || Percentage Parsed : 40
# Frames Per Second : 53 || Percentage Parsed : 40
# Frames Per Second : 55 || Percentage Parsed : 40
# Frames Per Second : 56 || Percentage Parsed : 40
# Frames Per Second : 56 || Percentage Parsed : 40
# Frames Per Second : 55 || Percentage Parsed : 40
# Frames Per Second : 54 || Percentage Parsed : 40
# Frames Per Second : 52 || Percentage Parsed : 40
# Frames Per Second : 49 || Percentage Parsed : 40
# Frames Per Second : 50 || Percentage Parsed : 40
# Frames Per Second : 51 || Percentage Parsed : 40
# Frames Per Second : 54 || Percentage Parsed : 40
# Frames Per Second : 54 || Percentage Parsed : 40
# Frames Per Second : 55 || Percentage Parsed : 41
# Frames Per Second : 56 || Percentage Parsed : 41
# Frames Per Second : 55 || Percentage Parsed : 41
# Frames Per Second : 57 || Percentage Parsed : 41
# Frames Per Second : 56 || Percentage Parsed : 41
# Frames Per Second : 55 || Percentage Parsed : 41
# Frames Per Second : 56 || Percentage Parsed : 41
# Frames Per Second : 56 || Percentage Parsed : 41
# Frames Per Second : 56 || Percentage Parsed : 41
# Frames Per Second : 56 || Percentage Parsed : 41
# Frames Per Second : 56 || Percentage Parsed : 41
# Frames Per Second : 52 || Percentage Parsed : 41
# Frames Per Second : 53 || Percentage Parsed : 41
# Frames Per Second : 53 || Percentage Parsed : 41
# Frames Per Second : 53 || Percentage Parsed : 42
# Frames Per Second : 50 || Percentage Parsed : 42
# Frames Per Second : 52 || Percentage Parsed : 42
# Frames Per Second : 52 || Percentage Parsed : 42
# Frames Per Second : 53 || Percentage Parsed : 42
# Frames Per Second : 55 || Percentage Parsed : 42
# Frames Per Second : 54 || Percentage Parsed : 42
# Frames Per Second : 56 || Percentage Parsed : 42
# Frames Per Second : 53 || Percentage Parsed : 42
# Frames Per Second : 52 || Percentage Parsed : 42
# Frames Per Second : 54 || Percentage Parsed : 42
# Frames Per Second : 54 || Percentage Parsed : 42
# Frames Per Second : 55 || Percentage Parsed : 42
# Frames Per Second : 51 || Percentage Parsed : 42
# Frames Per Second : 49 || Percentage Parsed : 43
# Frames Per Second : 49 || Percentage Parsed : 43
# Frames Per Second : 49 || Percentage Parsed : 43
# Frames Per Second : 51 || Percentage Parsed : 43
# Frames Per Second : 48 || Percentage Parsed : 43
# Frames Per Second : 48 || Percentage Parsed : 43
# Frames Per Second : 48 || Percentage Parsed : 43
# Frames Per Second : 49 || Percentage Parsed : 43
# Frames Per Second : 51 || Percentage Parsed : 43
# Frames Per Second : 52 || Percentage Parsed : 43
# Frames Per Second : 52 || Percentage Parsed : 43
# Frames Per Second : 50 || Percentage Parsed : 43
# Frames Per Second : 51 || Percentage Parsed : 43
# Frames Per Second : 53 || Percentage Parsed : 43
# Frames Per Second : 57 || Percentage Parsed : 43
# Frames Per Second : 57 || Percentage Parsed : 44
# Frames Per Second : 57 || Percentage Parsed : 44
# Frames Per Second : 57 || Percentage Parsed : 44
# Frames Per Second : 57 || Percentage Parsed : 44
# Frames Per Second : 55 || Percentage Parsed : 44
# Frames Per Second : 56 || Percentage Parsed : 44
# Frames Per Second : 54 || Percentage Parsed : 44
# Frames Per Second : 53 || Percentage Parsed : 44
# Frames Per Second : 52 || Percentage Parsed : 44
# Frames Per Second : 50 || Percentage Parsed : 44
# Frames Per Second : 50 || Percentage Parsed : 44
# Frames Per Second : 50 || Percentage Parsed : 44
# Frames Per Second : 49 || Percentage Parsed : 44
# Frames Per Second : 54 || Percentage Parsed : 44
# Frames Per Second : 57 || Percentage Parsed : 45
# Frames Per Second : 57 || Percentage Parsed : 45
# Frames Per Second : 56 || Percentage Parsed : 45
# Frames Per Second : 57 || Percentage Parsed : 45
# Frames Per Second : 55 || Percentage Parsed : 45
# Frames Per Second : 55 || Percentage Parsed : 45
# Frames Per Second : 56 || Percentage Parsed : 45
# Frames Per Second : 57 || Percentage Parsed : 45
# Frames Per Second : 58 || Percentage Parsed : 45
# Frames Per Second : 57 || Percentage Parsed : 45
# Frames Per Second : 55 || Percentage Parsed : 45
# Frames Per Second : 56 || Percentage Parsed : 45
# Frames Per Second : 55 || Percentage Parsed : 45
# Frames Per Second : 56 || Percentage Parsed : 45
# Frames Per Second : 54 || Percentage Parsed : 46
# Frames Per Second : 51 || Percentage Parsed : 46
# Frames Per Second : 53 || Percentage Parsed : 46
# Frames Per Second : 52 || Percentage Parsed : 46
# Frames Per Second : 52 || Percentage Parsed : 46
# Frames Per Second : 51 || Percentage Parsed : 46
# Frames Per Second : 51 || Percentage Parsed : 46
# Frames Per Second : 53 || Percentage Parsed : 46
# Frames Per Second : 52 || Percentage Parsed : 46
# Frames Per Second : 52 || Percentage Parsed : 46
# Frames Per Second : 52 || Percentage Parsed : 46
# Frames Per Second : 53 || Percentage Parsed : 46
# Frames Per Second : 52 || Percentage Parsed : 46
# Frames Per Second : 52 || Percentage Parsed : 46
# Frames Per Second : 53 || Percentage Parsed : 47
# Frames Per Second : 55 || Percentage Parsed : 47
# Frames Per Second : 55 || Percentage Parsed : 47
# Frames Per Second : 54 || Percentage Parsed : 47
# Frames Per Second : 55 || Percentage Parsed : 47
# Frames Per Second : 55 || Percentage Parsed : 47
# Frames Per Second : 55 || Percentage Parsed : 47
# Frames Per Second : 55 || Percentage Parsed : 47
# Frames Per Second : 57 || Percentage Parsed : 47
# Frames Per Second : 56 || Percentage Parsed : 47
# Frames Per Second : 56 || Percentage Parsed : 47
# Frames Per Second : 56 || Percentage Parsed : 47
# Frames Per Second : 55 || Percentage Parsed : 47
# Frames Per Second : 55 || Percentage Parsed : 47
# Frames Per Second : 55 || Percentage Parsed : 48
# Frames Per Second : 56 || Percentage Parsed : 48
# Frames Per Second : 52 || Percentage Parsed : 48
# Frames Per Second : 51 || Percentage Parsed : 48
# Frames Per Second : 51 || Percentage Parsed : 48
# Frames Per Second : 51 || Percentage Parsed : 48
# Frames Per Second : 54 || Percentage Parsed : 48
# Frames Per Second : 53 || Percentage Parsed : 48
# Frames Per Second : 53 || Percentage Parsed : 48
# Frames Per Second : 52 || Percentage Parsed : 48
# Frames Per Second : 54 || Percentage Parsed : 48
# Frames Per Second : 56 || Percentage Parsed : 48
# Frames Per Second : 57 || Percentage Parsed : 48
# Frames Per Second : 56 || Percentage Parsed : 48
# Frames Per Second : 56 || Percentage Parsed : 49
# Frames Per Second : 55 || Percentage Parsed : 49
# Frames Per Second : 56 || Percentage Parsed : 49
# Frames Per Second : 52 || Percentage Parsed : 49
# Frames Per Second : 53 || Percentage Parsed : 49
# Frames Per Second : 52 || Percentage Parsed : 49
# Frames Per Second : 51 || Percentage Parsed : 49
# Frames Per Second : 52 || Percentage Parsed : 49
# Frames Per Second : 52 || Percentage Parsed : 49
# Frames Per Second : 52 || Percentage Parsed : 49
# Frames Per Second : 55 || Percentage Parsed : 49
# Frames Per Second : 55 || Percentage Parsed : 49
# Frames Per Second : 55 || Percentage Parsed : 49
# Frames Per Second : 57 || Percentage Parsed : 49
# Frames Per Second : 56 || Percentage Parsed : 49
# Frames Per Second : 56 || Percentage Parsed : 50
# Frames Per Second : 54 || Percentage Parsed : 50
# Frames Per Second : 54 || Percentage Parsed : 50
# Frames Per Second : 54 || Percentage Parsed : 50
# Frames Per Second : 55 || Percentage Parsed : 50
# Frames Per Second : 55 || Percentage Parsed : 50
# Frames Per Second : 52 || Percentage Parsed : 50
# Frames Per Second : 53 || Percentage Parsed : 50
# Frames Per Second : 55 || Percentage Parsed : 50
# Frames Per Second : 56 || Percentage Parsed : 50
# Frames Per Second : 54 || Percentage Parsed : 50
# Frames Per Second : 55 || Percentage Parsed : 50
# Frames Per Second : 55 || Percentage Parsed : 50
# Frames Per Second : 56 || Percentage Parsed : 50
# Frames Per Second : 54 || Percentage Parsed : 51
# Frames Per Second : 53 || Percentage Parsed : 51
# Frames Per Second : 51 || Percentage Parsed : 51
# Frames Per Second : 52 || Percentage Parsed : 51
# Frames Per Second : 54 || Percentage Parsed : 51
# Frames Per Second : 51 || Percentage Parsed : 51
# Frames Per Second : 51 || Percentage Parsed : 51
# Frames Per Second : 50 || Percentage Parsed : 51
# Frames Per Second : 51 || Percentage Parsed : 51
# Frames Per Second : 51 || Percentage Parsed : 51
# Frames Per Second : 48 || Percentage Parsed : 51
# Frames Per Second : 49 || Percentage Parsed : 51
# Frames Per Second : 49 || Percentage Parsed : 51
# Frames Per Second : 49 || Percentage Parsed : 51
# Frames Per Second : 49 || Percentage Parsed : 52
# Frames Per Second : 50 || Percentage Parsed : 52
# Frames Per Second : 54 || Percentage Parsed : 52
# Frames Per Second : 54 || Percentage Parsed : 52
# Frames Per Second : 54 || Percentage Parsed : 52
# Frames Per Second : 54 || Percentage Parsed : 52
# Frames Per Second : 56 || Percentage Parsed : 52
# Frames Per Second : 57 || Percentage Parsed : 52
# Frames Per Second : 55 || Percentage Parsed : 52
# Frames Per Second : 56 || Percentage Parsed : 52
# Frames Per Second : 55 || Percentage Parsed : 52
# Frames Per Second : 55 || Percentage Parsed : 52
# Frames Per Second : 51 || Percentage Parsed : 52
# Frames Per Second : 49 || Percentage Parsed : 52
# Frames Per Second : 49 || Percentage Parsed : 53
# Frames Per Second : 48 || Percentage Parsed : 53
# Frames Per Second : 48 || Percentage Parsed : 53
# Frames Per Second : 48 || Percentage Parsed : 53
# Frames Per Second : 48 || Percentage Parsed : 53
# Frames Per Second : 48 || Percentage Parsed : 53
# Frames Per Second : 47 || Percentage Parsed : 53
# Frames Per Second : 47 || Percentage Parsed : 53
# Frames Per Second : 46 || Percentage Parsed : 53
# Frames Per Second : 46 || Percentage Parsed : 53
# Frames Per Second : 46 || Percentage Parsed : 53
# Frames Per Second : 46 || Percentage Parsed : 53
# Frames Per Second : 51 || Percentage Parsed : 53
# Frames Per Second : 57 || Percentage Parsed : 53
# Frames Per Second : 57 || Percentage Parsed : 54
# Frames Per Second : 57 || Percentage Parsed : 54
# Frames Per Second : 56 || Percentage Parsed : 54
# Frames Per Second : 56 || Percentage Parsed : 54
# Frames Per Second : 57 || Percentage Parsed : 54
# Frames Per Second : 58 || Percentage Parsed : 54
# Frames Per Second : 55 || Percentage Parsed : 54
# Frames Per Second : 55 || Percentage Parsed : 54
# Frames Per Second : 56 || Percentage Parsed : 54
# Frames Per Second : 56 || Percentage Parsed : 54
# Frames Per Second : 55 || Percentage Parsed : 54
# Frames Per Second : 55 || Percentage Parsed : 54
# Frames Per Second : 54 || Percentage Parsed : 54
# Frames Per Second : 51 || Percentage Parsed : 54
# Frames Per Second : 52 || Percentage Parsed : 54
# Frames Per Second : 53 || Percentage Parsed : 55
# Frames Per Second : 52 || Percentage Parsed : 55
# Frames Per Second : 51 || Percentage Parsed : 55
# Frames Per Second : 52 || Percentage Parsed : 55
# Frames Per Second : 49 || Percentage Parsed : 55
# Frames Per Second : 49 || Percentage Parsed : 55
# Frames Per Second : 47 || Percentage Parsed : 55
# Frames Per Second : 48 || Percentage Parsed : 55
# Frames Per Second : 48 || Percentage Parsed : 55
# Frames Per Second : 50 || Percentage Parsed : 55
# Frames Per Second : 52 || Percentage Parsed : 55
# Frames Per Second : 55 || Percentage Parsed : 55
# Frames Per Second : 56 || Percentage Parsed : 55
# Frames Per Second : 56 || Percentage Parsed : 55
# Frames Per Second : 56 || Percentage Parsed : 56
# Frames Per Second : 57 || Percentage Parsed : 56
# Frames Per Second : 58 || Percentage Parsed : 56
# Frames Per Second : 56 || Percentage Parsed : 56
# Frames Per Second : 56 || Percentage Parsed : 56
# Frames Per Second : 58 || Percentage Parsed : 56
# Frames Per Second : 58 || Percentage Parsed : 56
# Frames Per Second : 56 || Percentage Parsed : 56
# Frames Per Second : 57 || Percentage Parsed : 56
# Frames Per Second : 57 || Percentage Parsed : 56
# Frames Per Second : 56 || Percentage Parsed : 56
# Frames Per Second : 59 || Percentage Parsed : 56
# Frames Per Second : 57 || Percentage Parsed : 56
# Frames Per Second : 57 || Percentage Parsed : 56
# Frames Per Second : 58 || Percentage Parsed : 57
# Frames Per Second : 57 || Percentage Parsed : 57
# Frames Per Second : 56 || Percentage Parsed : 57
# Frames Per Second : 56 || Percentage Parsed : 57
# Frames Per Second : 57 || Percentage Parsed : 57
# Frames Per Second : 54 || Percentage Parsed : 57
# Frames Per Second : 54 || Percentage Parsed : 57
# Frames Per Second : 55 || Percentage Parsed : 57
# Frames Per Second : 55 || Percentage Parsed : 57
# Frames Per Second : 54 || Percentage Parsed : 57
# Frames Per Second : 55 || Percentage Parsed : 57
# Frames Per Second : 55 || Percentage Parsed : 57
# Frames Per Second : 55 || Percentage Parsed : 57
# Frames Per Second : 55 || Percentage Parsed : 57
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 56 || Percentage Parsed : 58
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 54 || Percentage Parsed : 58
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 53 || Percentage Parsed : 58
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 56 || Percentage Parsed : 58
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 57 || Percentage Parsed : 59
# Frames Per Second : 57 || Percentage Parsed : 59
# Frames Per Second : 53 || Percentage Parsed : 59
# Frames Per Second : 51 || Percentage Parsed : 59
# Frames Per Second : 51 || Percentage Parsed : 59
# Frames Per Second : 51 || Percentage Parsed : 59
# Frames Per Second : 51 || Percentage Parsed : 59
# Frames Per Second : 50 || Percentage Parsed : 59
# Frames Per Second : 50 || Percentage Parsed : 59
# Frames Per Second : 51 || Percentage Parsed : 59
# Frames Per Second : 50 || Percentage Parsed : 59
# Frames Per Second : 50 || Percentage Parsed : 59
# Frames Per Second : 54 || Percentage Parsed : 59
# Frames Per Second : 52 || Percentage Parsed : 59
# Frames Per Second : 54 || Percentage Parsed : 60
# Frames Per Second : 56 || Percentage Parsed : 60
# Frames Per Second : 55 || Percentage Parsed : 60
# Frames Per Second : 56 || Percentage Parsed : 60
# Frames Per Second : 55 || Percentage Parsed : 60
# Frames Per Second : 54 || Percentage Parsed : 60
# Frames Per Second : 55 || Percentage Parsed : 60
# Frames Per Second : 55 || Percentage Parsed : 60
# Frames Per Second : 55 || Percentage Parsed : 60
# Frames Per Second : 56 || Percentage Parsed : 60
# Frames Per Second : 55 || Percentage Parsed : 60
# Frames Per Second : 55 || Percentage Parsed : 60
# Frames Per Second : 55 || Percentage Parsed : 60
# Frames Per Second : 55 || Percentage Parsed : 60
# Frames Per Second : 54 || Percentage Parsed : 60
# Frames Per Second : 55 || Percentage Parsed : 61
# Frames Per Second : 55 || Percentage Parsed : 61
# Frames Per Second : 56 || Percentage Parsed : 61
# Frames Per Second : 55 || Percentage Parsed : 61
# Frames Per Second : 56 || Percentage Parsed : 61
# Frames Per Second : 57 || Percentage Parsed : 61
# Frames Per Second : 55 || Percentage Parsed : 61
# Frames Per Second : 56 || Percentage Parsed : 61
# Frames Per Second : 56 || Percentage Parsed : 61
# Frames Per Second : 56 || Percentage Parsed : 61
# Frames Per Second : 56 || Percentage Parsed : 61
# Frames Per Second : 54 || Percentage Parsed : 61
# Frames Per Second : 52 || Percentage Parsed : 61
# Frames Per Second : 52 || Percentage Parsed : 61
# Frames Per Second : 54 || Percentage Parsed : 62
# Frames Per Second : 52 || Percentage Parsed : 62
# Frames Per Second : 54 || Percentage Parsed : 62
# Frames Per Second : 56 || Percentage Parsed : 62
# Frames Per Second : 55 || Percentage Parsed : 62
# Frames Per Second : 55 || Percentage Parsed : 62
# Frames Per Second : 56 || Percentage Parsed : 62
# Frames Per Second : 55 || Percentage Parsed : 62
# Frames Per Second : 55 || Percentage Parsed : 62
# Frames Per Second : 56 || Percentage Parsed : 62
# Frames Per Second : 55 || Percentage Parsed : 62
# Frames Per Second : 56 || Percentage Parsed : 62
# Frames Per Second : 56 || Percentage Parsed : 62
# Frames Per Second : 55 || Percentage Parsed : 62
# Frames Per Second : 55 || Percentage Parsed : 63
# Frames Per Second : 55 || Percentage Parsed : 63
# Frames Per Second : 56 || Percentage Parsed : 63
# Frames Per Second : 56 || Percentage Parsed : 63
# Frames Per Second : 56 || Percentage Parsed : 63
# Frames Per Second : 55 || Percentage Parsed : 63
# Frames Per Second : 56 || Percentage Parsed : 63
# Frames Per Second : 55 || Percentage Parsed : 63
# Frames Per Second : 55 || Percentage Parsed : 63
# Frames Per Second : 55 || Percentage Parsed : 63
# Frames Per Second : 55 || Percentage Parsed : 63
# Frames Per Second : 55 || Percentage Parsed : 63
# Frames Per Second : 57 || Percentage Parsed : 63
# Frames Per Second : 56 || Percentage Parsed : 63
# Frames Per Second : 55 || Percentage Parsed : 64
# Frames Per Second : 53 || Percentage Parsed : 64
# Frames Per Second : 53 || Percentage Parsed : 64
# Frames Per Second : 55 || Percentage Parsed : 64
# Frames Per Second : 55 || Percentage Parsed : 64
# Frames Per Second : 56 || Percentage Parsed : 64
# Frames Per Second : 57 || Percentage Parsed : 64
# Frames Per Second : 57 || Percentage Parsed : 64
# Frames Per Second : 56 || Percentage Parsed : 64
# Frames Per Second : 57 || Percentage Parsed : 64
# Frames Per Second : 57 || Percentage Parsed : 64
# Frames Per Second : 57 || Percentage Parsed : 64
# Frames Per Second : 55 || Percentage Parsed : 64
# Frames Per Second : 55 || Percentage Parsed : 64
# Frames Per Second : 52 || Percentage Parsed : 65
# Frames Per Second : 51 || Percentage Parsed : 65
# Frames Per Second : 55 || Percentage Parsed : 65
# Frames Per Second : 55 || Percentage Parsed : 65
# Frames Per Second : 56 || Percentage Parsed : 65
# Frames Per Second : 56 || Percentage Parsed : 65
# Frames Per Second : 57 || Percentage Parsed : 65
# Frames Per Second : 58 || Percentage Parsed : 65
# Frames Per Second : 57 || Percentage Parsed : 65
# Frames Per Second : 55 || Percentage Parsed : 65
# Frames Per Second : 55 || Percentage Parsed : 65
# Frames Per Second : 55 || Percentage Parsed : 65
# Frames Per Second : 56 || Percentage Parsed : 65
# Frames Per Second : 54 || Percentage Parsed : 65
# Frames Per Second : 53 || Percentage Parsed : 65
# Frames Per Second : 52 || Percentage Parsed : 66
# Frames Per Second : 55 || Percentage Parsed : 66
# Frames Per Second : 55 || Percentage Parsed : 66
# Frames Per Second : 55 || Percentage Parsed : 66
# Frames Per Second : 56 || Percentage Parsed : 66
# Frames Per Second : 56 || Percentage Parsed : 66
# Frames Per Second : 54 || Percentage Parsed : 66
# Frames Per Second : 53 || Percentage Parsed : 66
# Frames Per Second : 52 || Percentage Parsed : 66
# Frames Per Second : 54 || Percentage Parsed : 66
# Frames Per Second : 56 || Percentage Parsed : 66
# Frames Per Second : 56 || Percentage Parsed : 66
# Frames Per Second : 56 || Percentage Parsed : 66
# Frames Per Second : 55 || Percentage Parsed : 66
# Completed!

# %% [markdown]
# Salvamos el video resultante del proceso en nuestro Drive:

# %%
# Input video path
save_path = "/content/fuerzas_armadas_yolov5.mp4"

# Compressed video path
compressed_path = "/content/fuerzas_armadas_yolov5_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")
# Out:
# 0

# %%
shutil.copy(
    "/content/fuerzas_armadas_yolov5_compressed.mp4",
    "/content/drive/MyDrive/tfg/videos/fuerzas_armadas_yolov5_compressed.mp4"
)
# Out:
# '/content/drive/MyDrive/tfg/videos/fuerzas_armadas_yolov5_compressed.mp4'

# %%
shutil.rmtree("/content/runs")

# %% [markdown]
# ## YOLOv5 con Data Augmentation

# %%
zip_path = "/content/drive/MyDrive/tfg/models/runs_yolov5_augmented.zip"
extract_path = "/content/"
# !unzip -q "$zip_path" -d "$extract_path"

# %%
model = YOLO("runs/detect/train/weights/best.pt")

# %%
yolov5_rtod = VideoParserObjectDetectionModel(model, YOLO_FNS, CLASS_INFO)

# %%
yolov5_rtod(URL, "fuerzas_armadas_yolov5_augmented.mp4")
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=xV24-uVq3WY
# [youtube] xV24-uVq3WY: Downloading webpage
# [youtube] xV24-uVq3WY: Downloading tv client config
# [youtube] xV24-uVq3WY: Downloading tv player API JSON
# [youtube] xV24-uVq3WY: Downloading ios player API JSON
# [youtube] xV24-uVq3WY: Downloading m3u8 information
# Frames Per Second : 44 || Percentage Parsed : 0
# Frames Per Second : 52 || Percentage Parsed : 0
# Frames Per Second : 52 || Percentage Parsed : 0
# Frames Per Second : 53 || Percentage Parsed : 0
# Frames Per Second : 53 || Percentage Parsed : 0
# Frames Per Second : 50 || Percentage Parsed : 0
# Frames Per Second : 53 || Percentage Parsed : 0
# Frames Per Second : 54 || Percentage Parsed : 0
# Frames Per Second : 53 || Percentage Parsed : 0
# Frames Per Second : 53 || Percentage Parsed : 0
# Frames Per Second : 54 || Percentage Parsed : 0
# Frames Per Second : 54 || Percentage Parsed : 0
# Frames Per Second : 54 || Percentage Parsed : 0
# Frames Per Second : 54 || Percentage Parsed : 0
# Frames Per Second : 53 || Percentage Parsed : 1
# Frames Per Second : 54 || Percentage Parsed : 1
# Frames Per Second : 52 || Percentage Parsed : 1
# Frames Per Second : 53 || Percentage Parsed : 1
# Frames Per Second : 52 || Percentage Parsed : 1
# Frames Per Second : 53 || Percentage Parsed : 1
# Frames Per Second : 53 || Percentage Parsed : 1
# Frames Per Second : 54 || Percentage Parsed : 1
# Frames Per Second : 54 || Percentage Parsed : 1
# Frames Per Second : 54 || Percentage Parsed : 1
# Frames Per Second : 55 || Percentage Parsed : 1
# Frames Per Second : 53 || Percentage Parsed : 1
# Frames Per Second : 54 || Percentage Parsed : 1
# Frames Per Second : 53 || Percentage Parsed : 1
# Frames Per Second : 54 || Percentage Parsed : 2
# Frames Per Second : 54 || Percentage Parsed : 2
# Frames Per Second : 53 || Percentage Parsed : 2
# Frames Per Second : 53 || Percentage Parsed : 2
# Frames Per Second : 53 || Percentage Parsed : 2
# Frames Per Second : 54 || Percentage Parsed : 2
# Frames Per Second : 53 || Percentage Parsed : 2
# Frames Per Second : 53 || Percentage Parsed : 2
# Frames Per Second : 53 || Percentage Parsed : 2
# Frames Per Second : 53 || Percentage Parsed : 2
# Frames Per Second : 52 || Percentage Parsed : 2
# Frames Per Second : 54 || Percentage Parsed : 2
# Frames Per Second : 53 || Percentage Parsed : 2
# Frames Per Second : 51 || Percentage Parsed : 2
# Frames Per Second : 52 || Percentage Parsed : 3
# Frames Per Second : 52 || Percentage Parsed : 3
# Frames Per Second : 52 || Percentage Parsed : 3
# Frames Per Second : 50 || Percentage Parsed : 3
# Frames Per Second : 53 || Percentage Parsed : 3
# Frames Per Second : 54 || Percentage Parsed : 3
# Frames Per Second : 54 || Percentage Parsed : 3
# Frames Per Second : 53 || Percentage Parsed : 3
# Frames Per Second : 53 || Percentage Parsed : 3
# Frames Per Second : 52 || Percentage Parsed : 3
# Frames Per Second : 54 || Percentage Parsed : 3
# Frames Per Second : 55 || Percentage Parsed : 3
# Frames Per Second : 53 || Percentage Parsed : 3
# Frames Per Second : 54 || Percentage Parsed : 3
# Frames Per Second : 53 || Percentage Parsed : 4
# Frames Per Second : 53 || Percentage Parsed : 4
# Frames Per Second : 53 || Percentage Parsed : 4
# Frames Per Second : 53 || Percentage Parsed : 4
# Frames Per Second : 53 || Percentage Parsed : 4
# Frames Per Second : 52 || Percentage Parsed : 4
# Frames Per Second : 54 || Percentage Parsed : 4
# Frames Per Second : 54 || Percentage Parsed : 4
# Frames Per Second : 55 || Percentage Parsed : 4
# Frames Per Second : 53 || Percentage Parsed : 4
# Frames Per Second : 54 || Percentage Parsed : 4
# Frames Per Second : 54 || Percentage Parsed : 4
# Frames Per Second : 53 || Percentage Parsed : 4
# Frames Per Second : 55 || Percentage Parsed : 4
# Frames Per Second : 54 || Percentage Parsed : 5
# Frames Per Second : 55 || Percentage Parsed : 5
# Frames Per Second : 54 || Percentage Parsed : 5
# Frames Per Second : 53 || Percentage Parsed : 5
# Frames Per Second : 53 || Percentage Parsed : 5
# Frames Per Second : 53 || Percentage Parsed : 5
# Frames Per Second : 53 || Percentage Parsed : 5
# Frames Per Second : 53 || Percentage Parsed : 5
# Frames Per Second : 54 || Percentage Parsed : 5
# Frames Per Second : 55 || Percentage Parsed : 5
# Frames Per Second : 55 || Percentage Parsed : 5
# Frames Per Second : 54 || Percentage Parsed : 5
# Frames Per Second : 54 || Percentage Parsed : 5
# Frames Per Second : 54 || Percentage Parsed : 5
# Frames Per Second : 55 || Percentage Parsed : 5
# Frames Per Second : 55 || Percentage Parsed : 6
# Frames Per Second : 54 || Percentage Parsed : 6
# Frames Per Second : 55 || Percentage Parsed : 6
# Frames Per Second : 54 || Percentage Parsed : 6
# Frames Per Second : 53 || Percentage Parsed : 6
# Frames Per Second : 55 || Percentage Parsed : 6
# Frames Per Second : 55 || Percentage Parsed : 6
# Frames Per Second : 54 || Percentage Parsed : 6
# Frames Per Second : 54 || Percentage Parsed : 6
# Frames Per Second : 53 || Percentage Parsed : 6
# Frames Per Second : 53 || Percentage Parsed : 6
# Frames Per Second : 53 || Percentage Parsed : 6
# Frames Per Second : 53 || Percentage Parsed : 6
# Frames Per Second : 55 || Percentage Parsed : 6
# Frames Per Second : 55 || Percentage Parsed : 7
# Frames Per Second : 55 || Percentage Parsed : 7
# Frames Per Second : 55 || Percentage Parsed : 7
# Frames Per Second : 55 || Percentage Parsed : 7
# Frames Per Second : 55 || Percentage Parsed : 7
# Frames Per Second : 56 || Percentage Parsed : 7
# Frames Per Second : 56 || Percentage Parsed : 7
# Frames Per Second : 55 || Percentage Parsed : 7
# Frames Per Second : 54 || Percentage Parsed : 7
# Frames Per Second : 55 || Percentage Parsed : 7
# Frames Per Second : 55 || Percentage Parsed : 7
# Frames Per Second : 54 || Percentage Parsed : 7
# Frames Per Second : 54 || Percentage Parsed : 7
# Frames Per Second : 53 || Percentage Parsed : 7
# Frames Per Second : 54 || Percentage Parsed : 8
# Frames Per Second : 55 || Percentage Parsed : 8
# Frames Per Second : 55 || Percentage Parsed : 8
# Frames Per Second : 54 || Percentage Parsed : 8
# Frames Per Second : 55 || Percentage Parsed : 8
# Frames Per Second : 55 || Percentage Parsed : 8
# Frames Per Second : 55 || Percentage Parsed : 8
# Frames Per Second : 54 || Percentage Parsed : 8
# Frames Per Second : 55 || Percentage Parsed : 8
# Frames Per Second : 56 || Percentage Parsed : 8
# Frames Per Second : 55 || Percentage Parsed : 8
# Frames Per Second : 55 || Percentage Parsed : 8
# Frames Per Second : 55 || Percentage Parsed : 8
# Frames Per Second : 55 || Percentage Parsed : 8
# Frames Per Second : 52 || Percentage Parsed : 9
# Frames Per Second : 54 || Percentage Parsed : 9
# Frames Per Second : 55 || Percentage Parsed : 9
# Frames Per Second : 54 || Percentage Parsed : 9
# Frames Per Second : 54 || Percentage Parsed : 9
# Frames Per Second : 55 || Percentage Parsed : 9
# Frames Per Second : 55 || Percentage Parsed : 9
# Frames Per Second : 53 || Percentage Parsed : 9
# Frames Per Second : 55 || Percentage Parsed : 9
# Frames Per Second : 55 || Percentage Parsed : 9
# Frames Per Second : 56 || Percentage Parsed : 9
# Frames Per Second : 56 || Percentage Parsed : 9
# Frames Per Second : 55 || Percentage Parsed : 9
# Frames Per Second : 55 || Percentage Parsed : 9
# Frames Per Second : 55 || Percentage Parsed : 10
# Frames Per Second : 56 || Percentage Parsed : 10
# Frames Per Second : 56 || Percentage Parsed : 10
# Frames Per Second : 56 || Percentage Parsed : 10
# Frames Per Second : 55 || Percentage Parsed : 10
# Frames Per Second : 53 || Percentage Parsed : 10
# Frames Per Second : 55 || Percentage Parsed : 10
# Frames Per Second : 54 || Percentage Parsed : 10
# Frames Per Second : 54 || Percentage Parsed : 10
# Frames Per Second : 53 || Percentage Parsed : 10
# Frames Per Second : 55 || Percentage Parsed : 10
# Frames Per Second : 54 || Percentage Parsed : 10
# Frames Per Second : 54 || Percentage Parsed : 10
# Frames Per Second : 54 || Percentage Parsed : 10
# Frames Per Second : 54 || Percentage Parsed : 10
# Frames Per Second : 53 || Percentage Parsed : 11
# Frames Per Second : 51 || Percentage Parsed : 11
# Frames Per Second : 53 || Percentage Parsed : 11
# Frames Per Second : 54 || Percentage Parsed : 11
# Frames Per Second : 54 || Percentage Parsed : 11
# Frames Per Second : 54 || Percentage Parsed : 11
# Frames Per Second : 54 || Percentage Parsed : 11
# Frames Per Second : 56 || Percentage Parsed : 11
# Frames Per Second : 55 || Percentage Parsed : 11
# Frames Per Second : 54 || Percentage Parsed : 11
# Frames Per Second : 54 || Percentage Parsed : 11
# Frames Per Second : 54 || Percentage Parsed : 11
# Frames Per Second : 54 || Percentage Parsed : 11
# Frames Per Second : 56 || Percentage Parsed : 11
# Frames Per Second : 54 || Percentage Parsed : 12
# Frames Per Second : 54 || Percentage Parsed : 12
# Frames Per Second : 54 || Percentage Parsed : 12
# Frames Per Second : 54 || Percentage Parsed : 12
# Frames Per Second : 55 || Percentage Parsed : 12
# Frames Per Second : 56 || Percentage Parsed : 12
# Frames Per Second : 54 || Percentage Parsed : 12
# Frames Per Second : 54 || Percentage Parsed : 12
# Frames Per Second : 54 || Percentage Parsed : 12
# Frames Per Second : 54 || Percentage Parsed : 12
# Frames Per Second : 54 || Percentage Parsed : 12
# Frames Per Second : 54 || Percentage Parsed : 12
# Frames Per Second : 52 || Percentage Parsed : 12
# Frames Per Second : 54 || Percentage Parsed : 12
# Frames Per Second : 54 || Percentage Parsed : 13
# Frames Per Second : 54 || Percentage Parsed : 13
# Frames Per Second : 52 || Percentage Parsed : 13
# Frames Per Second : 55 || Percentage Parsed : 13
# Frames Per Second : 54 || Percentage Parsed : 13
# Frames Per Second : 53 || Percentage Parsed : 13
# Frames Per Second : 54 || Percentage Parsed : 13
# Frames Per Second : 53 || Percentage Parsed : 13
# Frames Per Second : 54 || Percentage Parsed : 13
# Frames Per Second : 55 || Percentage Parsed : 13
# Frames Per Second : 53 || Percentage Parsed : 13
# Frames Per Second : 54 || Percentage Parsed : 13
# Frames Per Second : 55 || Percentage Parsed : 13
# Frames Per Second : 55 || Percentage Parsed : 13
# Frames Per Second : 55 || Percentage Parsed : 14
# Frames Per Second : 55 || Percentage Parsed : 14
# Frames Per Second : 54 || Percentage Parsed : 14
# Frames Per Second : 54 || Percentage Parsed : 14
# Frames Per Second : 56 || Percentage Parsed : 14
# Frames Per Second : 52 || Percentage Parsed : 14
# Frames Per Second : 51 || Percentage Parsed : 14
# Frames Per Second : 53 || Percentage Parsed : 14
# Frames Per Second : 55 || Percentage Parsed : 14
# Frames Per Second : 55 || Percentage Parsed : 14
# Frames Per Second : 55 || Percentage Parsed : 14
# Frames Per Second : 53 || Percentage Parsed : 14
# Frames Per Second : 54 || Percentage Parsed : 14
# Frames Per Second : 54 || Percentage Parsed : 14
# Frames Per Second : 55 || Percentage Parsed : 15
# Frames Per Second : 55 || Percentage Parsed : 15
# Frames Per Second : 55 || Percentage Parsed : 15
# Frames Per Second : 55 || Percentage Parsed : 15
# Frames Per Second : 56 || Percentage Parsed : 15
# Frames Per Second : 55 || Percentage Parsed : 15
# Frames Per Second : 55 || Percentage Parsed : 15
# Frames Per Second : 56 || Percentage Parsed : 15
# Frames Per Second : 54 || Percentage Parsed : 15
# Frames Per Second : 55 || Percentage Parsed : 15
# Frames Per Second : 55 || Percentage Parsed : 15
# Frames Per Second : 56 || Percentage Parsed : 15
# Frames Per Second : 55 || Percentage Parsed : 15
# Frames Per Second : 55 || Percentage Parsed : 15
# Frames Per Second : 55 || Percentage Parsed : 16
# Frames Per Second : 56 || Percentage Parsed : 16
# Frames Per Second : 55 || Percentage Parsed : 16
# Frames Per Second : 55 || Percentage Parsed : 16
# Frames Per Second : 55 || Percentage Parsed : 16
# Frames Per Second : 55 || Percentage Parsed : 16
# Frames Per Second : 55 || Percentage Parsed : 16
# Frames Per Second : 55 || Percentage Parsed : 16
# Frames Per Second : 55 || Percentage Parsed : 16
# Frames Per Second : 55 || Percentage Parsed : 16
# Frames Per Second : 55 || Percentage Parsed : 16
# Frames Per Second : 53 || Percentage Parsed : 16
# Frames Per Second : 51 || Percentage Parsed : 16
# Frames Per Second : 52 || Percentage Parsed : 16
# Frames Per Second : 53 || Percentage Parsed : 16
# Frames Per Second : 53 || Percentage Parsed : 17
# Frames Per Second : 55 || Percentage Parsed : 17
# Frames Per Second : 55 || Percentage Parsed : 17
# Frames Per Second : 56 || Percentage Parsed : 17
# Frames Per Second : 56 || Percentage Parsed : 17
# Frames Per Second : 56 || Percentage Parsed : 17
# Frames Per Second : 55 || Percentage Parsed : 17
# Frames Per Second : 56 || Percentage Parsed : 17
# Frames Per Second : 55 || Percentage Parsed : 17
# Frames Per Second : 56 || Percentage Parsed : 17
# Frames Per Second : 55 || Percentage Parsed : 17
# Frames Per Second : 52 || Percentage Parsed : 17
# Frames Per Second : 53 || Percentage Parsed : 17
# Frames Per Second : 54 || Percentage Parsed : 17
# Frames Per Second : 53 || Percentage Parsed : 18
# Frames Per Second : 52 || Percentage Parsed : 18
# Frames Per Second : 49 || Percentage Parsed : 18
# Frames Per Second : 53 || Percentage Parsed : 18
# Frames Per Second : 52 || Percentage Parsed : 18
# Frames Per Second : 52 || Percentage Parsed : 18
# Frames Per Second : 52 || Percentage Parsed : 18
# Frames Per Second : 50 || Percentage Parsed : 18
# Frames Per Second : 52 || Percentage Parsed : 18
# Frames Per Second : 51 || Percentage Parsed : 18
# Frames Per Second : 51 || Percentage Parsed : 18
# Frames Per Second : 52 || Percentage Parsed : 18
# Frames Per Second : 55 || Percentage Parsed : 18
# Frames Per Second : 55 || Percentage Parsed : 18
# Frames Per Second : 55 || Percentage Parsed : 19
# Frames Per Second : 54 || Percentage Parsed : 19
# Frames Per Second : 55 || Percentage Parsed : 19
# Frames Per Second : 55 || Percentage Parsed : 19
# Frames Per Second : 52 || Percentage Parsed : 19
# Frames Per Second : 55 || Percentage Parsed : 19
# Frames Per Second : 54 || Percentage Parsed : 19
# Frames Per Second : 55 || Percentage Parsed : 19
# Frames Per Second : 54 || Percentage Parsed : 19
# Frames Per Second : 54 || Percentage Parsed : 19
# Frames Per Second : 55 || Percentage Parsed : 19
# Frames Per Second : 54 || Percentage Parsed : 19
# Frames Per Second : 54 || Percentage Parsed : 19
# Frames Per Second : 54 || Percentage Parsed : 19
# Frames Per Second : 55 || Percentage Parsed : 20
# Frames Per Second : 55 || Percentage Parsed : 20
# Frames Per Second : 55 || Percentage Parsed : 20
# Frames Per Second : 55 || Percentage Parsed : 20
# Frames Per Second : 56 || Percentage Parsed : 20
# Frames Per Second : 55 || Percentage Parsed : 20
# Frames Per Second : 57 || Percentage Parsed : 20
# Frames Per Second : 55 || Percentage Parsed : 20
# Frames Per Second : 55 || Percentage Parsed : 20
# Frames Per Second : 54 || Percentage Parsed : 20
# Frames Per Second : 54 || Percentage Parsed : 20
# Frames Per Second : 52 || Percentage Parsed : 20
# Frames Per Second : 52 || Percentage Parsed : 20
# Frames Per Second : 53 || Percentage Parsed : 20
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 54 || Percentage Parsed : 21
# Frames Per Second : 54 || Percentage Parsed : 21
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 54 || Percentage Parsed : 21
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 56 || Percentage Parsed : 21
# Frames Per Second : 55 || Percentage Parsed : 22
# Frames Per Second : 56 || Percentage Parsed : 22
# Frames Per Second : 55 || Percentage Parsed : 22
# Frames Per Second : 55 || Percentage Parsed : 22
# Frames Per Second : 55 || Percentage Parsed : 22
# Frames Per Second : 54 || Percentage Parsed : 22
# Frames Per Second : 54 || Percentage Parsed : 22
# Frames Per Second : 53 || Percentage Parsed : 22
# Frames Per Second : 55 || Percentage Parsed : 22
# Frames Per Second : 55 || Percentage Parsed : 22
# Frames Per Second : 56 || Percentage Parsed : 22
# Frames Per Second : 55 || Percentage Parsed : 22
# Frames Per Second : 55 || Percentage Parsed : 22
# Frames Per Second : 55 || Percentage Parsed : 22
# Frames Per Second : 54 || Percentage Parsed : 23
# Frames Per Second : 56 || Percentage Parsed : 23
# Frames Per Second : 55 || Percentage Parsed : 23
# Frames Per Second : 55 || Percentage Parsed : 23
# Frames Per Second : 55 || Percentage Parsed : 23
# Frames Per Second : 55 || Percentage Parsed : 23
# Frames Per Second : 54 || Percentage Parsed : 23
# Frames Per Second : 55 || Percentage Parsed : 23
# Frames Per Second : 55 || Percentage Parsed : 23
# Frames Per Second : 55 || Percentage Parsed : 23
# Frames Per Second : 54 || Percentage Parsed : 23
# Frames Per Second : 55 || Percentage Parsed : 23
# Frames Per Second : 56 || Percentage Parsed : 23
# Frames Per Second : 56 || Percentage Parsed : 23
# Frames Per Second : 55 || Percentage Parsed : 24
# Frames Per Second : 54 || Percentage Parsed : 24
# Frames Per Second : 56 || Percentage Parsed : 24
# Frames Per Second : 55 || Percentage Parsed : 24
# Frames Per Second : 55 || Percentage Parsed : 24
# Frames Per Second : 55 || Percentage Parsed : 24
# Frames Per Second : 55 || Percentage Parsed : 24
# Frames Per Second : 55 || Percentage Parsed : 24
# Frames Per Second : 55 || Percentage Parsed : 24
# Frames Per Second : 55 || Percentage Parsed : 24
# Frames Per Second : 55 || Percentage Parsed : 24
# Frames Per Second : 55 || Percentage Parsed : 24
# Frames Per Second : 55 || Percentage Parsed : 24
# Frames Per Second : 55 || Percentage Parsed : 24
# Frames Per Second : 55 || Percentage Parsed : 25
# Frames Per Second : 55 || Percentage Parsed : 25
# Frames Per Second : 55 || Percentage Parsed : 25
# Frames Per Second : 56 || Percentage Parsed : 25
# Frames Per Second : 56 || Percentage Parsed : 25
# Frames Per Second : 55 || Percentage Parsed : 25
# Frames Per Second : 56 || Percentage Parsed : 25
# Frames Per Second : 56 || Percentage Parsed : 25
# Frames Per Second : 55 || Percentage Parsed : 25
# Frames Per Second : 55 || Percentage Parsed : 25
# Frames Per Second : 56 || Percentage Parsed : 25
# Frames Per Second : 55 || Percentage Parsed : 25
# Frames Per Second : 55 || Percentage Parsed : 25
# Frames Per Second : 55 || Percentage Parsed : 25
# Frames Per Second : 56 || Percentage Parsed : 26
# Frames Per Second : 55 || Percentage Parsed : 26
# Frames Per Second : 56 || Percentage Parsed : 26
# Frames Per Second : 55 || Percentage Parsed : 26
# Frames Per Second : 56 || Percentage Parsed : 26
# Frames Per Second : 56 || Percentage Parsed : 26
# Frames Per Second : 55 || Percentage Parsed : 26
# Frames Per Second : 55 || Percentage Parsed : 26
# Frames Per Second : 56 || Percentage Parsed : 26
# Frames Per Second : 55 || Percentage Parsed : 26
# Frames Per Second : 55 || Percentage Parsed : 26
# Frames Per Second : 54 || Percentage Parsed : 26
# Frames Per Second : 54 || Percentage Parsed : 26
# Frames Per Second : 55 || Percentage Parsed : 26
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 56 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 54 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 56 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 28
# Frames Per Second : 55 || Percentage Parsed : 28
# Frames Per Second : 55 || Percentage Parsed : 28
# Frames Per Second : 53 || Percentage Parsed : 28
# Frames Per Second : 55 || Percentage Parsed : 28
# Frames Per Second : 55 || Percentage Parsed : 28
# Frames Per Second : 56 || Percentage Parsed : 28
# Frames Per Second : 55 || Percentage Parsed : 28
# Frames Per Second : 56 || Percentage Parsed : 28
# Frames Per Second : 55 || Percentage Parsed : 28
# Frames Per Second : 55 || Percentage Parsed : 28
# Frames Per Second : 55 || Percentage Parsed : 28
# Frames Per Second : 56 || Percentage Parsed : 28
# Frames Per Second : 56 || Percentage Parsed : 28
# Frames Per Second : 55 || Percentage Parsed : 29
# Frames Per Second : 54 || Percentage Parsed : 29
# Frames Per Second : 55 || Percentage Parsed : 29
# Frames Per Second : 55 || Percentage Parsed : 29
# Frames Per Second : 52 || Percentage Parsed : 29
# Frames Per Second : 51 || Percentage Parsed : 29
# Frames Per Second : 51 || Percentage Parsed : 29
# Frames Per Second : 50 || Percentage Parsed : 29
# Frames Per Second : 50 || Percentage Parsed : 29
# Frames Per Second : 51 || Percentage Parsed : 29
# Frames Per Second : 50 || Percentage Parsed : 29
# Frames Per Second : 50 || Percentage Parsed : 29
# Frames Per Second : 49 || Percentage Parsed : 29
# Frames Per Second : 51 || Percentage Parsed : 29
# Frames Per Second : 50 || Percentage Parsed : 30
# Frames Per Second : 50 || Percentage Parsed : 30
# Frames Per Second : 54 || Percentage Parsed : 30
# Frames Per Second : 56 || Percentage Parsed : 30
# Frames Per Second : 56 || Percentage Parsed : 30
# Frames Per Second : 54 || Percentage Parsed : 30
# Frames Per Second : 55 || Percentage Parsed : 30
# Frames Per Second : 56 || Percentage Parsed : 30
# Frames Per Second : 55 || Percentage Parsed : 30
# Frames Per Second : 55 || Percentage Parsed : 30
# Frames Per Second : 54 || Percentage Parsed : 30
# Frames Per Second : 52 || Percentage Parsed : 30
# Frames Per Second : 53 || Percentage Parsed : 30
# Frames Per Second : 55 || Percentage Parsed : 30
# Frames Per Second : 56 || Percentage Parsed : 31
# Frames Per Second : 56 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 56 || Percentage Parsed : 31
# Frames Per Second : 56 || Percentage Parsed : 31
# Frames Per Second : 56 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 32
# Frames Per Second : 55 || Percentage Parsed : 32
# Frames Per Second : 56 || Percentage Parsed : 32
# Frames Per Second : 57 || Percentage Parsed : 32
# Frames Per Second : 57 || Percentage Parsed : 32
# Frames Per Second : 55 || Percentage Parsed : 32
# Frames Per Second : 55 || Percentage Parsed : 32
# Frames Per Second : 55 || Percentage Parsed : 32
# Frames Per Second : 55 || Percentage Parsed : 32
# Frames Per Second : 52 || Percentage Parsed : 32
# Frames Per Second : 53 || Percentage Parsed : 32
# Frames Per Second : 55 || Percentage Parsed : 32
# Frames Per Second : 56 || Percentage Parsed : 32
# Frames Per Second : 56 || Percentage Parsed : 32
# Frames Per Second : 56 || Percentage Parsed : 32
# Frames Per Second : 54 || Percentage Parsed : 33
# Frames Per Second : 53 || Percentage Parsed : 33
# Frames Per Second : 51 || Percentage Parsed : 33
# Frames Per Second : 53 || Percentage Parsed : 33
# Frames Per Second : 52 || Percentage Parsed : 33
# Frames Per Second : 54 || Percentage Parsed : 33
# Frames Per Second : 55 || Percentage Parsed : 33
# Frames Per Second : 55 || Percentage Parsed : 33
# Frames Per Second : 55 || Percentage Parsed : 33
# Frames Per Second : 55 || Percentage Parsed : 33
# Frames Per Second : 55 || Percentage Parsed : 33
# Frames Per Second : 54 || Percentage Parsed : 33
# Frames Per Second : 54 || Percentage Parsed : 33
# Frames Per Second : 55 || Percentage Parsed : 33
# Frames Per Second : 54 || Percentage Parsed : 34
# Frames Per Second : 52 || Percentage Parsed : 34
# Frames Per Second : 51 || Percentage Parsed : 34
# Frames Per Second : 50 || Percentage Parsed : 34
# Frames Per Second : 50 || Percentage Parsed : 34
# Frames Per Second : 49 || Percentage Parsed : 34
# Frames Per Second : 50 || Percentage Parsed : 34
# Frames Per Second : 52 || Percentage Parsed : 34
# Frames Per Second : 53 || Percentage Parsed : 34
# Frames Per Second : 53 || Percentage Parsed : 34
# Frames Per Second : 55 || Percentage Parsed : 34
# Frames Per Second : 56 || Percentage Parsed : 34
# Frames Per Second : 56 || Percentage Parsed : 34
# Frames Per Second : 56 || Percentage Parsed : 34
# Frames Per Second : 55 || Percentage Parsed : 35
# Frames Per Second : 55 || Percentage Parsed : 35
# Frames Per Second : 56 || Percentage Parsed : 35
# Frames Per Second : 55 || Percentage Parsed : 35
# Frames Per Second : 55 || Percentage Parsed : 35
# Frames Per Second : 55 || Percentage Parsed : 35
# Frames Per Second : 55 || Percentage Parsed : 35
# Frames Per Second : 55 || Percentage Parsed : 35
# Frames Per Second : 55 || Percentage Parsed : 35
# Frames Per Second : 54 || Percentage Parsed : 35
# Frames Per Second : 54 || Percentage Parsed : 35
# Frames Per Second : 55 || Percentage Parsed : 35
# Frames Per Second : 55 || Percentage Parsed : 35
# Frames Per Second : 55 || Percentage Parsed : 35
# Frames Per Second : 55 || Percentage Parsed : 36
# Frames Per Second : 56 || Percentage Parsed : 36
# Frames Per Second : 55 || Percentage Parsed : 36
# Frames Per Second : 55 || Percentage Parsed : 36
# Frames Per Second : 56 || Percentage Parsed : 36
# Frames Per Second : 55 || Percentage Parsed : 36
# Frames Per Second : 55 || Percentage Parsed : 36
# Frames Per Second : 54 || Percentage Parsed : 36
# Frames Per Second : 53 || Percentage Parsed : 36
# Frames Per Second : 54 || Percentage Parsed : 36
# Frames Per Second : 54 || Percentage Parsed : 36
# Frames Per Second : 54 || Percentage Parsed : 36
# Frames Per Second : 54 || Percentage Parsed : 36
# Frames Per Second : 54 || Percentage Parsed : 36
# Frames Per Second : 55 || Percentage Parsed : 37
# Frames Per Second : 52 || Percentage Parsed : 37
# Frames Per Second : 51 || Percentage Parsed : 37
# Frames Per Second : 52 || Percentage Parsed : 37
# Frames Per Second : 52 || Percentage Parsed : 37
# Frames Per Second : 51 || Percentage Parsed : 37
# Frames Per Second : 54 || Percentage Parsed : 37
# Frames Per Second : 54 || Percentage Parsed : 37
# Frames Per Second : 55 || Percentage Parsed : 37
# Frames Per Second : 56 || Percentage Parsed : 37
# Frames Per Second : 55 || Percentage Parsed : 37
# Frames Per Second : 55 || Percentage Parsed : 37
# Frames Per Second : 56 || Percentage Parsed : 37
# Frames Per Second : 55 || Percentage Parsed : 37
# Frames Per Second : 54 || Percentage Parsed : 38
# Frames Per Second : 54 || Percentage Parsed : 38
# Frames Per Second : 55 || Percentage Parsed : 38
# Frames Per Second : 53 || Percentage Parsed : 38
# Frames Per Second : 51 || Percentage Parsed : 38
# Frames Per Second : 51 || Percentage Parsed : 38
# Frames Per Second : 53 || Percentage Parsed : 38
# Frames Per Second : 51 || Percentage Parsed : 38
# Frames Per Second : 53 || Percentage Parsed : 38
# Frames Per Second : 53 || Percentage Parsed : 38
# Frames Per Second : 52 || Percentage Parsed : 38
# Frames Per Second : 54 || Percentage Parsed : 38
# Frames Per Second : 54 || Percentage Parsed : 38
# Frames Per Second : 55 || Percentage Parsed : 38
# Frames Per Second : 55 || Percentage Parsed : 38
# Frames Per Second : 54 || Percentage Parsed : 39
# Frames Per Second : 53 || Percentage Parsed : 39
# Frames Per Second : 52 || Percentage Parsed : 39
# Frames Per Second : 50 || Percentage Parsed : 39
# Frames Per Second : 51 || Percentage Parsed : 39
# Frames Per Second : 50 || Percentage Parsed : 39
# Frames Per Second : 49 || Percentage Parsed : 39
# Frames Per Second : 47 || Percentage Parsed : 39
# Frames Per Second : 49 || Percentage Parsed : 39
# Frames Per Second : 54 || Percentage Parsed : 39
# Frames Per Second : 56 || Percentage Parsed : 39
# Frames Per Second : 55 || Percentage Parsed : 39
# Frames Per Second : 54 || Percentage Parsed : 39
# Frames Per Second : 54 || Percentage Parsed : 39
# Frames Per Second : 55 || Percentage Parsed : 40
# Frames Per Second : 55 || Percentage Parsed : 40
# Frames Per Second : 55 || Percentage Parsed : 40
# Frames Per Second : 55 || Percentage Parsed : 40
# Frames Per Second : 54 || Percentage Parsed : 40
# Frames Per Second : 54 || Percentage Parsed : 40
# Frames Per Second : 55 || Percentage Parsed : 40
# Frames Per Second : 54 || Percentage Parsed : 40
# Frames Per Second : 55 || Percentage Parsed : 40
# Frames Per Second : 53 || Percentage Parsed : 40
# Frames Per Second : 50 || Percentage Parsed : 40
# Frames Per Second : 48 || Percentage Parsed : 40
# Frames Per Second : 50 || Percentage Parsed : 40
# Frames Per Second : 52 || Percentage Parsed : 40
# Frames Per Second : 52 || Percentage Parsed : 41
# Frames Per Second : 54 || Percentage Parsed : 41
# Frames Per Second : 54 || Percentage Parsed : 41
# Frames Per Second : 54 || Percentage Parsed : 41
# Frames Per Second : 55 || Percentage Parsed : 41
# Frames Per Second : 54 || Percentage Parsed : 41
# Frames Per Second : 53 || Percentage Parsed : 41
# Frames Per Second : 53 || Percentage Parsed : 41
# Frames Per Second : 54 || Percentage Parsed : 41
# Frames Per Second : 55 || Percentage Parsed : 41
# Frames Per Second : 52 || Percentage Parsed : 41
# Frames Per Second : 49 || Percentage Parsed : 41
# Frames Per Second : 48 || Percentage Parsed : 41
# Frames Per Second : 47 || Percentage Parsed : 41
# Frames Per Second : 48 || Percentage Parsed : 42
# Frames Per Second : 48 || Percentage Parsed : 42
# Frames Per Second : 47 || Percentage Parsed : 42
# Frames Per Second : 48 || Percentage Parsed : 42
# Frames Per Second : 49 || Percentage Parsed : 42
# Frames Per Second : 48 || Percentage Parsed : 42
# Frames Per Second : 47 || Percentage Parsed : 42
# Frames Per Second : 46 || Percentage Parsed : 42
# Frames Per Second : 47 || Percentage Parsed : 42
# Frames Per Second : 46 || Percentage Parsed : 42
# Frames Per Second : 46 || Percentage Parsed : 42
# Frames Per Second : 45 || Percentage Parsed : 42
# Frames Per Second : 45 || Percentage Parsed : 42
# Frames Per Second : 46 || Percentage Parsed : 42
# Frames Per Second : 46 || Percentage Parsed : 43
# Frames Per Second : 45 || Percentage Parsed : 43
# Frames Per Second : 45 || Percentage Parsed : 43
# Frames Per Second : 45 || Percentage Parsed : 43
# Frames Per Second : 46 || Percentage Parsed : 43
# Frames Per Second : 45 || Percentage Parsed : 43
# Frames Per Second : 46 || Percentage Parsed : 43
# Frames Per Second : 51 || Percentage Parsed : 43
# Frames Per Second : 55 || Percentage Parsed : 43
# Frames Per Second : 54 || Percentage Parsed : 43
# Frames Per Second : 54 || Percentage Parsed : 43
# Frames Per Second : 54 || Percentage Parsed : 43
# Frames Per Second : 55 || Percentage Parsed : 43
# Frames Per Second : 55 || Percentage Parsed : 43
# Frames Per Second : 54 || Percentage Parsed : 43
# Frames Per Second : 53 || Percentage Parsed : 44
# Frames Per Second : 54 || Percentage Parsed : 44
# Frames Per Second : 54 || Percentage Parsed : 44
# Frames Per Second : 53 || Percentage Parsed : 44
# Frames Per Second : 54 || Percentage Parsed : 44
# Frames Per Second : 54 || Percentage Parsed : 44
# Frames Per Second : 51 || Percentage Parsed : 44
# Frames Per Second : 46 || Percentage Parsed : 44
# Frames Per Second : 45 || Percentage Parsed : 44
# Frames Per Second : 46 || Percentage Parsed : 44
# Frames Per Second : 45 || Percentage Parsed : 44
# Frames Per Second : 45 || Percentage Parsed : 44
# Frames Per Second : 46 || Percentage Parsed : 44
# Frames Per Second : 50 || Percentage Parsed : 44
# Frames Per Second : 54 || Percentage Parsed : 45
# Frames Per Second : 55 || Percentage Parsed : 45
# Frames Per Second : 55 || Percentage Parsed : 45
# Frames Per Second : 55 || Percentage Parsed : 45
# Frames Per Second : 55 || Percentage Parsed : 45
# Frames Per Second : 55 || Percentage Parsed : 45
# Frames Per Second : 56 || Percentage Parsed : 45
# Frames Per Second : 56 || Percentage Parsed : 45
# Frames Per Second : 55 || Percentage Parsed : 45
# Frames Per Second : 56 || Percentage Parsed : 45
# Frames Per Second : 56 || Percentage Parsed : 45
# Frames Per Second : 55 || Percentage Parsed : 45
# Frames Per Second : 55 || Percentage Parsed : 45
# Frames Per Second : 53 || Percentage Parsed : 45
# Frames Per Second : 52 || Percentage Parsed : 46
# Frames Per Second : 52 || Percentage Parsed : 46
# Frames Per Second : 52 || Percentage Parsed : 46
# Frames Per Second : 51 || Percentage Parsed : 46
# Frames Per Second : 51 || Percentage Parsed : 46
# Frames Per Second : 50 || Percentage Parsed : 46
# Frames Per Second : 50 || Percentage Parsed : 46
# Frames Per Second : 50 || Percentage Parsed : 46
# Frames Per Second : 50 || Percentage Parsed : 46
# Frames Per Second : 50 || Percentage Parsed : 46
# Frames Per Second : 50 || Percentage Parsed : 46
# Frames Per Second : 51 || Percentage Parsed : 46
# Frames Per Second : 51 || Percentage Parsed : 46
# Frames Per Second : 52 || Percentage Parsed : 46
# Frames Per Second : 53 || Percentage Parsed : 47
# Frames Per Second : 53 || Percentage Parsed : 47
# Frames Per Second : 52 || Percentage Parsed : 47
# Frames Per Second : 54 || Percentage Parsed : 47
# Frames Per Second : 54 || Percentage Parsed : 47
# Frames Per Second : 53 || Percentage Parsed : 47
# Frames Per Second : 52 || Percentage Parsed : 47
# Frames Per Second : 55 || Percentage Parsed : 47
# Frames Per Second : 55 || Percentage Parsed : 47
# Frames Per Second : 55 || Percentage Parsed : 47
# Frames Per Second : 56 || Percentage Parsed : 47
# Frames Per Second : 56 || Percentage Parsed : 47
# Frames Per Second : 55 || Percentage Parsed : 47
# Frames Per Second : 56 || Percentage Parsed : 47
# Frames Per Second : 56 || Percentage Parsed : 48
# Frames Per Second : 57 || Percentage Parsed : 48
# Frames Per Second : 54 || Percentage Parsed : 48
# Frames Per Second : 53 || Percentage Parsed : 48
# Frames Per Second : 54 || Percentage Parsed : 48
# Frames Per Second : 52 || Percentage Parsed : 48
# Frames Per Second : 51 || Percentage Parsed : 48
# Frames Per Second : 50 || Percentage Parsed : 48
# Frames Per Second : 49 || Percentage Parsed : 48
# Frames Per Second : 48 || Percentage Parsed : 48
# Frames Per Second : 49 || Percentage Parsed : 48
# Frames Per Second : 52 || Percentage Parsed : 48
# Frames Per Second : 51 || Percentage Parsed : 48
# Frames Per Second : 52 || Percentage Parsed : 48
# Frames Per Second : 54 || Percentage Parsed : 49
# Frames Per Second : 55 || Percentage Parsed : 49
# Frames Per Second : 55 || Percentage Parsed : 49
# Frames Per Second : 56 || Percentage Parsed : 49
# Frames Per Second : 57 || Percentage Parsed : 49
# Frames Per Second : 57 || Percentage Parsed : 49
# Frames Per Second : 55 || Percentage Parsed : 49
# Frames Per Second : 55 || Percentage Parsed : 49
# Frames Per Second : 56 || Percentage Parsed : 49
# Frames Per Second : 56 || Percentage Parsed : 49
# Frames Per Second : 56 || Percentage Parsed : 49
# Frames Per Second : 57 || Percentage Parsed : 49
# Frames Per Second : 55 || Percentage Parsed : 49
# Frames Per Second : 56 || Percentage Parsed : 49
# Frames Per Second : 55 || Percentage Parsed : 49
# Frames Per Second : 53 || Percentage Parsed : 50
# Frames Per Second : 54 || Percentage Parsed : 50
# Frames Per Second : 55 || Percentage Parsed : 50
# Frames Per Second : 56 || Percentage Parsed : 50
# Frames Per Second : 55 || Percentage Parsed : 50
# Frames Per Second : 55 || Percentage Parsed : 50
# Frames Per Second : 55 || Percentage Parsed : 50
# Frames Per Second : 55 || Percentage Parsed : 50
# Frames Per Second : 55 || Percentage Parsed : 50
# Frames Per Second : 56 || Percentage Parsed : 50
# Frames Per Second : 57 || Percentage Parsed : 50
# Frames Per Second : 55 || Percentage Parsed : 50
# Frames Per Second : 55 || Percentage Parsed : 50
# Frames Per Second : 56 || Percentage Parsed : 50
# Frames Per Second : 54 || Percentage Parsed : 51
# Frames Per Second : 55 || Percentage Parsed : 51
# Frames Per Second : 54 || Percentage Parsed : 51
# Frames Per Second : 54 || Percentage Parsed : 51
# Frames Per Second : 55 || Percentage Parsed : 51
# Frames Per Second : 56 || Percentage Parsed : 51
# Frames Per Second : 55 || Percentage Parsed : 51
# Frames Per Second : 52 || Percentage Parsed : 51
# Frames Per Second : 51 || Percentage Parsed : 51
# Frames Per Second : 50 || Percentage Parsed : 51
# Frames Per Second : 48 || Percentage Parsed : 51
# Frames Per Second : 48 || Percentage Parsed : 51
# Frames Per Second : 47 || Percentage Parsed : 51
# Frames Per Second : 46 || Percentage Parsed : 51
# Frames Per Second : 47 || Percentage Parsed : 52
# Frames Per Second : 47 || Percentage Parsed : 52
# Frames Per Second : 52 || Percentage Parsed : 52
# Frames Per Second : 53 || Percentage Parsed : 52
# Frames Per Second : 54 || Percentage Parsed : 52
# Frames Per Second : 55 || Percentage Parsed : 52
# Frames Per Second : 54 || Percentage Parsed : 52
# Frames Per Second : 53 || Percentage Parsed : 52
# Frames Per Second : 53 || Percentage Parsed : 52
# Frames Per Second : 53 || Percentage Parsed : 52
# Frames Per Second : 53 || Percentage Parsed : 52
# Frames Per Second : 54 || Percentage Parsed : 52
# Frames Per Second : 49 || Percentage Parsed : 52
# Frames Per Second : 47 || Percentage Parsed : 52
# Frames Per Second : 47 || Percentage Parsed : 53
# Frames Per Second : 47 || Percentage Parsed : 53
# Frames Per Second : 47 || Percentage Parsed : 53
# Frames Per Second : 49 || Percentage Parsed : 53
# Frames Per Second : 48 || Percentage Parsed : 53
# Frames Per Second : 48 || Percentage Parsed : 53
# Frames Per Second : 46 || Percentage Parsed : 53
# Frames Per Second : 45 || Percentage Parsed : 53
# Frames Per Second : 45 || Percentage Parsed : 53
# Frames Per Second : 45 || Percentage Parsed : 53
# Frames Per Second : 45 || Percentage Parsed : 53
# Frames Per Second : 45 || Percentage Parsed : 53
# Frames Per Second : 49 || Percentage Parsed : 53
# Frames Per Second : 54 || Percentage Parsed : 53
# Frames Per Second : 51 || Percentage Parsed : 54
# Frames Per Second : 52 || Percentage Parsed : 54
# Frames Per Second : 51 || Percentage Parsed : 54
# Frames Per Second : 51 || Percentage Parsed : 54
# Frames Per Second : 54 || Percentage Parsed : 54
# Frames Per Second : 54 || Percentage Parsed : 54
# Frames Per Second : 54 || Percentage Parsed : 54
# Frames Per Second : 54 || Percentage Parsed : 54
# Frames Per Second : 55 || Percentage Parsed : 54
# Frames Per Second : 51 || Percentage Parsed : 54
# Frames Per Second : 49 || Percentage Parsed : 54
# Frames Per Second : 51 || Percentage Parsed : 54
# Frames Per Second : 50 || Percentage Parsed : 54
# Frames Per Second : 50 || Percentage Parsed : 54
# Frames Per Second : 51 || Percentage Parsed : 54
# Frames Per Second : 51 || Percentage Parsed : 55
# Frames Per Second : 52 || Percentage Parsed : 55
# Frames Per Second : 54 || Percentage Parsed : 55
# Frames Per Second : 50 || Percentage Parsed : 55
# Frames Per Second : 46 || Percentage Parsed : 55
# Frames Per Second : 46 || Percentage Parsed : 55
# Frames Per Second : 47 || Percentage Parsed : 55
# Frames Per Second : 46 || Percentage Parsed : 55
# Frames Per Second : 48 || Percentage Parsed : 55
# Frames Per Second : 49 || Percentage Parsed : 55
# Frames Per Second : 54 || Percentage Parsed : 55
# Frames Per Second : 54 || Percentage Parsed : 55
# Frames Per Second : 55 || Percentage Parsed : 55
# Frames Per Second : 55 || Percentage Parsed : 55
# Frames Per Second : 54 || Percentage Parsed : 56
# Frames Per Second : 55 || Percentage Parsed : 56
# Frames Per Second : 56 || Percentage Parsed : 56
# Frames Per Second : 55 || Percentage Parsed : 56
# Frames Per Second : 55 || Percentage Parsed : 56
# Frames Per Second : 56 || Percentage Parsed : 56
# Frames Per Second : 55 || Percentage Parsed : 56
# Frames Per Second : 56 || Percentage Parsed : 56
# Frames Per Second : 55 || Percentage Parsed : 56
# Frames Per Second : 53 || Percentage Parsed : 56
# Frames Per Second : 55 || Percentage Parsed : 56
# Frames Per Second : 53 || Percentage Parsed : 56
# Frames Per Second : 52 || Percentage Parsed : 56
# Frames Per Second : 55 || Percentage Parsed : 56
# Frames Per Second : 55 || Percentage Parsed : 57
# Frames Per Second : 54 || Percentage Parsed : 57
# Frames Per Second : 56 || Percentage Parsed : 57
# Frames Per Second : 56 || Percentage Parsed : 57
# Frames Per Second : 55 || Percentage Parsed : 57
# Frames Per Second : 54 || Percentage Parsed : 57
# Frames Per Second : 50 || Percentage Parsed : 57
# Frames Per Second : 49 || Percentage Parsed : 57
# Frames Per Second : 49 || Percentage Parsed : 57
# Frames Per Second : 49 || Percentage Parsed : 57
# Frames Per Second : 53 || Percentage Parsed : 57
# Frames Per Second : 55 || Percentage Parsed : 57
# Frames Per Second : 55 || Percentage Parsed : 57
# Frames Per Second : 55 || Percentage Parsed : 57
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 56 || Percentage Parsed : 58
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 56 || Percentage Parsed : 58
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 53 || Percentage Parsed : 58
# Frames Per Second : 50 || Percentage Parsed : 58
# Frames Per Second : 51 || Percentage Parsed : 58
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 54 || Percentage Parsed : 58
# Frames Per Second : 53 || Percentage Parsed : 58
# Frames Per Second : 53 || Percentage Parsed : 59
# Frames Per Second : 55 || Percentage Parsed : 59
# Frames Per Second : 53 || Percentage Parsed : 59
# Frames Per Second : 51 || Percentage Parsed : 59
# Frames Per Second : 53 || Percentage Parsed : 59
# Frames Per Second : 53 || Percentage Parsed : 59
# Frames Per Second : 54 || Percentage Parsed : 59
# Frames Per Second : 53 || Percentage Parsed : 59
# Frames Per Second : 53 || Percentage Parsed : 59
# Frames Per Second : 51 || Percentage Parsed : 59
# Frames Per Second : 50 || Percentage Parsed : 59
# Frames Per Second : 51 || Percentage Parsed : 59
# Frames Per Second : 51 || Percentage Parsed : 59
# Frames Per Second : 52 || Percentage Parsed : 59
# Frames Per Second : 51 || Percentage Parsed : 60
# Frames Per Second : 52 || Percentage Parsed : 60
# Frames Per Second : 54 || Percentage Parsed : 60
# Frames Per Second : 54 || Percentage Parsed : 60
# Frames Per Second : 53 || Percentage Parsed : 60
# Frames Per Second : 52 || Percentage Parsed : 60
# Frames Per Second : 53 || Percentage Parsed : 60
# Frames Per Second : 55 || Percentage Parsed : 60
# Frames Per Second : 54 || Percentage Parsed : 60
# Frames Per Second : 53 || Percentage Parsed : 60
# Frames Per Second : 55 || Percentage Parsed : 60
# Frames Per Second : 53 || Percentage Parsed : 60
# Frames Per Second : 51 || Percentage Parsed : 60
# Frames Per Second : 52 || Percentage Parsed : 60
# Frames Per Second : 51 || Percentage Parsed : 60
# Frames Per Second : 51 || Percentage Parsed : 61
# Frames Per Second : 50 || Percentage Parsed : 61
# Frames Per Second : 52 || Percentage Parsed : 61
# Frames Per Second : 51 || Percentage Parsed : 61
# Frames Per Second : 52 || Percentage Parsed : 61
# Frames Per Second : 55 || Percentage Parsed : 61
# Frames Per Second : 54 || Percentage Parsed : 61
# Frames Per Second : 55 || Percentage Parsed : 61
# Frames Per Second : 55 || Percentage Parsed : 61
# Frames Per Second : 55 || Percentage Parsed : 61
# Frames Per Second : 54 || Percentage Parsed : 61
# Frames Per Second : 55 || Percentage Parsed : 61
# Frames Per Second : 54 || Percentage Parsed : 61
# Frames Per Second : 54 || Percentage Parsed : 61
# Frames Per Second : 52 || Percentage Parsed : 62
# Frames Per Second : 53 || Percentage Parsed : 62
# Frames Per Second : 55 || Percentage Parsed : 62
# Frames Per Second : 55 || Percentage Parsed : 62
# Frames Per Second : 55 || Percentage Parsed : 62
# Frames Per Second : 55 || Percentage Parsed : 62
# Frames Per Second : 54 || Percentage Parsed : 62
# Frames Per Second : 55 || Percentage Parsed : 62
# Frames Per Second : 54 || Percentage Parsed : 62
# Frames Per Second : 55 || Percentage Parsed : 62
# Frames Per Second : 55 || Percentage Parsed : 62
# Frames Per Second : 56 || Percentage Parsed : 62
# Frames Per Second : 55 || Percentage Parsed : 62
# Frames Per Second : 54 || Percentage Parsed : 62
# Frames Per Second : 53 || Percentage Parsed : 63
# Frames Per Second : 54 || Percentage Parsed : 63
# Frames Per Second : 52 || Percentage Parsed : 63
# Frames Per Second : 51 || Percentage Parsed : 63
# Frames Per Second : 49 || Percentage Parsed : 63
# Frames Per Second : 54 || Percentage Parsed : 63
# Frames Per Second : 55 || Percentage Parsed : 63
# Frames Per Second : 56 || Percentage Parsed : 63
# Frames Per Second : 56 || Percentage Parsed : 63
# Frames Per Second : 54 || Percentage Parsed : 63
# Frames Per Second : 54 || Percentage Parsed : 63
# Frames Per Second : 54 || Percentage Parsed : 63
# Frames Per Second : 54 || Percentage Parsed : 63
# Frames Per Second : 53 || Percentage Parsed : 63
# Frames Per Second : 53 || Percentage Parsed : 64
# Frames Per Second : 54 || Percentage Parsed : 64
# Frames Per Second : 55 || Percentage Parsed : 64
# Frames Per Second : 56 || Percentage Parsed : 64
# Frames Per Second : 56 || Percentage Parsed : 64
# Frames Per Second : 54 || Percentage Parsed : 64
# Frames Per Second : 53 || Percentage Parsed : 64
# Frames Per Second : 53 || Percentage Parsed : 64
# Frames Per Second : 50 || Percentage Parsed : 64
# Frames Per Second : 51 || Percentage Parsed : 64
# Frames Per Second : 53 || Percentage Parsed : 64
# Frames Per Second : 52 || Percentage Parsed : 64
# Frames Per Second : 54 || Percentage Parsed : 64
# Frames Per Second : 52 || Percentage Parsed : 64
# Frames Per Second : 51 || Percentage Parsed : 65
# Frames Per Second : 52 || Percentage Parsed : 65
# Frames Per Second : 54 || Percentage Parsed : 65
# Frames Per Second : 53 || Percentage Parsed : 65
# Frames Per Second : 53 || Percentage Parsed : 65
# Frames Per Second : 53 || Percentage Parsed : 65
# Frames Per Second : 53 || Percentage Parsed : 65
# Frames Per Second : 54 || Percentage Parsed : 65
# Frames Per Second : 56 || Percentage Parsed : 65
# Frames Per Second : 55 || Percentage Parsed : 65
# Frames Per Second : 54 || Percentage Parsed : 65
# Frames Per Second : 53 || Percentage Parsed : 65
# Frames Per Second : 53 || Percentage Parsed : 65
# Frames Per Second : 54 || Percentage Parsed : 65
# Frames Per Second : 53 || Percentage Parsed : 65
# Frames Per Second : 55 || Percentage Parsed : 66
# Frames Per Second : 55 || Percentage Parsed : 66
# Frames Per Second : 53 || Percentage Parsed : 66
# Frames Per Second : 50 || Percentage Parsed : 66
# Frames Per Second : 50 || Percentage Parsed : 66
# Frames Per Second : 50 || Percentage Parsed : 66
# Frames Per Second : 53 || Percentage Parsed : 66
# Frames Per Second : 52 || Percentage Parsed : 66
# Frames Per Second : 51 || Percentage Parsed : 66
# Frames Per Second : 50 || Percentage Parsed : 66
# Frames Per Second : 52 || Percentage Parsed : 66
# Frames Per Second : 55 || Percentage Parsed : 66
# Frames Per Second : 55 || Percentage Parsed : 66
# Frames Per Second : 54 || Percentage Parsed : 66
# Completed!

# %% [markdown]
# Salvamos el video resultante del proceso en nuestro Drive:

# %%
# Input video path
save_path = "/content/fuerzas_armadas_yolov5_augmented.mp4"

# Compressed video path
compressed_path = "/content/fuerzas_armadas_yolov5_augmented_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")
# Out:
# 0

# %%
shutil.copy(
    "/content/fuerzas_armadas_yolov5_augmented_compressed.mp4",
    "/content/drive/MyDrive/tfg/videos/fuerzas_armadas_yolov5_augmented_compressed.mp4"
)
# Out:
# '/content/drive/MyDrive/tfg/videos/fuerzas_armadas_yolov5_augmented_compressed.mp4'

# %%
shutil.rmtree("/content/runs")

# %% [markdown]
# ## YOLOv5 con Data Augmentation e Imágenes de Humanos

# %%
zip_path = "/content/drive/MyDrive/tfg/models/runs_yolov5_augmented_humans.zip"
extract_path = "/content/"
# !unzip -q "$zip_path" -d "$extract_path"

# %%
model = YOLO("runs/detect/train/weights/best.pt")

# %%
yolov5_rtod = VideoParserObjectDetectionModel(model, YOLO_FNS, CLASS_INFO)

# %%
yolov5_rtod(URL, "fuerzas_armadas_yolov5_augmented_humans.mp4")
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=xV24-uVq3WY
# [youtube] xV24-uVq3WY: Downloading webpage
# [youtube] xV24-uVq3WY: Downloading tv client config
# [youtube] xV24-uVq3WY: Downloading player 91e7c654-main
# [youtube] xV24-uVq3WY: Downloading tv player API JSON
# [youtube] xV24-uVq3WY: Downloading ios player API JSON
# [youtube] xV24-uVq3WY: Downloading m3u8 information
# Frames Per Second : 41 || Percentage Parsed : 0
# Frames Per Second : 51 || Percentage Parsed : 0
# Frames Per Second : 53 || Percentage Parsed : 0
# Frames Per Second : 53 || Percentage Parsed : 0
# Frames Per Second : 51 || Percentage Parsed : 0
# Frames Per Second : 53 || Percentage Parsed : 0
# Frames Per Second : 53 || Percentage Parsed : 0
# Frames Per Second : 53 || Percentage Parsed : 0
# Frames Per Second : 53 || Percentage Parsed : 0
# Frames Per Second : 52 || Percentage Parsed : 0
# Frames Per Second : 54 || Percentage Parsed : 0
# Frames Per Second : 54 || Percentage Parsed : 0
# Frames Per Second : 52 || Percentage Parsed : 0
# Frames Per Second : 53 || Percentage Parsed : 0
# Frames Per Second : 55 || Percentage Parsed : 1
# Frames Per Second : 55 || Percentage Parsed : 1
# Frames Per Second : 56 || Percentage Parsed : 1
# Frames Per Second : 55 || Percentage Parsed : 1
# Frames Per Second : 56 || Percentage Parsed : 1
# Frames Per Second : 55 || Percentage Parsed : 1
# Frames Per Second : 54 || Percentage Parsed : 1
# Frames Per Second : 54 || Percentage Parsed : 1
# Frames Per Second : 54 || Percentage Parsed : 1
# Frames Per Second : 53 || Percentage Parsed : 1
# Frames Per Second : 54 || Percentage Parsed : 1
# Frames Per Second : 55 || Percentage Parsed : 1
# Frames Per Second : 55 || Percentage Parsed : 1
# Frames Per Second : 53 || Percentage Parsed : 1
# Frames Per Second : 55 || Percentage Parsed : 2
# Frames Per Second : 54 || Percentage Parsed : 2
# Frames Per Second : 55 || Percentage Parsed : 2
# Frames Per Second : 55 || Percentage Parsed : 2
# Frames Per Second : 55 || Percentage Parsed : 2
# Frames Per Second : 54 || Percentage Parsed : 2
# Frames Per Second : 53 || Percentage Parsed : 2
# Frames Per Second : 55 || Percentage Parsed : 2
# Frames Per Second : 54 || Percentage Parsed : 2
# Frames Per Second : 53 || Percentage Parsed : 2
# Frames Per Second : 53 || Percentage Parsed : 2
# Frames Per Second : 54 || Percentage Parsed : 2
# Frames Per Second : 54 || Percentage Parsed : 2
# Frames Per Second : 54 || Percentage Parsed : 2
# Frames Per Second : 54 || Percentage Parsed : 3
# Frames Per Second : 54 || Percentage Parsed : 3
# Frames Per Second : 53 || Percentage Parsed : 3
# Frames Per Second : 54 || Percentage Parsed : 3
# Frames Per Second : 53 || Percentage Parsed : 3
# Frames Per Second : 53 || Percentage Parsed : 3
# Frames Per Second : 54 || Percentage Parsed : 3
# Frames Per Second : 54 || Percentage Parsed : 3
# Frames Per Second : 54 || Percentage Parsed : 3
# Frames Per Second : 53 || Percentage Parsed : 3
# Frames Per Second : 54 || Percentage Parsed : 3
# Frames Per Second : 52 || Percentage Parsed : 3
# Frames Per Second : 55 || Percentage Parsed : 3
# Frames Per Second : 56 || Percentage Parsed : 3
# Frames Per Second : 56 || Percentage Parsed : 4
# Frames Per Second : 54 || Percentage Parsed : 4
# Frames Per Second : 54 || Percentage Parsed : 4
# Frames Per Second : 55 || Percentage Parsed : 4
# Frames Per Second : 54 || Percentage Parsed : 4
# Frames Per Second : 54 || Percentage Parsed : 4
# Frames Per Second : 54 || Percentage Parsed : 4
# Frames Per Second : 54 || Percentage Parsed : 4
# Frames Per Second : 53 || Percentage Parsed : 4
# Frames Per Second : 52 || Percentage Parsed : 4
# Frames Per Second : 54 || Percentage Parsed : 4
# Frames Per Second : 53 || Percentage Parsed : 4
# Frames Per Second : 54 || Percentage Parsed : 4
# Frames Per Second : 54 || Percentage Parsed : 4
# Frames Per Second : 55 || Percentage Parsed : 5
# Frames Per Second : 55 || Percentage Parsed : 5
# Frames Per Second : 56 || Percentage Parsed : 5
# Frames Per Second : 55 || Percentage Parsed : 5
# Frames Per Second : 53 || Percentage Parsed : 5
# Frames Per Second : 54 || Percentage Parsed : 5
# Frames Per Second : 55 || Percentage Parsed : 5
# Frames Per Second : 54 || Percentage Parsed : 5
# Frames Per Second : 54 || Percentage Parsed : 5
# Frames Per Second : 55 || Percentage Parsed : 5
# Frames Per Second : 55 || Percentage Parsed : 5
# Frames Per Second : 54 || Percentage Parsed : 5
# Frames Per Second : 54 || Percentage Parsed : 5
# Frames Per Second : 53 || Percentage Parsed : 5
# Frames Per Second : 55 || Percentage Parsed : 5
# Frames Per Second : 55 || Percentage Parsed : 6
# Frames Per Second : 55 || Percentage Parsed : 6
# Frames Per Second : 55 || Percentage Parsed : 6
# Frames Per Second : 55 || Percentage Parsed : 6
# Frames Per Second : 56 || Percentage Parsed : 6
# Frames Per Second : 54 || Percentage Parsed : 6
# Frames Per Second : 54 || Percentage Parsed : 6
# Frames Per Second : 53 || Percentage Parsed : 6
# Frames Per Second : 53 || Percentage Parsed : 6
# Frames Per Second : 54 || Percentage Parsed : 6
# Frames Per Second : 54 || Percentage Parsed : 6
# Frames Per Second : 54 || Percentage Parsed : 6
# Frames Per Second : 54 || Percentage Parsed : 6
# Frames Per Second : 55 || Percentage Parsed : 6
# Frames Per Second : 54 || Percentage Parsed : 7
# Frames Per Second : 54 || Percentage Parsed : 7
# Frames Per Second : 55 || Percentage Parsed : 7
# Frames Per Second : 55 || Percentage Parsed : 7
# Frames Per Second : 53 || Percentage Parsed : 7
# Frames Per Second : 54 || Percentage Parsed : 7
# Frames Per Second : 54 || Percentage Parsed : 7
# Frames Per Second : 54 || Percentage Parsed : 7
# Frames Per Second : 56 || Percentage Parsed : 7
# Frames Per Second : 56 || Percentage Parsed : 7
# Frames Per Second : 55 || Percentage Parsed : 7
# Frames Per Second : 54 || Percentage Parsed : 7
# Frames Per Second : 53 || Percentage Parsed : 7
# Frames Per Second : 55 || Percentage Parsed : 7
# Frames Per Second : 55 || Percentage Parsed : 8
# Frames Per Second : 55 || Percentage Parsed : 8
# Frames Per Second : 53 || Percentage Parsed : 8
# Frames Per Second : 53 || Percentage Parsed : 8
# Frames Per Second : 53 || Percentage Parsed : 8
# Frames Per Second : 55 || Percentage Parsed : 8
# Frames Per Second : 55 || Percentage Parsed : 8
# Frames Per Second : 55 || Percentage Parsed : 8
# Frames Per Second : 55 || Percentage Parsed : 8
# Frames Per Second : 56 || Percentage Parsed : 8
# Frames Per Second : 55 || Percentage Parsed : 8
# Frames Per Second : 55 || Percentage Parsed : 8
# Frames Per Second : 55 || Percentage Parsed : 8
# Frames Per Second : 55 || Percentage Parsed : 8
# Frames Per Second : 56 || Percentage Parsed : 9
# Frames Per Second : 56 || Percentage Parsed : 9
# Frames Per Second : 55 || Percentage Parsed : 9
# Frames Per Second : 55 || Percentage Parsed : 9
# Frames Per Second : 54 || Percentage Parsed : 9
# Frames Per Second : 54 || Percentage Parsed : 9
# Frames Per Second : 55 || Percentage Parsed : 9
# Frames Per Second : 54 || Percentage Parsed : 9
# Frames Per Second : 55 || Percentage Parsed : 9
# Frames Per Second : 55 || Percentage Parsed : 9
# Frames Per Second : 54 || Percentage Parsed : 9
# Frames Per Second : 54 || Percentage Parsed : 9
# Frames Per Second : 53 || Percentage Parsed : 9
# Frames Per Second : 55 || Percentage Parsed : 9
# Frames Per Second : 55 || Percentage Parsed : 10
# Frames Per Second : 55 || Percentage Parsed : 10
# Frames Per Second : 53 || Percentage Parsed : 10
# Frames Per Second : 54 || Percentage Parsed : 10
# Frames Per Second : 55 || Percentage Parsed : 10
# Frames Per Second : 55 || Percentage Parsed : 10
# Frames Per Second : 52 || Percentage Parsed : 10
# Frames Per Second : 53 || Percentage Parsed : 10
# Frames Per Second : 55 || Percentage Parsed : 10
# Frames Per Second : 55 || Percentage Parsed : 10
# Frames Per Second : 55 || Percentage Parsed : 10
# Frames Per Second : 54 || Percentage Parsed : 10
# Frames Per Second : 54 || Percentage Parsed : 10
# Frames Per Second : 55 || Percentage Parsed : 10
# Frames Per Second : 55 || Percentage Parsed : 10
# Frames Per Second : 55 || Percentage Parsed : 11
# Frames Per Second : 55 || Percentage Parsed : 11
# Frames Per Second : 56 || Percentage Parsed : 11
# Frames Per Second : 54 || Percentage Parsed : 11
# Frames Per Second : 54 || Percentage Parsed : 11
# Frames Per Second : 54 || Percentage Parsed : 11
# Frames Per Second : 55 || Percentage Parsed : 11
# Frames Per Second : 55 || Percentage Parsed : 11
# Frames Per Second : 54 || Percentage Parsed : 11
# Frames Per Second : 54 || Percentage Parsed : 11
# Frames Per Second : 54 || Percentage Parsed : 11
# Frames Per Second : 54 || Percentage Parsed : 11
# Frames Per Second : 54 || Percentage Parsed : 11
# Frames Per Second : 54 || Percentage Parsed : 11
# Frames Per Second : 53 || Percentage Parsed : 12
# Frames Per Second : 54 || Percentage Parsed : 12
# Frames Per Second : 54 || Percentage Parsed : 12
# Frames Per Second : 53 || Percentage Parsed : 12
# Frames Per Second : 54 || Percentage Parsed : 12
# Frames Per Second : 54 || Percentage Parsed : 12
# Frames Per Second : 55 || Percentage Parsed : 12
# Frames Per Second : 55 || Percentage Parsed : 12
# Frames Per Second : 52 || Percentage Parsed : 12
# Frames Per Second : 55 || Percentage Parsed : 12
# Frames Per Second : 57 || Percentage Parsed : 12
# Frames Per Second : 58 || Percentage Parsed : 12
# Frames Per Second : 57 || Percentage Parsed : 12
# Frames Per Second : 57 || Percentage Parsed : 12
# Frames Per Second : 57 || Percentage Parsed : 13
# Frames Per Second : 55 || Percentage Parsed : 13
# Frames Per Second : 55 || Percentage Parsed : 13
# Frames Per Second : 54 || Percentage Parsed : 13
# Frames Per Second : 55 || Percentage Parsed : 13
# Frames Per Second : 55 || Percentage Parsed : 13
# Frames Per Second : 55 || Percentage Parsed : 13
# Frames Per Second : 56 || Percentage Parsed : 13
# Frames Per Second : 54 || Percentage Parsed : 13
# Frames Per Second : 55 || Percentage Parsed : 13
# Frames Per Second : 55 || Percentage Parsed : 13
# Frames Per Second : 55 || Percentage Parsed : 13
# Frames Per Second : 55 || Percentage Parsed : 13
# Frames Per Second : 54 || Percentage Parsed : 13
# Frames Per Second : 53 || Percentage Parsed : 14
# Frames Per Second : 54 || Percentage Parsed : 14
# Frames Per Second : 54 || Percentage Parsed : 14
# Frames Per Second : 55 || Percentage Parsed : 14
# Frames Per Second : 52 || Percentage Parsed : 14
# Frames Per Second : 54 || Percentage Parsed : 14
# Frames Per Second : 53 || Percentage Parsed : 14
# Frames Per Second : 54 || Percentage Parsed : 14
# Frames Per Second : 54 || Percentage Parsed : 14
# Frames Per Second : 55 || Percentage Parsed : 14
# Frames Per Second : 54 || Percentage Parsed : 14
# Frames Per Second : 53 || Percentage Parsed : 14
# Frames Per Second : 53 || Percentage Parsed : 14
# Frames Per Second : 51 || Percentage Parsed : 14
# Frames Per Second : 53 || Percentage Parsed : 15
# Frames Per Second : 54 || Percentage Parsed : 15
# Frames Per Second : 53 || Percentage Parsed : 15
# Frames Per Second : 54 || Percentage Parsed : 15
# Frames Per Second : 53 || Percentage Parsed : 15
# Frames Per Second : 52 || Percentage Parsed : 15
# Frames Per Second : 53 || Percentage Parsed : 15
# Frames Per Second : 52 || Percentage Parsed : 15
# Frames Per Second : 53 || Percentage Parsed : 15
# Frames Per Second : 52 || Percentage Parsed : 15
# Frames Per Second : 54 || Percentage Parsed : 15
# Frames Per Second : 55 || Percentage Parsed : 15
# Frames Per Second : 55 || Percentage Parsed : 15
# Frames Per Second : 53 || Percentage Parsed : 15
# Frames Per Second : 54 || Percentage Parsed : 16
# Frames Per Second : 54 || Percentage Parsed : 16
# Frames Per Second : 54 || Percentage Parsed : 16
# Frames Per Second : 53 || Percentage Parsed : 16
# Frames Per Second : 53 || Percentage Parsed : 16
# Frames Per Second : 52 || Percentage Parsed : 16
# Frames Per Second : 54 || Percentage Parsed : 16
# Frames Per Second : 53 || Percentage Parsed : 16
# Frames Per Second : 54 || Percentage Parsed : 16
# Frames Per Second : 55 || Percentage Parsed : 16
# Frames Per Second : 54 || Percentage Parsed : 16
# Frames Per Second : 54 || Percentage Parsed : 16
# Frames Per Second : 54 || Percentage Parsed : 16
# Frames Per Second : 55 || Percentage Parsed : 16
# Frames Per Second : 55 || Percentage Parsed : 16
# Frames Per Second : 55 || Percentage Parsed : 17
# Frames Per Second : 55 || Percentage Parsed : 17
# Frames Per Second : 54 || Percentage Parsed : 17
# Frames Per Second : 54 || Percentage Parsed : 17
# Frames Per Second : 55 || Percentage Parsed : 17
# Frames Per Second : 55 || Percentage Parsed : 17
# Frames Per Second : 55 || Percentage Parsed : 17
# Frames Per Second : 58 || Percentage Parsed : 17
# Frames Per Second : 58 || Percentage Parsed : 17
# Frames Per Second : 57 || Percentage Parsed : 17
# Frames Per Second : 57 || Percentage Parsed : 17
# Frames Per Second : 54 || Percentage Parsed : 17
# Frames Per Second : 52 || Percentage Parsed : 17
# Frames Per Second : 54 || Percentage Parsed : 17
# Frames Per Second : 53 || Percentage Parsed : 18
# Frames Per Second : 53 || Percentage Parsed : 18
# Frames Per Second : 53 || Percentage Parsed : 18
# Frames Per Second : 52 || Percentage Parsed : 18
# Frames Per Second : 51 || Percentage Parsed : 18
# Frames Per Second : 54 || Percentage Parsed : 18
# Frames Per Second : 57 || Percentage Parsed : 18
# Frames Per Second : 56 || Percentage Parsed : 18
# Frames Per Second : 57 || Percentage Parsed : 18
# Frames Per Second : 58 || Percentage Parsed : 18
# Frames Per Second : 57 || Percentage Parsed : 18
# Frames Per Second : 58 || Percentage Parsed : 18
# Frames Per Second : 58 || Percentage Parsed : 18
# Frames Per Second : 56 || Percentage Parsed : 18
# Frames Per Second : 54 || Percentage Parsed : 19
# Frames Per Second : 55 || Percentage Parsed : 19
# Frames Per Second : 55 || Percentage Parsed : 19
# Frames Per Second : 54 || Percentage Parsed : 19
# Frames Per Second : 54 || Percentage Parsed : 19
# Frames Per Second : 54 || Percentage Parsed : 19
# Frames Per Second : 54 || Percentage Parsed : 19
# Frames Per Second : 55 || Percentage Parsed : 19
# Frames Per Second : 55 || Percentage Parsed : 19
# Frames Per Second : 55 || Percentage Parsed : 19
# Frames Per Second : 57 || Percentage Parsed : 19
# Frames Per Second : 57 || Percentage Parsed : 19
# Frames Per Second : 58 || Percentage Parsed : 19
# Frames Per Second : 58 || Percentage Parsed : 19
# Frames Per Second : 58 || Percentage Parsed : 20
# Frames Per Second : 58 || Percentage Parsed : 20
# Frames Per Second : 58 || Percentage Parsed : 20
# Frames Per Second : 55 || Percentage Parsed : 20
# Frames Per Second : 53 || Percentage Parsed : 20
# Frames Per Second : 57 || Percentage Parsed : 20
# Frames Per Second : 56 || Percentage Parsed : 20
# Frames Per Second : 53 || Percentage Parsed : 20
# Frames Per Second : 54 || Percentage Parsed : 20
# Frames Per Second : 54 || Percentage Parsed : 20
# Frames Per Second : 54 || Percentage Parsed : 20
# Frames Per Second : 55 || Percentage Parsed : 20
# Frames Per Second : 55 || Percentage Parsed : 20
# Frames Per Second : 55 || Percentage Parsed : 20
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 53 || Percentage Parsed : 21
# Frames Per Second : 53 || Percentage Parsed : 21
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 57 || Percentage Parsed : 21
# Frames Per Second : 56 || Percentage Parsed : 21
# Frames Per Second : 56 || Percentage Parsed : 21
# Frames Per Second : 56 || Percentage Parsed : 21
# Frames Per Second : 54 || Percentage Parsed : 21
# Frames Per Second : 54 || Percentage Parsed : 21
# Frames Per Second : 54 || Percentage Parsed : 21
# Frames Per Second : 54 || Percentage Parsed : 21
# Frames Per Second : 54 || Percentage Parsed : 21
# Frames Per Second : 55 || Percentage Parsed : 21
# Frames Per Second : 54 || Percentage Parsed : 22
# Frames Per Second : 53 || Percentage Parsed : 22
# Frames Per Second : 55 || Percentage Parsed : 22
# Frames Per Second : 54 || Percentage Parsed : 22
# Frames Per Second : 53 || Percentage Parsed : 22
# Frames Per Second : 53 || Percentage Parsed : 22
# Frames Per Second : 54 || Percentage Parsed : 22
# Frames Per Second : 54 || Percentage Parsed : 22
# Frames Per Second : 53 || Percentage Parsed : 22
# Frames Per Second : 54 || Percentage Parsed : 22
# Frames Per Second : 55 || Percentage Parsed : 22
# Frames Per Second : 55 || Percentage Parsed : 22
# Frames Per Second : 53 || Percentage Parsed : 22
# Frames Per Second : 53 || Percentage Parsed : 22
# Frames Per Second : 54 || Percentage Parsed : 23
# Frames Per Second : 55 || Percentage Parsed : 23
# Frames Per Second : 55 || Percentage Parsed : 23
# Frames Per Second : 54 || Percentage Parsed : 23
# Frames Per Second : 55 || Percentage Parsed : 23
# Frames Per Second : 55 || Percentage Parsed : 23
# Frames Per Second : 55 || Percentage Parsed : 23
# Frames Per Second : 54 || Percentage Parsed : 23
# Frames Per Second : 54 || Percentage Parsed : 23
# Frames Per Second : 54 || Percentage Parsed : 23
# Frames Per Second : 54 || Percentage Parsed : 23
# Frames Per Second : 54 || Percentage Parsed : 23
# Frames Per Second : 53 || Percentage Parsed : 23
# Frames Per Second : 55 || Percentage Parsed : 23
# Frames Per Second : 54 || Percentage Parsed : 24
# Frames Per Second : 54 || Percentage Parsed : 24
# Frames Per Second : 54 || Percentage Parsed : 24
# Frames Per Second : 53 || Percentage Parsed : 24
# Frames Per Second : 50 || Percentage Parsed : 24
# Frames Per Second : 52 || Percentage Parsed : 24
# Frames Per Second : 54 || Percentage Parsed : 24
# Frames Per Second : 54 || Percentage Parsed : 24
# Frames Per Second : 55 || Percentage Parsed : 24
# Frames Per Second : 54 || Percentage Parsed : 24
# Frames Per Second : 54 || Percentage Parsed : 24
# Frames Per Second : 54 || Percentage Parsed : 24
# Frames Per Second : 54 || Percentage Parsed : 24
# Frames Per Second : 53 || Percentage Parsed : 24
# Frames Per Second : 54 || Percentage Parsed : 25
# Frames Per Second : 54 || Percentage Parsed : 25
# Frames Per Second : 52 || Percentage Parsed : 25
# Frames Per Second : 53 || Percentage Parsed : 25
# Frames Per Second : 54 || Percentage Parsed : 25
# Frames Per Second : 55 || Percentage Parsed : 25
# Frames Per Second : 54 || Percentage Parsed : 25
# Frames Per Second : 55 || Percentage Parsed : 25
# Frames Per Second : 55 || Percentage Parsed : 25
# Frames Per Second : 55 || Percentage Parsed : 25
# Frames Per Second : 56 || Percentage Parsed : 25
# Frames Per Second : 53 || Percentage Parsed : 25
# Frames Per Second : 54 || Percentage Parsed : 25
# Frames Per Second : 54 || Percentage Parsed : 25
# Frames Per Second : 54 || Percentage Parsed : 26
# Frames Per Second : 55 || Percentage Parsed : 26
# Frames Per Second : 55 || Percentage Parsed : 26
# Frames Per Second : 54 || Percentage Parsed : 26
# Frames Per Second : 56 || Percentage Parsed : 26
# Frames Per Second : 56 || Percentage Parsed : 26
# Frames Per Second : 55 || Percentage Parsed : 26
# Frames Per Second : 56 || Percentage Parsed : 26
# Frames Per Second : 54 || Percentage Parsed : 26
# Frames Per Second : 54 || Percentage Parsed : 26
# Frames Per Second : 55 || Percentage Parsed : 26
# Frames Per Second : 54 || Percentage Parsed : 26
# Frames Per Second : 54 || Percentage Parsed : 26
# Frames Per Second : 55 || Percentage Parsed : 26
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 54 || Percentage Parsed : 27
# Frames Per Second : 54 || Percentage Parsed : 27
# Frames Per Second : 56 || Percentage Parsed : 27
# Frames Per Second : 54 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 56 || Percentage Parsed : 27
# Frames Per Second : 55 || Percentage Parsed : 27
# Frames Per Second : 57 || Percentage Parsed : 27
# Frames Per Second : 58 || Percentage Parsed : 27
# Frames Per Second : 58 || Percentage Parsed : 27
# Frames Per Second : 56 || Percentage Parsed : 27
# Frames Per Second : 54 || Percentage Parsed : 28
# Frames Per Second : 55 || Percentage Parsed : 28
# Frames Per Second : 54 || Percentage Parsed : 28
# Frames Per Second : 55 || Percentage Parsed : 28
# Frames Per Second : 54 || Percentage Parsed : 28
# Frames Per Second : 55 || Percentage Parsed : 28
# Frames Per Second : 55 || Percentage Parsed : 28
# Frames Per Second : 55 || Percentage Parsed : 28
# Frames Per Second : 53 || Percentage Parsed : 28
# Frames Per Second : 52 || Percentage Parsed : 28
# Frames Per Second : 55 || Percentage Parsed : 28
# Frames Per Second : 54 || Percentage Parsed : 28
# Frames Per Second : 54 || Percentage Parsed : 28
# Frames Per Second : 55 || Percentage Parsed : 28
# Frames Per Second : 56 || Percentage Parsed : 29
# Frames Per Second : 55 || Percentage Parsed : 29
# Frames Per Second : 53 || Percentage Parsed : 29
# Frames Per Second : 55 || Percentage Parsed : 29
# Frames Per Second : 55 || Percentage Parsed : 29
# Frames Per Second : 56 || Percentage Parsed : 29
# Frames Per Second : 52 || Percentage Parsed : 29
# Frames Per Second : 55 || Percentage Parsed : 29
# Frames Per Second : 54 || Percentage Parsed : 29
# Frames Per Second : 54 || Percentage Parsed : 29
# Frames Per Second : 55 || Percentage Parsed : 29
# Frames Per Second : 52 || Percentage Parsed : 29
# Frames Per Second : 55 || Percentage Parsed : 29
# Frames Per Second : 54 || Percentage Parsed : 29
# Frames Per Second : 50 || Percentage Parsed : 30
# Frames Per Second : 54 || Percentage Parsed : 30
# Frames Per Second : 54 || Percentage Parsed : 30
# Frames Per Second : 55 || Percentage Parsed : 30
# Frames Per Second : 54 || Percentage Parsed : 30
# Frames Per Second : 55 || Percentage Parsed : 30
# Frames Per Second : 55 || Percentage Parsed : 30
# Frames Per Second : 56 || Percentage Parsed : 30
# Frames Per Second : 55 || Percentage Parsed : 30
# Frames Per Second : 53 || Percentage Parsed : 30
# Frames Per Second : 55 || Percentage Parsed : 30
# Frames Per Second : 54 || Percentage Parsed : 30
# Frames Per Second : 55 || Percentage Parsed : 30
# Frames Per Second : 54 || Percentage Parsed : 30
# Frames Per Second : 54 || Percentage Parsed : 31
# Frames Per Second : 54 || Percentage Parsed : 31
# Frames Per Second : 54 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 54 || Percentage Parsed : 31
# Frames Per Second : 54 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 54 || Percentage Parsed : 31
# Frames Per Second : 54 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 55 || Percentage Parsed : 31
# Frames Per Second : 54 || Percentage Parsed : 32
# Frames Per Second : 55 || Percentage Parsed : 32
# Frames Per Second : 53 || Percentage Parsed : 32
# Frames Per Second : 54 || Percentage Parsed : 32
# Frames Per Second : 54 || Percentage Parsed : 32
# Frames Per Second : 54 || Percentage Parsed : 32
# Frames Per Second : 55 || Percentage Parsed : 32
# Frames Per Second : 53 || Percentage Parsed : 32
# Frames Per Second : 54 || Percentage Parsed : 32
# Frames Per Second : 51 || Percentage Parsed : 32
# Frames Per Second : 52 || Percentage Parsed : 32
# Frames Per Second : 52 || Percentage Parsed : 32
# Frames Per Second : 53 || Percentage Parsed : 32
# Frames Per Second : 55 || Percentage Parsed : 32
# Frames Per Second : 52 || Percentage Parsed : 32
# Frames Per Second : 53 || Percentage Parsed : 33
# Frames Per Second : 52 || Percentage Parsed : 33
# Frames Per Second : 53 || Percentage Parsed : 33
# Frames Per Second : 53 || Percentage Parsed : 33
# Frames Per Second : 55 || Percentage Parsed : 33
# Frames Per Second : 54 || Percentage Parsed : 33
# Frames Per Second : 55 || Percentage Parsed : 33
# Frames Per Second : 55 || Percentage Parsed : 33
# Frames Per Second : 57 || Percentage Parsed : 33
# Frames Per Second : 56 || Percentage Parsed : 33
# Frames Per Second : 56 || Percentage Parsed : 33
# Frames Per Second : 54 || Percentage Parsed : 33
# Frames Per Second : 53 || Percentage Parsed : 33
# Frames Per Second : 53 || Percentage Parsed : 33
# Frames Per Second : 53 || Percentage Parsed : 34
# Frames Per Second : 54 || Percentage Parsed : 34
# Frames Per Second : 55 || Percentage Parsed : 34
# Frames Per Second : 52 || Percentage Parsed : 34
# Frames Per Second : 52 || Percentage Parsed : 34
# Frames Per Second : 50 || Percentage Parsed : 34
# Frames Per Second : 52 || Percentage Parsed : 34
# Frames Per Second : 52 || Percentage Parsed : 34
# Frames Per Second : 54 || Percentage Parsed : 34
# Frames Per Second : 53 || Percentage Parsed : 34
# Frames Per Second : 54 || Percentage Parsed : 34
# Frames Per Second : 53 || Percentage Parsed : 34
# Frames Per Second : 53 || Percentage Parsed : 34
# Frames Per Second : 54 || Percentage Parsed : 34
# Frames Per Second : 54 || Percentage Parsed : 35
# Frames Per Second : 53 || Percentage Parsed : 35
# Frames Per Second : 54 || Percentage Parsed : 35
# Frames Per Second : 54 || Percentage Parsed : 35
# Frames Per Second : 53 || Percentage Parsed : 35
# Frames Per Second : 53 || Percentage Parsed : 35
# Frames Per Second : 53 || Percentage Parsed : 35
# Frames Per Second : 54 || Percentage Parsed : 35
# Frames Per Second : 54 || Percentage Parsed : 35
# Frames Per Second : 54 || Percentage Parsed : 35
# Frames Per Second : 53 || Percentage Parsed : 35
# Frames Per Second : 51 || Percentage Parsed : 35
# Frames Per Second : 49 || Percentage Parsed : 35
# Frames Per Second : 51 || Percentage Parsed : 35
# Frames Per Second : 54 || Percentage Parsed : 36
# Frames Per Second : 54 || Percentage Parsed : 36
# Frames Per Second : 54 || Percentage Parsed : 36
# Frames Per Second : 54 || Percentage Parsed : 36
# Frames Per Second : 55 || Percentage Parsed : 36
# Frames Per Second : 55 || Percentage Parsed : 36
# Frames Per Second : 55 || Percentage Parsed : 36
# Frames Per Second : 54 || Percentage Parsed : 36
# Frames Per Second : 53 || Percentage Parsed : 36
# Frames Per Second : 55 || Percentage Parsed : 36
# Frames Per Second : 54 || Percentage Parsed : 36
# Frames Per Second : 55 || Percentage Parsed : 36
# Frames Per Second : 55 || Percentage Parsed : 36
# Frames Per Second : 57 || Percentage Parsed : 36
# Frames Per Second : 55 || Percentage Parsed : 37
# Frames Per Second : 55 || Percentage Parsed : 37
# Frames Per Second : 54 || Percentage Parsed : 37
# Frames Per Second : 53 || Percentage Parsed : 37
# Frames Per Second : 54 || Percentage Parsed : 37
# Frames Per Second : 53 || Percentage Parsed : 37
# Frames Per Second : 54 || Percentage Parsed : 37
# Frames Per Second : 55 || Percentage Parsed : 37
# Frames Per Second : 54 || Percentage Parsed : 37
# Frames Per Second : 54 || Percentage Parsed : 37
# Frames Per Second : 55 || Percentage Parsed : 37
# Frames Per Second : 54 || Percentage Parsed : 37
# Frames Per Second : 55 || Percentage Parsed : 37
# Frames Per Second : 53 || Percentage Parsed : 37
# Frames Per Second : 55 || Percentage Parsed : 38
# Frames Per Second : 54 || Percentage Parsed : 38
# Frames Per Second : 55 || Percentage Parsed : 38
# Frames Per Second : 55 || Percentage Parsed : 38
# Frames Per Second : 53 || Percentage Parsed : 38
# Frames Per Second : 53 || Percentage Parsed : 38
# Frames Per Second : 54 || Percentage Parsed : 38
# Frames Per Second : 55 || Percentage Parsed : 38
# Frames Per Second : 56 || Percentage Parsed : 38
# Frames Per Second : 54 || Percentage Parsed : 38
# Frames Per Second : 54 || Percentage Parsed : 38
# Frames Per Second : 54 || Percentage Parsed : 38
# Frames Per Second : 54 || Percentage Parsed : 38
# Frames Per Second : 56 || Percentage Parsed : 38
# Frames Per Second : 55 || Percentage Parsed : 38
# Frames Per Second : 53 || Percentage Parsed : 39
# Frames Per Second : 49 || Percentage Parsed : 39
# Frames Per Second : 49 || Percentage Parsed : 39
# Frames Per Second : 46 || Percentage Parsed : 39
# Frames Per Second : 46 || Percentage Parsed : 39
# Frames Per Second : 47 || Percentage Parsed : 39
# Frames Per Second : 45 || Percentage Parsed : 39
# Frames Per Second : 46 || Percentage Parsed : 39
# Frames Per Second : 49 || Percentage Parsed : 39
# Frames Per Second : 51 || Percentage Parsed : 39
# Frames Per Second : 54 || Percentage Parsed : 39
# Frames Per Second : 54 || Percentage Parsed : 39
# Frames Per Second : 53 || Percentage Parsed : 39
# Frames Per Second : 54 || Percentage Parsed : 39
# Frames Per Second : 54 || Percentage Parsed : 40
# Frames Per Second : 55 || Percentage Parsed : 40
# Frames Per Second : 55 || Percentage Parsed : 40
# Frames Per Second : 54 || Percentage Parsed : 40
# Frames Per Second : 54 || Percentage Parsed : 40
# Frames Per Second : 55 || Percentage Parsed : 40
# Frames Per Second : 55 || Percentage Parsed : 40
# Frames Per Second : 58 || Percentage Parsed : 40
# Frames Per Second : 56 || Percentage Parsed : 40
# Frames Per Second : 56 || Percentage Parsed : 40
# Frames Per Second : 53 || Percentage Parsed : 40
# Frames Per Second : 53 || Percentage Parsed : 40
# Frames Per Second : 53 || Percentage Parsed : 40
# Frames Per Second : 53 || Percentage Parsed : 40
# Frames Per Second : 54 || Percentage Parsed : 41
# Frames Per Second : 56 || Percentage Parsed : 41
# Frames Per Second : 58 || Percentage Parsed : 41
# Frames Per Second : 57 || Percentage Parsed : 41
# Frames Per Second : 55 || Percentage Parsed : 41
# Frames Per Second : 55 || Percentage Parsed : 41
# Frames Per Second : 54 || Percentage Parsed : 41
# Frames Per Second : 55 || Percentage Parsed : 41
# Frames Per Second : 55 || Percentage Parsed : 41
# Frames Per Second : 55 || Percentage Parsed : 41
# Frames Per Second : 51 || Percentage Parsed : 41
# Frames Per Second : 50 || Percentage Parsed : 41
# Frames Per Second : 51 || Percentage Parsed : 41
# Frames Per Second : 49 || Percentage Parsed : 41
# Frames Per Second : 49 || Percentage Parsed : 42
# Frames Per Second : 50 || Percentage Parsed : 42
# Frames Per Second : 50 || Percentage Parsed : 42
# Frames Per Second : 50 || Percentage Parsed : 42
# Frames Per Second : 49 || Percentage Parsed : 42
# Frames Per Second : 50 || Percentage Parsed : 42
# Frames Per Second : 46 || Percentage Parsed : 42
# Frames Per Second : 44 || Percentage Parsed : 42
# Frames Per Second : 44 || Percentage Parsed : 42
# Frames Per Second : 45 || Percentage Parsed : 42
# Frames Per Second : 45 || Percentage Parsed : 42
# Frames Per Second : 44 || Percentage Parsed : 42
# Frames Per Second : 46 || Percentage Parsed : 42
# Frames Per Second : 46 || Percentage Parsed : 42
# Frames Per Second : 45 || Percentage Parsed : 43
# Frames Per Second : 44 || Percentage Parsed : 43
# Frames Per Second : 44 || Percentage Parsed : 43
# Frames Per Second : 44 || Percentage Parsed : 43
# Frames Per Second : 45 || Percentage Parsed : 43
# Frames Per Second : 45 || Percentage Parsed : 43
# Frames Per Second : 44 || Percentage Parsed : 43
# Frames Per Second : 50 || Percentage Parsed : 43
# Frames Per Second : 55 || Percentage Parsed : 43
# Frames Per Second : 55 || Percentage Parsed : 43
# Frames Per Second : 53 || Percentage Parsed : 43
# Frames Per Second : 53 || Percentage Parsed : 43
# Frames Per Second : 54 || Percentage Parsed : 43
# Frames Per Second : 51 || Percentage Parsed : 43
# Frames Per Second : 49 || Percentage Parsed : 43
# Frames Per Second : 49 || Percentage Parsed : 44
# Frames Per Second : 52 || Percentage Parsed : 44
# Frames Per Second : 50 || Percentage Parsed : 44
# Frames Per Second : 49 || Percentage Parsed : 44
# Frames Per Second : 50 || Percentage Parsed : 44
# Frames Per Second : 51 || Percentage Parsed : 44
# Frames Per Second : 49 || Percentage Parsed : 44
# Frames Per Second : 48 || Percentage Parsed : 44
# Frames Per Second : 48 || Percentage Parsed : 44
# Frames Per Second : 48 || Percentage Parsed : 44
# Frames Per Second : 47 || Percentage Parsed : 44
# Frames Per Second : 47 || Percentage Parsed : 44
# Frames Per Second : 47 || Percentage Parsed : 44
# Frames Per Second : 53 || Percentage Parsed : 44
# Frames Per Second : 54 || Percentage Parsed : 45
# Frames Per Second : 54 || Percentage Parsed : 45
# Frames Per Second : 56 || Percentage Parsed : 45
# Frames Per Second : 56 || Percentage Parsed : 45
# Frames Per Second : 54 || Percentage Parsed : 45
# Frames Per Second : 54 || Percentage Parsed : 45
# Frames Per Second : 53 || Percentage Parsed : 45
# Frames Per Second : 53 || Percentage Parsed : 45
# Frames Per Second : 54 || Percentage Parsed : 45
# Frames Per Second : 54 || Percentage Parsed : 45
# Frames Per Second : 52 || Percentage Parsed : 45
# Frames Per Second : 51 || Percentage Parsed : 45
# Frames Per Second : 55 || Percentage Parsed : 45
# Frames Per Second : 53 || Percentage Parsed : 45
# Frames Per Second : 52 || Percentage Parsed : 46
# Frames Per Second : 52 || Percentage Parsed : 46
# Frames Per Second : 52 || Percentage Parsed : 46
# Frames Per Second : 53 || Percentage Parsed : 46
# Frames Per Second : 53 || Percentage Parsed : 46
# Frames Per Second : 56 || Percentage Parsed : 46
# Frames Per Second : 55 || Percentage Parsed : 46
# Frames Per Second : 53 || Percentage Parsed : 46
# Frames Per Second : 54 || Percentage Parsed : 46
# Frames Per Second : 54 || Percentage Parsed : 46
# Frames Per Second : 54 || Percentage Parsed : 46
# Frames Per Second : 53 || Percentage Parsed : 46
# Frames Per Second : 54 || Percentage Parsed : 46
# Frames Per Second : 53 || Percentage Parsed : 46
# Frames Per Second : 54 || Percentage Parsed : 47
# Frames Per Second : 54 || Percentage Parsed : 47
# Frames Per Second : 51 || Percentage Parsed : 47
# Frames Per Second : 49 || Percentage Parsed : 47
# Frames Per Second : 50 || Percentage Parsed : 47
# Frames Per Second : 50 || Percentage Parsed : 47
# Frames Per Second : 51 || Percentage Parsed : 47
# Frames Per Second : 54 || Percentage Parsed : 47
# Frames Per Second : 53 || Percentage Parsed : 47
# Frames Per Second : 55 || Percentage Parsed : 47
# Frames Per Second : 55 || Percentage Parsed : 47
# Frames Per Second : 55 || Percentage Parsed : 47
# Frames Per Second : 53 || Percentage Parsed : 47
# Frames Per Second : 55 || Percentage Parsed : 47
# Frames Per Second : 55 || Percentage Parsed : 48
# Frames Per Second : 53 || Percentage Parsed : 48
# Frames Per Second : 54 || Percentage Parsed : 48
# Frames Per Second : 57 || Percentage Parsed : 48
# Frames Per Second : 55 || Percentage Parsed : 48
# Frames Per Second : 52 || Percentage Parsed : 48
# Frames Per Second : 52 || Percentage Parsed : 48
# Frames Per Second : 53 || Percentage Parsed : 48
# Frames Per Second : 54 || Percentage Parsed : 48
# Frames Per Second : 50 || Percentage Parsed : 48
# Frames Per Second : 52 || Percentage Parsed : 48
# Frames Per Second : 55 || Percentage Parsed : 48
# Frames Per Second : 55 || Percentage Parsed : 48
# Frames Per Second : 53 || Percentage Parsed : 48
# Frames Per Second : 56 || Percentage Parsed : 49
# Frames Per Second : 57 || Percentage Parsed : 49
# Frames Per Second : 54 || Percentage Parsed : 49
# Frames Per Second : 52 || Percentage Parsed : 49
# Frames Per Second : 52 || Percentage Parsed : 49
# Frames Per Second : 52 || Percentage Parsed : 49
# Frames Per Second : 52 || Percentage Parsed : 49
# Frames Per Second : 52 || Percentage Parsed : 49
# Frames Per Second : 52 || Percentage Parsed : 49
# Frames Per Second : 53 || Percentage Parsed : 49
# Frames Per Second : 57 || Percentage Parsed : 49
# Frames Per Second : 56 || Percentage Parsed : 49
# Frames Per Second : 58 || Percentage Parsed : 49
# Frames Per Second : 58 || Percentage Parsed : 49
# Frames Per Second : 56 || Percentage Parsed : 49
# Frames Per Second : 50 || Percentage Parsed : 50
# Frames Per Second : 50 || Percentage Parsed : 50
# Frames Per Second : 50 || Percentage Parsed : 50
# Frames Per Second : 49 || Percentage Parsed : 50
# Frames Per Second : 51 || Percentage Parsed : 50
# Frames Per Second : 51 || Percentage Parsed : 50
# Frames Per Second : 52 || Percentage Parsed : 50
# Frames Per Second : 53 || Percentage Parsed : 50
# Frames Per Second : 56 || Percentage Parsed : 50
# Frames Per Second : 56 || Percentage Parsed : 50
# Frames Per Second : 57 || Percentage Parsed : 50
# Frames Per Second : 57 || Percentage Parsed : 50
# Frames Per Second : 57 || Percentage Parsed : 50
# Frames Per Second : 57 || Percentage Parsed : 50
# Frames Per Second : 58 || Percentage Parsed : 51
# Frames Per Second : 57 || Percentage Parsed : 51
# Frames Per Second : 58 || Percentage Parsed : 51
# Frames Per Second : 58 || Percentage Parsed : 51
# Frames Per Second : 58 || Percentage Parsed : 51
# Frames Per Second : 58 || Percentage Parsed : 51
# Frames Per Second : 58 || Percentage Parsed : 51
# Frames Per Second : 55 || Percentage Parsed : 51
# Frames Per Second : 54 || Percentage Parsed : 51
# Frames Per Second : 53 || Percentage Parsed : 51
# Frames Per Second : 51 || Percentage Parsed : 51
# Frames Per Second : 50 || Percentage Parsed : 51
# Frames Per Second : 49 || Percentage Parsed : 51
# Frames Per Second : 50 || Percentage Parsed : 51
# Frames Per Second : 49 || Percentage Parsed : 52
# Frames Per Second : 48 || Percentage Parsed : 52
# Frames Per Second : 50 || Percentage Parsed : 52
# Frames Per Second : 53 || Percentage Parsed : 52
# Frames Per Second : 53 || Percentage Parsed : 52
# Frames Per Second : 53 || Percentage Parsed : 52
# Frames Per Second : 54 || Percentage Parsed : 52
# Frames Per Second : 54 || Percentage Parsed : 52
# Frames Per Second : 55 || Percentage Parsed : 52
# Frames Per Second : 54 || Percentage Parsed : 52
# Frames Per Second : 53 || Percentage Parsed : 52
# Frames Per Second : 52 || Percentage Parsed : 52
# Frames Per Second : 50 || Percentage Parsed : 52
# Frames Per Second : 48 || Percentage Parsed : 52
# Frames Per Second : 48 || Percentage Parsed : 53
# Frames Per Second : 47 || Percentage Parsed : 53
# Frames Per Second : 46 || Percentage Parsed : 53
# Frames Per Second : 48 || Percentage Parsed : 53
# Frames Per Second : 48 || Percentage Parsed : 53
# Frames Per Second : 48 || Percentage Parsed : 53
# Frames Per Second : 48 || Percentage Parsed : 53
# Frames Per Second : 48 || Percentage Parsed : 53
# Frames Per Second : 47 || Percentage Parsed : 53
# Frames Per Second : 47 || Percentage Parsed : 53
# Frames Per Second : 48 || Percentage Parsed : 53
# Frames Per Second : 47 || Percentage Parsed : 53
# Frames Per Second : 53 || Percentage Parsed : 53
# Frames Per Second : 55 || Percentage Parsed : 53
# Frames Per Second : 58 || Percentage Parsed : 54
# Frames Per Second : 58 || Percentage Parsed : 54
# Frames Per Second : 55 || Percentage Parsed : 54
# Frames Per Second : 56 || Percentage Parsed : 54
# Frames Per Second : 58 || Percentage Parsed : 54
# Frames Per Second : 58 || Percentage Parsed : 54
# Frames Per Second : 58 || Percentage Parsed : 54
# Frames Per Second : 56 || Percentage Parsed : 54
# Frames Per Second : 60 || Percentage Parsed : 54
# Frames Per Second : 56 || Percentage Parsed : 54
# Frames Per Second : 52 || Percentage Parsed : 54
# Frames Per Second : 52 || Percentage Parsed : 54
# Frames Per Second : 52 || Percentage Parsed : 54
# Frames Per Second : 54 || Percentage Parsed : 54
# Frames Per Second : 53 || Percentage Parsed : 54
# Frames Per Second : 53 || Percentage Parsed : 55
# Frames Per Second : 54 || Percentage Parsed : 55
# Frames Per Second : 54 || Percentage Parsed : 55
# Frames Per Second : 52 || Percentage Parsed : 55
# Frames Per Second : 48 || Percentage Parsed : 55
# Frames Per Second : 49 || Percentage Parsed : 55
# Frames Per Second : 51 || Percentage Parsed : 55
# Frames Per Second : 52 || Percentage Parsed : 55
# Frames Per Second : 53 || Percentage Parsed : 55
# Frames Per Second : 57 || Percentage Parsed : 55
# Frames Per Second : 55 || Percentage Parsed : 55
# Frames Per Second : 57 || Percentage Parsed : 55
# Frames Per Second : 58 || Percentage Parsed : 55
# Frames Per Second : 58 || Percentage Parsed : 55
# Frames Per Second : 59 || Percentage Parsed : 56
# Frames Per Second : 58 || Percentage Parsed : 56
# Frames Per Second : 58 || Percentage Parsed : 56
# Frames Per Second : 59 || Percentage Parsed : 56
# Frames Per Second : 57 || Percentage Parsed : 56
# Frames Per Second : 58 || Percentage Parsed : 56
# Frames Per Second : 55 || Percentage Parsed : 56
# Frames Per Second : 53 || Percentage Parsed : 56
# Frames Per Second : 57 || Percentage Parsed : 56
# Frames Per Second : 56 || Percentage Parsed : 56
# Frames Per Second : 54 || Percentage Parsed : 56
# Frames Per Second : 54 || Percentage Parsed : 56
# Frames Per Second : 52 || Percentage Parsed : 56
# Frames Per Second : 55 || Percentage Parsed : 56
# Frames Per Second : 54 || Percentage Parsed : 57
# Frames Per Second : 55 || Percentage Parsed : 57
# Frames Per Second : 55 || Percentage Parsed : 57
# Frames Per Second : 55 || Percentage Parsed : 57
# Frames Per Second : 55 || Percentage Parsed : 57
# Frames Per Second : 57 || Percentage Parsed : 57
# Frames Per Second : 58 || Percentage Parsed : 57
# Frames Per Second : 56 || Percentage Parsed : 57
# Frames Per Second : 55 || Percentage Parsed : 57
# Frames Per Second : 54 || Percentage Parsed : 57
# Frames Per Second : 54 || Percentage Parsed : 57
# Frames Per Second : 55 || Percentage Parsed : 57
# Frames Per Second : 54 || Percentage Parsed : 57
# Frames Per Second : 55 || Percentage Parsed : 57
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 56 || Percentage Parsed : 58
# Frames Per Second : 54 || Percentage Parsed : 58
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 56 || Percentage Parsed : 58
# Frames Per Second : 56 || Percentage Parsed : 58
# Frames Per Second : 54 || Percentage Parsed : 58
# Frames Per Second : 54 || Percentage Parsed : 58
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 54 || Percentage Parsed : 58
# Frames Per Second : 55 || Percentage Parsed : 58
# Frames Per Second : 54 || Percentage Parsed : 58
# Frames Per Second : 54 || Percentage Parsed : 59
# Frames Per Second : 55 || Percentage Parsed : 59
# Frames Per Second : 54 || Percentage Parsed : 59
# Frames Per Second : 53 || Percentage Parsed : 59
# Frames Per Second : 52 || Percentage Parsed : 59
# Frames Per Second : 55 || Percentage Parsed : 59
# Frames Per Second : 54 || Percentage Parsed : 59
# Frames Per Second : 54 || Percentage Parsed : 59
# Frames Per Second : 55 || Percentage Parsed : 59
# Frames Per Second : 57 || Percentage Parsed : 59
# Frames Per Second : 57 || Percentage Parsed : 59
# Frames Per Second : 55 || Percentage Parsed : 59
# Frames Per Second : 54 || Percentage Parsed : 59
# Frames Per Second : 55 || Percentage Parsed : 59
# Frames Per Second : 55 || Percentage Parsed : 60
# Frames Per Second : 56 || Percentage Parsed : 60
# Frames Per Second : 54 || Percentage Parsed : 60
# Frames Per Second : 53 || Percentage Parsed : 60
# Frames Per Second : 56 || Percentage Parsed : 60
# Frames Per Second : 57 || Percentage Parsed : 60
# Frames Per Second : 58 || Percentage Parsed : 60
# Frames Per Second : 55 || Percentage Parsed : 60
# Frames Per Second : 56 || Percentage Parsed : 60
# Frames Per Second : 55 || Percentage Parsed : 60
# Frames Per Second : 55 || Percentage Parsed : 60
# Frames Per Second : 55 || Percentage Parsed : 60
# Frames Per Second : 55 || Percentage Parsed : 60
# Frames Per Second : 55 || Percentage Parsed : 60
# Frames Per Second : 55 || Percentage Parsed : 60
# Frames Per Second : 58 || Percentage Parsed : 61
# Frames Per Second : 58 || Percentage Parsed : 61
# Frames Per Second : 57 || Percentage Parsed : 61
# Frames Per Second : 57 || Percentage Parsed : 61
# Frames Per Second : 58 || Percentage Parsed : 61
# Frames Per Second : 55 || Percentage Parsed : 61
# Frames Per Second : 52 || Percentage Parsed : 61
# Frames Per Second : 57 || Percentage Parsed : 61
# Frames Per Second : 57 || Percentage Parsed : 61
# Frames Per Second : 57 || Percentage Parsed : 61
# Frames Per Second : 55 || Percentage Parsed : 61
# Frames Per Second : 54 || Percentage Parsed : 61
# Frames Per Second : 53 || Percentage Parsed : 61
# Frames Per Second : 53 || Percentage Parsed : 61
# Frames Per Second : 55 || Percentage Parsed : 62
# Frames Per Second : 56 || Percentage Parsed : 62
# Frames Per Second : 53 || Percentage Parsed : 62
# Frames Per Second : 55 || Percentage Parsed : 62
# Frames Per Second : 55 || Percentage Parsed : 62
# Frames Per Second : 54 || Percentage Parsed : 62
# Frames Per Second : 53 || Percentage Parsed : 62
# Frames Per Second : 54 || Percentage Parsed : 62
# Frames Per Second : 55 || Percentage Parsed : 62
# Frames Per Second : 55 || Percentage Parsed : 62
# Frames Per Second : 54 || Percentage Parsed : 62
# Frames Per Second : 54 || Percentage Parsed : 62
# Frames Per Second : 54 || Percentage Parsed : 62
# Frames Per Second : 54 || Percentage Parsed : 62
# Frames Per Second : 54 || Percentage Parsed : 63
# Frames Per Second : 53 || Percentage Parsed : 63
# Frames Per Second : 54 || Percentage Parsed : 63
# Frames Per Second : 54 || Percentage Parsed : 63
# Frames Per Second : 54 || Percentage Parsed : 63
# Frames Per Second : 54 || Percentage Parsed : 63
# Frames Per Second : 55 || Percentage Parsed : 63
# Frames Per Second : 55 || Percentage Parsed : 63
# Frames Per Second : 55 || Percentage Parsed : 63
# Frames Per Second : 56 || Percentage Parsed : 63
# Frames Per Second : 55 || Percentage Parsed : 63
# Frames Per Second : 55 || Percentage Parsed : 63
# Frames Per Second : 57 || Percentage Parsed : 63
# Frames Per Second : 56 || Percentage Parsed : 63
# Frames Per Second : 55 || Percentage Parsed : 64
# Frames Per Second : 55 || Percentage Parsed : 64
# Frames Per Second : 55 || Percentage Parsed : 64
# Frames Per Second : 55 || Percentage Parsed : 64
# Frames Per Second : 56 || Percentage Parsed : 64
# Frames Per Second : 54 || Percentage Parsed : 64
# Frames Per Second : 58 || Percentage Parsed : 64
# Frames Per Second : 57 || Percentage Parsed : 64
# Frames Per Second : 54 || Percentage Parsed : 64
# Frames Per Second : 55 || Percentage Parsed : 64
# Frames Per Second : 55 || Percentage Parsed : 64
# Frames Per Second : 55 || Percentage Parsed : 64
# Frames Per Second : 54 || Percentage Parsed : 64
# Frames Per Second : 55 || Percentage Parsed : 64
# Frames Per Second : 53 || Percentage Parsed : 65
# Frames Per Second : 55 || Percentage Parsed : 65
# Frames Per Second : 57 || Percentage Parsed : 65
# Frames Per Second : 57 || Percentage Parsed : 65
# Frames Per Second : 58 || Percentage Parsed : 65
# Frames Per Second : 57 || Percentage Parsed : 65
# Frames Per Second : 59 || Percentage Parsed : 65
# Frames Per Second : 58 || Percentage Parsed : 65
# Frames Per Second : 57 || Percentage Parsed : 65
# Frames Per Second : 54 || Percentage Parsed : 65
# Frames Per Second : 56 || Percentage Parsed : 65
# Frames Per Second : 56 || Percentage Parsed : 65
# Frames Per Second : 52 || Percentage Parsed : 65
# Frames Per Second : 54 || Percentage Parsed : 65
# Frames Per Second : 52 || Percentage Parsed : 65
# Frames Per Second : 51 || Percentage Parsed : 66
# Frames Per Second : 52 || Percentage Parsed : 66
# Frames Per Second : 53 || Percentage Parsed : 66
# Frames Per Second : 51 || Percentage Parsed : 66
# Frames Per Second : 52 || Percentage Parsed : 66
# Frames Per Second : 52 || Percentage Parsed : 66
# Frames Per Second : 52 || Percentage Parsed : 66
# Frames Per Second : 52 || Percentage Parsed : 66
# Frames Per Second : 52 || Percentage Parsed : 66
# Frames Per Second : 54 || Percentage Parsed : 66
# Frames Per Second : 54 || Percentage Parsed : 66
# Frames Per Second : 56 || Percentage Parsed : 66
# Frames Per Second : 55 || Percentage Parsed : 66
# Frames Per Second : 56 || Percentage Parsed : 66
# Completed!

# %% [markdown]
# Salvamos el video resultante del proceso en nuestro Drive:

# %%
# Input video path
save_path = "/content/fuerzas_armadas_yolov5_augmented_humans.mp4"

# Compressed video path
compressed_path = "/content/fuerzas_armadas_yolov5_augmented_humans_compressed_02.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")
# Out:
# 0

# %%
shutil.copy(
    "/content/fuerzas_armadas_yolov5_augmented_humans_compressed_02.mp4",
    "/content/drive/MyDrive/tfg/videos/fuerzas_armadas_yolov5_augmented_humans_compressed_02_true.mp4"
)
# Out:
# '/content/drive/MyDrive/tfg/videos/fuerzas_armadas_yolov5_augmented_humans_compressed_02_true.mp4'

# %%
shutil.rmtree("/content/runs")
